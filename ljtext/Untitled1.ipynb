# %%
from sqlalchemy import create_engine
import pandas as pd
import pyhive
login_info = {'host': '10.5.70.24',
              'port': '10000',
              'db': 'default'}
engine = create_engine(
    'hive://{host}:{port}/{db}'
        .format(
                host=login_info['host'],
                port=login_info['port'],
                db=login_info['db']), echo=False)

# %%
store_basic_sql= '''select COUNT(*) from erke_shidian_edw_ai_dev.dim_stockorg'''
store_basic = pd.read_sql(store_basic_sql, engine)
store_basic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8253643af252> in <module>
#       1 store_basic_sql= '''select COUNT(*) from erke_shidian_edw_ai_dev.dim_stockorg'''
# ----> 2 store_basic = pd.read_sql(store_basic_sql, engine)
#       3 store_basic
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     395             sql, index_col=index_col, params=params,
#     396             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 397             chunksize=chunksize)
#     398
#     399
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1061         args = _convert_params(sql, params)
#    1062
# ...

# %%
from pyhive import hive
conn = hive.Connection(host='10.5.70.24', port=10000, username='', database='default')
cursor = conn.cursor()
cursor.execute('select COUNT(*) from erke_shidian_edw_ai_dev.dim_stockorg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e6da8be0e517> in <module>
#       1 from pyhive import hive
# ----> 2 conn = hive.Connection(host='10.5.70.24', port=10000, username='', database='default')
#       3 cursor = conn.cursor()
#       4 cursor.execute('select COUNT(*) from erke_shidian_edw_ai_dev.dim_stockorg')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyhive\hive.py in __init__(self, host, port, username, database, auth, configuration, kerberos_service_name, password, thrift_transport)
#     150             elif auth in ('LDAP', 'KERBEROS', 'NONE', 'CUSTOM'):
#     151                 # Defer import so package dependency is optional
# --> 152                 import sasl
#     153                 import thrift_sasl
#     154
#
# ModuleNotFoundError: No module named 'sasl'
