# %%
import pickle
import pandas as pd
import datetime as dt

# %% [markdown]
# # 期初库存表

# %%
i0 = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\i0.pickle')

# %%
i0
# Out:
#                                   i0  r
# prod_id     color_id size org_id
# 11119101014 001      39   0001    37  0
#                           2492     3  0
#                           2822     5  0
#                           3607     2  0
#                           3766     1  0
#                           3771     2  0
#                           5797     2  0
#                           6095     4  0
#                           6099     3  0
#                           7233     4  0
#                           7235     3  0
#                           7248     2  0
#                           7293     2  0
#                           7305     5  0
#                           7312     3  0
#                           7313     2  0
#                           7315     3  0
#                           7325     3  0
#                           7358     1  0
#                           7383     1  0
#                           7384     1  0
# ...

# %% [markdown]
# # 产品信息表

# %%
pi = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\pi.pickle')

# %%
pi
# Out:
#                      size  size_order  year season_id class_0
# prod_id     color_id
# 11119101014 001        38           3  2019        Q1      鞋类
#             001        39           4  2019        Q1      鞋类
#             001        40           5  2019        Q1      鞋类
#             001        41           6  2019        Q1      鞋类
#             001        42           7  2019        Q1      鞋类
#             001        43           8  2019        Q1      鞋类
#             001        44           9  2019        Q1      鞋类
#             001        45          10  2019        Q1      鞋类
#             001        46          11  2019        Q1      鞋类
#             001        47          12  2019        Q1      鞋类
#             001        48          13  2019        Q1      鞋类
#             001        49          14  2019        Q1      鞋类
#             001        50          15  2019        Q1      鞋类
#             002        38           3  2019        Q1      鞋类
# ...

# %% [markdown]
# # 库存移动事实表

# %%
mv = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\mv.pickle')

# %%
mv
# Out:
#                           org_send_id org_rec_id  date_send   date_rec  \
# prod_id     color_id size
# 11117101032 男滑板鞋     39          X416       3131 2018-06-12 2018-06-12
#                      40          3131       X416 2018-06-08 2018-06-10
#                      40          X416       3131 2018-06-12 2018-06-12
#                      40          X416       3131 2018-06-12 2018-06-12
#                      40          X416       9623 2018-06-12 2018-06-14
#                      41          X416       3131 2018-06-12 2018-06-12
# 11117101145 男滑板鞋     42          7300       9623 2018-03-03 2018-03-04
# 11117102143 男微跑鞋     39          0001       3131 2018-04-17 2018-04-17
#                      39          0001       3766 2018-04-15 2018-04-15
#                      39          0001       7235 2018-04-17 2018-04-17
#                      39          0001       X011 2018-04-17 2018-04-17
#                      39          0001       X450 2018-04-18 2018-04-18
# ...

# %% [markdown]
# # 组织信息表

# %%
oi = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\oi.pickle')

# %%
oi
# Out:
#        prov_id city_id dist_id mng_reg_id  is_store
# org_id
# 0001        江苏      无锡    None       None         0
# 2492        浙江     杭州市    None        萧山区         1
# 2822        浙江     杭州市    None       杭州外区         1
# 3131        浙江     杭州市    None        萧山区         1
# 3607        浙江     绍兴市    None        绍兴区         1
# 3698        浙江     宁波市    None       宁波二区         1
# 3766        浙江     杭州市    None        杭州区         1
# 3771        浙江     杭州市    None        萧山区         1
# 5797        浙江     嘉兴市    None        嘉兴区         1
# 6095        浙江     杭州市    None       杭州外区         1
# 6099        浙江     绍兴市    None        绍兴区         1
# 6814        浙江     杭州市    None        萧山区         1
# 7233        浙江     杭州市    None        杭州区         1
# 7235        浙江     杭州市    None        杭州区         1
# 7248        浙江     湖州市    None        湖州区         1
# 7293        浙江     嘉兴市    None        嘉兴区         1
# 7300        浙江     嘉兴市    None        嘉兴区         1
# ...

# %% [markdown]
# # 销售数据表

# %%
s = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\s.pickle')

# %%
s
# Out:
#                                   date_sell    s
# prod_id     color_id size org_id
# 11119101014 001      39   3771   2019-03-18  158
#                           3771   2019-03-17   79
#                           5797   2019-03-16   79
#                           7541   2019-03-26   79
#                           8270   2019-03-10   79
#                           8792   2019-03-01   79
#                           9208   2019-03-20   79
#                           9212   2019-03-22   79
#                           9550   2019-03-16   79
#                           9738   2019-03-28   79
#                           X002   2019-03-09   79
#                           X032   2019-03-11   79
#                           X044   2019-03-10   79
#                           X044   2019-03-09   79
#                           X398   2019-03-13   79
#                           X517   2019-03-09   79
#                      40   2492   2019-03-21   79
# ...

# %% [markdown]
# # 空表

# %%
di = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\di.pickle')

# %%
itp = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\itp.pickle')

# %%
mpa = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\mpa.pickle')

# %%
mss = pd.read_pickle('C:\\Users\\liuju\\Desktop\\linezone_model_set\\data0329\\mss.pickle')

# %%
di
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
itp
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mpa
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mss
# Out:
# Empty DataFrame
# Columns: []
# Index: []
