# %%
import pandas as pd
import numpy as np

s = pd.Series([1,2,4,123])
s
# Out:
# 0      1
# 1      2
# 2      4
# 3    123
# dtype: int64

# %%
datalist = np.array([2,12,223,3])
print('len= '+str(len(datalist)))
s = pd.Series(datalist)
s
print('s[2]='+str(s[2]))
print(s[1])
# Out:
# len= 4
# s[2]=223
# 12

# %%
p = pd.Series(datalist,index = [100,101,102,105])
p
# Out:
# 100      2
# 101     12
# 102    223
# 105      3
# dtype: int32

# %%
data2 = 5
da2 = pd.Series(data2, index = [1, 3, 4])
da2
# Out:
# 1    5
# 3    5
# 4    5
# dtype: int64

# %%
data1 = {'a':2,'b':44,'c':2,'3':88}
dal = pd.Series(data1, index = ['a','3','d','c'])
print(dal['3'])
print(dal[:4])
dal
# Out:
# 88.0
# a     2.0
# 3    88.0
# d     NaN
# c     2.0
# dtype: float64
# a     2.0
# 3    88.0
# d     NaN
# c     2.0
# dtype: float64

# %% [markdown]
# ## DataFrame

# %%
f1 = pd.DataFrame()
print(f1)
f1
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
list1 = [1,23,33,4,3]
f2 = pd.DataFrame(list1)
f2
# Out:
#     0
# 0   1
# 1  23
# 2  33
# 3   4
# 4   3

# %%
print(f2)
# Out:
#     0
# 0   1
# 1  23
# 2  33
# 3   4
# 4   3

# %%
list3 = [["liu",2],['sun',8],['bule','jun']]
f3 = pd.DataFrame(list3)
f3
# Out:
#       0    1
# 0   liu    2
# 1   sun    8
# 2  bule  jun

# %% [markdown]
# ## 字典

# %%
list4 = [{'liu':'kk','jun':'as'},{'liu':'bb','jun':'ss','hell':'kk9'}]
list4
# Out:
# [{'liu': 'kk', 'jun': 'as'}, {'liu': 'bb', 'jun': 'ss', 'hell': 'kk9'}]

# %%
f5 = pd.DataFrame(list4)
f5
# Out:
#   hell jun liu
# 0  NaN  as  kk
# 1  kk9  ss  bb

# %%
f6 = pd.DataFrame(list4,index = ['fies','sec'])
f6['jun']
# Out:
# fies    as
# sec     ss
# Name: jun, dtype: object

# %%
f7 = pd.DataFrame(list4, index = ['no1','no2'], columns = ['liu', 'jun'])
f7
# Out:
#     liu jun
# no1  kk  as
# no2  bb  ss

# %% [markdown]
# # 字典的系列可以传递以形成一个DataFrame。 所得到的索引是通过的所有系列索引的并集。

# %%
list18 = {'one':pd.Series([1,3,2,],index=['ll','kk','jj']), 'two':pd.Series([33,23,22],index=['ll','kk','bb'])}
f8 = pd.DataFrame(list18)
f8
# Out:
#     one   two
# bb  NaN  22.0
# jj  2.0   NaN
# kk  3.0  23.0
# ll  1.0  33.0

# %% [markdown]
# # 列选择

# %%
f8['one']
# Out:
# bb    NaN
# jj    2.0
# kk    3.0
# ll    1.0
# Name: one, dtype: float64

# %%
f8['one'].tolist()
# Out:
# [nan, 2.0, 3.0, 1.0]

# %% [markdown]
# ## 列添加

# %%
f8['three'] = pd.Series(['99','990','88'],index = ['ll','kk','bb'])
f8
# Out:
#     one   two three
# bb  NaN  22.0    88
# jj  2.0   NaN   NaN
# kk  3.0  23.0   990
# ll  1.0  33.0    99

# %% [markdown]
# # 列删除

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])
unsorted_df
# Out:
#        col2      col1
# 1 -0.881921  0.533603
# 4 -0.126661 -1.668083
# 6  0.331692  0.157608
# 2 -1.661957  0.158401
# 3 -0.093566 -0.445374
# 5 -0.115678  1.406142
# 9 -1.313440 -0.095257
# 8 -0.751357  0.592248
# 0 -0.662915  0.367287
# 7 -0.812934  0.637964

# %%
sort_df = unsorted_df.sort_index()
sort_df
# Out:
#        col2      col1
# 0 -0.662915  0.367287
# 1 -0.881921  0.533603
# 2 -1.661957  0.158401
# 3 -0.093566 -0.445374
# 4 -0.126661 -1.668083
# 5 -0.115678  1.406142
# 6  0.331692  0.157608
# 7 -0.812934  0.637964
# 8 -0.751357  0.592248
# 9 -1.313440 -0.095257

# %%
sort_udf = unsorted_df.sort_index (ascending = False)
sort_udf
# Out:
#        col2      col1
# 9 -1.313440 -0.095257
# 8 -0.751357  0.592248
# 7 -0.812934  0.637964
# 6  0.331692  0.157608
# 5 -0.115678  1.406142
# 4 -0.126661 -1.668083
# 3 -0.093566 -0.445374
# 2 -1.661957  0.158401
# 1 -0.881921  0.533603
# 0 -0.662915  0.367287

# %%
kk = unsorted_df.sort_index(axis = 1)
kk
# Out:
#        col1      col2
# 1  0.533603 -0.881921
# 4 -1.668083 -0.126661
# 6  0.157608  0.331692
# 2  0.158401 -1.661957
# 3 -0.445374 -0.093566
# 5  1.406142 -0.115678
# 9 -0.095257 -1.313440
# 8  0.592248 -0.751357
# 0  0.367287 -0.662915
# 7  0.637964 -0.812934

# %%
kk1 = kk.sort_values(by = 'col1')
kk1
# Out:
#        col1      col2
# 4 -1.668083 -0.126661
# 3 -0.445374 -0.093566
# 9 -0.095257 -1.313440
# 6  0.157608  0.331692
# 2  0.158401 -1.661957
# 0  0.367287 -0.662915
# 1  0.533603 -0.881921
# 8  0.592248 -0.751357
# 7  0.637964 -0.812934
# 5  1.406142 -0.115678

# %%
kk2 = kk.sort_values(by = ['col1','col2'])
kk2
# Out:
#        col1      col2
# 4 -1.668083 -0.126661
# 3 -0.445374 -0.093566
# 9 -0.095257 -1.313440
# 6  0.157608  0.331692
# 2  0.158401 -1.661957
# 0  0.367287 -0.662915
# 1  0.533603 -0.881921
# 8  0.592248 -0.751357
# 7  0.637964 -0.812934
# 5  1.406142 -0.115678

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],          
        'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
kk3 = pd.DataFrame(ipl_data)
kk3
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
kk3.groupby('Team')

# %%
kk4 =kk3.groupby('Team').groups
kk4
# Out:
# {'Devils': Int64Index([2, 3], dtype='int64'),
#  'Kings': Int64Index([4, 6, 7], dtype='int64'),
#  'Riders': Int64Index([0, 1, 8, 11], dtype='int64'),
#  'Royals': Int64Index([9, 10], dtype='int64'),
#  'kings': Int64Index([5], dtype='int64')}

# %%
kk5 = kk3.groupby(['Team','Year']).groups
kk5
# Out:
# {('Devils', 2014): Int64Index([2], dtype='int64'),
#  ('Devils', 2015): Int64Index([3], dtype='int64'),
#  ('Kings', 2014): Int64Index([4], dtype='int64'),
#  ('Kings', 2016): Int64Index([6], dtype='int64'),
#  ('Kings', 2017): Int64Index([7], dtype='int64'),
#  ('Riders', 2014): Int64Index([0], dtype='int64'),
#  ('Riders', 2015): Int64Index([1], dtype='int64'),
#  ('Riders', 2016): Int64Index([8], dtype='int64'),
#  ('Riders', 2017): Int64Index([11], dtype='int64'),
#  ('Royals', 2014): Int64Index([9], dtype='int64'),
#  ('Royals', 2015): Int64Index([10], dtype='int64'),
#  ('kings', 2015): Int64Index([5], dtype='int64')}

# %% [markdown]
# # format

# %%
print('{},{}'.format('liu','jun'))
# Out:
# liu,jun

# %%
print('{0}{1}'.format('liu','jun'))
# Out:
# liujun

# %%
print('{1},{0},{1}'.format('liu','jun'))
# Out:
# jun,liu,jun

# %%
print('{name},{age}'.format(name='liu',age=18))
# Out:
# liu,18

# %%
list1=['ni','hao','21']
ss = 'wold ssi {}'.format(list1)
ss
# Out:
# "wold ssi ['ni', 'hao', '21']"

# %%
b_dict={"name":'liu', "sex":'nan'}
kk = 'wold shift {name},sex is {sex}'.format(**b_dict)
kk
# Out:
# 'wold shift liu,sex is nan'

# %%
listkk= ['12',"nin",'hao']
s1 = ','.join(listkk)
s1
# Out:
# '12,nin,hao'

# %%
s2 = ','.join("'"+x+"'" for x in listkk)
s2
# Out:
# "'12','nin','hao'"

# %%
from numpy import nan as NaN
df1=pd.DataFrame([[1,2,3],[NaN,NaN,2],[NaN,NaN,NaN],[8,8,NaN]])
df1
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  NaN  NaN  2.0
# 2  NaN  NaN  NaN
# 3  8.0  8.0  NaN

# %%
df1.fillna(0)
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  0.0  0.0  2.0
# 2  0.0  0.0  0.0
# 3  8.0  8.0  0.0

# %%
import numpy as np
df=pd.DataFrame(np.arange(16).reshape((4,4)),index=list(range(4)),columns=['a','b','c','d'])

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.loc[1:3,['b','c']]
# Out:
#     b   c
# 1   5   6
# 2   9  10
# 3  13  14

# %%
df['b']
# Out:
# 0     1
# 1     5
# 2     9
# 3    13
# Name: b, dtype: int32

# %%
df[0:2]
# Out:
#    a  b  c  d
# 0  0  1  2  3
# 1  4  5  6  7

# %%
df.loc[df.loc[:,'a']>1]
# Out:
#     a   b   c   d
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.d
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# Name: d, dtype: int32

# %%
size_list = ['a','b','c','d']

for i in size_list:
    print(df.loc[df[i],i])
# Out:
# 0     0.0
# 4     NaN
# 8     NaN
# 12    NaN
# Name: a, dtype: float64
# 1     5.0
# 5     NaN
# 9     NaN
# 13    NaN
# Name: b, dtype: float64
# 2     10.0
# 6      NaN
# 10     NaN
# 14     NaN
# Name: c, dtype: float64
# 3     15.0
# 7      NaN
# 11     NaN
# 15     NaN
# Name: d, dtype: float64
# C:\Users\liuju\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\indexing.py:1017: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]

# %%
for i in size_list:
    df.loc[df[i]<3,i] =0
    df.loc[df[i]>5,i] =1
df
# Out:
#    a  b  c  d
# 0  0  0  0  3
# 1  4  5  1  1
# 2  1  1  1  1
# 3  1  1  1  1

# %%
fs11 = pd.DataFrame([[21, 1.0,3.0,1],
                   [31, 4.0,5.0,2],
                   [21, 4.0,5.0,-3],
                   [5, 0.0,6.0,4]],

columns = list('ABCD'))
fs11
# Out:
#     A    B    C  D
# 0  21  1.0  3.0  1
# 1  31  4.0  5.0  2
# 2  21  4.0  5.0 -3
# 3   5  0.0  6.0  4

# %%
fs11.cumsum(axis=1)
# Out:
#       A     B     C     D
# 0  21.0  22.0  25.0  26.0
# 1  31.0  35.0  40.0  42.0
# 2  21.0  25.0  30.0  27.0
# 3   5.0   5.0  11.0  15.0

# %%
fs11['max'] = fs11['A']+fs11['B']
fs11
# Out:
#     A    B    C  D   max
# 0  21  1.0  3.0  1  22.0
# 1  31  4.0  5.0  2  35.0
# 2  21  4.0  5.0 -3  25.0
# 3   5  0.0  6.0  4   5.0

# %%
fs11['sum'] = fs11['D'].cumsum()
fs11
# Out:
#     A    B    C  D   max  sum
# 0  21  1.0  3.0  1  22.0    1
# 1  31  4.0  5.0  2  35.0    3
# 2  21  4.0  5.0 -3  25.0    0
# 3   5  0.0  6.0  4   5.0    4

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(8, 4),
index = ['a','b','c','d','e','f','g','z'], columns = ['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# a  0.759611 -0.512248 -0.369929  0.972781
# b  0.126708  0.141740  0.163930 -0.737872
# c -0.764427 -0.792664  0.061916  1.936459
# d -0.186104 -1.432157  0.863699  1.670368
# e -1.132617  0.395906 -0.325871  0.036250
# f  0.388658 -0.337952  0.374892  0.574721
# g -0.695758  1.228083  0.964450 -0.114034
# z -0.854621 -0.912551 -0.369441 -1.501509

# %%
df['A']
# Out:
# a    0.759611
# b    0.126708
# c   -0.764427
# d   -0.186104
# e   -1.132617
# f    0.388658
# g   -0.695758
# z   -0.854621
# Name: A, dtype: float64

# %%
df.loc[:,['A','D']]
# Out:
#           A         D
# a  0.759611  0.972781
# b  0.126708 -0.737872
# c -0.764427  1.936459
# d -0.186104  1.670368
# e -1.132617  0.036250
# f  0.388658  0.574721
# g -0.695758 -0.114034
# z -0.854621 -1.501509

# %%
df.loc[df['D']<0, 'D'] = 0
df
# Out:
#           A         B         C         D
# a  0.759611 -0.512248 -0.369929  0.972781
# b  0.126708  0.141740  0.163930  0.000000
# c -0.764427 -0.792664  0.061916  1.936459
# d -0.186104 -1.432157  0.863699  1.670368
# e -1.132617  0.395906 -0.325871  0.036250
# f  0.388658 -0.337952  0.374892  0.574721
# g -0.695758  1.228083  0.964450  0.000000
# z -0.854621 -0.912551 -0.369441  0.000000

# %%
df.loc[['a','e'],['A','D']]
# Out:
#           A         D
# a  0.759611  0.972781
# e -1.132617  0.036250

# %%
df.loc['a':'e',['A','D']]
# Out:
#           A         D
# a  0.759611  0.972781
# b  0.126708  0.000000
# c -0.764427  1.936459
# d -0.186104  1.670368
# e -1.132617  0.036250

# %%
df.loc['a':'e']
# Out:
#           A         B         C         D
# a  0.759611 -0.512248 -0.369929  0.972781
# b  0.126708  0.141740  0.163930  0.000000
# c -0.764427 -0.792664  0.061916  1.936459
# d -0.186104 -1.432157  0.863699  1.670368
# e -1.132617  0.395906 -0.325871  0.036250

# %% [markdown]
# # loc 两个是参数，前面一个是判断条件，缺失的时候，考虑那个是默认的. 第一个参数是行或者判断条件，第一个参数是列，缺失的情况下 默认是所有

# %%
df.loc['a']
# Out:
# A    0.759611
# B   -0.512248
# C   -0.369929
# D    0.972781
# Name: a, dtype: float64

# %%
df.loc[:,'A']
# Out:
# a    0.759611
# b    0.126708
# c   -0.764427
# d   -0.186104
# e   -1.132617
# f    0.388658
# g   -0.695758
# z   -0.854621
# Name: A, dtype: float64

# %% [markdown]
# # 第一个参数是条件：列A 所有大于0的数，第二个参数是对应的列

# %%
df.loc[df['A']>0,'A']=0

# %%
df
# Out:
#           A         B         C         D
# a  0.000000 -0.512248 -0.369929  0.972781
# b  0.000000  0.141740  0.163930  0.000000
# c -0.764427 -0.792664  0.061916  1.936459
# d -0.186104 -1.432157  0.863699  1.670368
# e -1.132617  0.395906 -0.325871  0.036250
# f  0.000000 -0.337952  0.374892  0.574721
# g -0.695758  1.228083  0.964450  0.000000
# z -0.854621 -0.912551 -0.369441  0.000000

# %%
df['sumCD'] = df['C']+df['D']
df
# Out:
#           A         B         C         D     sumCD
# a  0.000000 -0.512248 -0.369929  0.972781  0.602851
# b  0.000000  0.141740  0.163930  0.000000  0.163930
# c -0.764427 -0.792664  0.061916  1.936459  1.998375
# d -0.186104 -1.432157  0.863699  1.670368  2.534067
# e -1.132617  0.395906 -0.325871  0.036250 -0.289621
# f  0.000000 -0.337952  0.374892  0.574721  0.949613
# g -0.695758  1.228083  0.964450  0.000000  0.964450
# z -0.854621 -0.912551 -0.369441  0.000000 -0.369441

# %%
df['test'] = df['A'].sum()
df
# Out:
#           A         B         C         D     sumCD      test
# a  0.000000 -0.512248 -0.369929  0.972781  0.602851 -3.633527
# b  0.000000  0.141740  0.163930  0.000000  0.163930 -3.633527
# c -0.764427 -0.792664  0.061916  1.936459  1.998375 -3.633527
# d -0.186104 -1.432157  0.863699  1.670368  2.534067 -3.633527
# e -1.132617  0.395906 -0.325871  0.036250 -0.289621 -3.633527
# f  0.000000 -0.337952  0.374892  0.574721  0.949613 -3.633527
# g -0.695758  1.228083  0.964450  0.000000  0.964450 -3.633527
# z -0.854621 -0.912551 -0.369441  0.000000 -0.369441 -3.633527

# %%
sale_data = {'prod_id': ['1101', '1101', '1107', '1107', '11071',
         '1102', '11022', '2200', '3300', '999', '44', '66'],
         'size_id': [12, 12, 233, 233, 21,888 ,888,144,277 , 477,177,2888],
         'Year': [2014-1,2015-3,2014-3,2015-9,2014-1,2015,2016,2017,2016,2014,2015,2017],          
        'qty':[8,79,863,73,1,0,756,0,64,7,8,6]}
sale_data = pd.DataFrame(sale_data)

# %%
sale_data
# Out:
#    prod_id  size_id  Year  qty
# 0     1101       12  2013    8
# 1     1101       12  2012   79
# 2     1107      233  2011  863
# 3     1107      233  2006   73
# 4    11071       21  2013    1
# 5     1102      888  2015    0
# 6    11022      888  2016  756
# 7     2200      144  2017    0
# 8     3300      277  2016   64
# 9      999      477  2014    7
# 10      44      177  2015    8
# 11      66     2888  2017    6

# %%
sale_data.set_index(['prod_id','size_id'],inplace = True)

# %%
sale_data
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12       2013    8
#         12       2012   79
# 1107    233      2011  863
#         233      2006   73
# 11071   21       2013    1
# 1102    888      2015    0
# 11022   888      2016  756
# 2200    144      2017    0
# 3300    277      2016   64
# 999     477      2014    7
# 44      177      2015    8
# 66      2888     2017    6

# %%
sale_data
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12       2013    8
#         12       2012   79
# 1107    233      2011  863
#         233      2006   73
# 11071   21       2013    1
# 1102    888      2015    0
# 11022   888      2016  756
# 2200    144      2017    0
# 3300    277      2016   64
# 999     477      2014    7
# 44      177      2015    8
# 66      2888     2017    6

# %%
sale_data_1 = sale_data['qty'].sum(level = ['prod_id','size_id']).reset_index().rename(columns = {'qty':'sumaa'})
sale_data_1

lll = sale_data_1.set_index(['prod_id','size_id']).reset_index(['prod_id','size_id'])

# %%
sale_data_1
# Out:
#   prod_id  size_id  sumaa
# 0    1101       12     87
# 1    1107      233    936
# 2   11071       21      1
# 3    1102      888      0
# 4   11022      888    756
# 5    2200      144      0
# 6    3300      277     64
# 7     999      477      7
# 8      44      177      8
# 9      66     2888      6

# %%
lll
# Out:
#   prod_id  size_id  sumaa
# 0    1101       12     87
# 1    1107      233    936
# 2   11071       21      1
# 3    1102      888      0
# 4   11022      888    756
# 5    2200      144      0
# 6    3300      277     64
# 7     999      477      7
# 8      44      177      8
# 9      66     2888      6

# %%
lll.reset_index()
lll
# Out:
#   prod_id  size_id  sumaa
# 0    1101       12     87
# 1    1107      233    936
# 2   11071       21      1
# 3    1102      888      0
# 4   11022      888    756
# 5    2200      144      0
# 6    3300      277     64
# 7     999      477      7
# 8      44      177      8
# 9      66     2888      6

# %%
sale_data['Year']
# Out:
# prod_id  size_id
# 1101     12         2013
#          12         2012
# 1107     233        2011
#          233        2006
# 11071    21         2013
# 1102     888        2015
# 11022    888        2016
# 2200     144        2017
# 3300     277        2016
# 999      477        2014
# 44       177        2015
# 66       2888       2017
# Name: Year, dtype: int64

# %%
pd.to_datetime(sale_data['Year'])
# Out:
# prod_id  size_id
# 1101     12        1970-01-01 00:00:00.000002013
#          12        1970-01-01 00:00:00.000002012
# 1107     233       1970-01-01 00:00:00.000002011
#          233       1970-01-01 00:00:00.000002006
# 11071    21        1970-01-01 00:00:00.000002013
# 1102     888       1970-01-01 00:00:00.000002015
# 11022    888       1970-01-01 00:00:00.000002016
# 2200     144       1970-01-01 00:00:00.000002017
# 3300     277       1970-01-01 00:00:00.000002016
# 999      477       1970-01-01 00:00:00.000002014
# 44       177       1970-01-01 00:00:00.000002015
# 66       2888      1970-01-01 00:00:00.000002017
# Name: Year, dtype: datetime64[ns]

# %%
sale_data
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12       2013    8
#         12       2012   79
# 1107    233      2011  863
#         233      2006   73
# 11071   21       2013    1
# 1102    888      2015    0
# 11022   888      2016  756
# 2200    144      2017    0
# 3300    277      2016   64
# 999     477      2014    7
# 44      177      2015    8
# 66      2888     2017    6

# %%
salemax = sale_data.groupby(['prod_id','size_id'])
salemax['qty'].max().reset_index().rename(columns={'qty':'max'})
# Out:
#   prod_id  size_id  max
# 0    1101       12   79
# 1    1102      888    0
# 2   11022      888  756
# 3    1107      233  863
# 4   11071       21    1
# 5    2200      144    0
# 6    3300      277   64
# 7      44      177    8
# 8      66     2888    6
# 9     999      477    7

# %%
col_group = ['prod_id','size_id']
salemax = sale_data.groupby(col_group)['qty'].max().reset_index()

# %%
salemax
# Out:
#   prod_id  size_id  qty
# 0    1101       12   79
# 1    1102      888    0
# 2   11022      888  756
# 3    1107      233  863
# 4   11071       21    1
# 5    2200      144    0
# 6    3300      277   64
# 7      44      177    8
# 8      66     2888    6
# 9     999      477    7

# %%
salemax.set_index(['prod_id','size_id'],inplace= True)
salemax
# Out:
#                  qty
# prod_id size_id
# 1101    12        79
# 1102    888        0
# 11022   888      756
# 1107    233      863
# 11071   21         1
# 2200    144        0
# 3300    277       64
# 44      177        8
# 66      2888       6
# 999     477        7

# %%
salemax.loc[salemax['qty']>0].index
# Out:
# MultiIndex(levels=[['1101', '1102', '11022', '1107', '11071', '2200', '3300', '44', '66', '999'], [12, 21, 144, 177, 233, 277, 477, 888, 2888]],
#            codes=[[0, 2, 3, 4, 6, 7, 8, 9], [0, 7, 4, 1, 5, 3, 8, 6]],
#            names=['prod_id', 'size_id'])

# %%
salemax
# Out:
#                  qty
# prod_id size_id
# 1101    12        79
# 1102    888        0
# 11022   888      756
# 1107    233      863
# 11071   21         1
# 2200    144        0
# 3300    277       64
# 44      177        8
# 66      2888       6
# 999     477        7

# %%
qq = salemax.reset_index().groupby(['prod_id','size_id']).count()
qq.columns = ['count']
qq
# Out:
#                  count
# prod_id size_id
# 1101    12           1
# 1102    888          1
# 11022   888          1
# 1107    233          1
# 11071   21           1
# 2200    144          1
# 3300    277          1
# 44      177          1
# 66      2888         1
# 999     477          1

# %% [markdown]
# # sort_index()

# %%
frame=pd.DataFrame(np.arange(12).reshape((4,3)),columns=['c','a','b'],index=['D','B','C','A'])

# %%
frame
# Out:
#    c   a   b
# D  0   1   2
# B  3   4   5
# C  6   7   8
# A  9  10  11

# %%
frame.sort_index(inplace =True)

# %%
frame
# Out:
#    c   a   b
# A  9  10  11
# B  3   4   5
# C  6   7   8
# D  0   1   2

# %%
frame_copy = frame.copy()

# %%
frame_copy
# Out:
#    c   a   b
# A  9  10  11
# B  3   4   5
# C  6   7   8
# D  0   1   2

# %%
frame_copy['col'] = 1
frame_copy.set_index('col', inplace= True)
frame_copy
# Out:
#      c   a   b
# col
# 1    9  10  11
# 1    3   4   5
# 1    6   7   8
# 1    0   1   2

# %% [markdown]
# # append

# %%
df1 = pd.DataFrame([[1, 2,7,7], [3, 4,8,8]], columns=list('ABCD'))
df1['is'] = 0
df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'))
df2['is'] =1

# %%
df1
# Out:
#    A  B  C  D  is
# 0  1  2  7  7   0
# 1  3  4  8  8   0

# %%
df2
# Out:
#    A  B  is
# 0  5  6   1
# 1  7  8   1

# %%
org = df1.append(df2, sort = False)

# %% [raw]
# org

# %%
org['col'] =1

# %%
org
# Out:
#    A  B    C    D  is  col
# 0  1  2  7.0  7.0   0    1
# 1  3  4  8.0  8.0   0    1
# 0  5  6  NaN  NaN   1    1
# 1  7  8  NaN  NaN   1    1

# %%
org.fillna({'D':0})
# Out:
#    A  B    C    D  is  col
# 0  1  2  7.0  7.0   0    1
# 1  3  4  8.0  8.0   0    1
# 0  5  6  NaN  0.0   1    1
# 1  7  8  NaN  0.0   1    1

# %%
week_no = pd.DataFrame(list(range(-4,0)),columns = ['week_no'])
week_no
# Out:
#    week_no
# 0       -4
# 1       -3
# 2       -2
# 3       -1

# %%
week_no['col_on'] = 1

# %%
week_no
# Out:
#    week_no  col_on
# 0       -4       1
# 1       -3       1
# 2       -2       1
# 3       -1       1

# %%
week_no.set_index('col_on',inplace =True)

# %%
week_no
# Out:
#         week_no
# col_on
# 1            -4
# 1            -3
# 1            -2
# 1            -1

# %%
sale_data
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12       2013    8
#         12       2012   79
# 1107    233      2011  863
#         233      2006   73
# 11071   21       2013    1
# 1102    888      2015    0
# 11022   888      2016  756
# 2200    144      2017    0
# 3300    277      2016   64
# 999     477      2014    7
# 44      177      2015    8
# 66      2888     2017    6

# %%
qs = sale_data.reset_index().groupby(['prod_id','size_id']).count()

# %%
qs
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12          2    2
# 1102    888         1    1
# 11022   888         1    1
# 1107    233         2    2
# 11071   21          1    1
# 2200    144         1    1
# 3300    277         1    1
# 44      177         1    1
# 66      2888        1    1
# 999     477         1    1

# %% [markdown]
# # drop

# %%
sale_data.drop(['Year'],axis=1)
# Out:
#                  qty
# prod_id size_id
# 1101    12         8
#         12        79
# 1107    233      863
#         233       73
# 11071   21         1
# 1102    888        0
# 11022   888      756
# 2200    144        0
# 3300    277       64
# 999     477        7
# 44      177        8
# 66      2888       6

# %%
sale_data
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12       2013    8
#         12       2012   79
# 1107    233      2011  863
#         233      2006   73
# 11071   21       2013    1
# 1102    888      2015    0
# 11022   888      2016  756
# 2200    144      2017    0
# 3300    277      2016   64
# 999     477      2014    7
# 44      177      2015    8
# 66      2888     2017    6

# %%
sale_data.reset_index().drop([4])
# Out:
#    prod_id  size_id  Year  qty
# 0     1101       12  2013    8
# 1     1101       12  2012   79
# 2     1107      233  2011  863
# 3     1107      233  2006   73
# 5     1102      888  2015    0
# 6    11022      888  2016  756
# 7     2200      144  2017    0
# 8     3300      277  2016   64
# 9      999      477  2014    7
# 10      44      177  2015    8
# 11      66     2888  2017    6

# %%
sale_data
# Out:
#                  Year  qty
# prod_id size_id
# 1101    12       2013    8
#         12       2012   79
# 1107    233      2011  863
#         233      2006   73
# 11071   21       2013    1
# 1102    888      2015    0
# 11022   888      2016  756
# 2200    144      2017    0
# 3300    277      2016   64
# 999     477      2014    7
# 44      177      2015    8
# 66      2888     2017    6

# %%
sale_copy = sale_data

# %% [markdown]
# # 删除列 drop

# %%
sale_data.drop(columns = ['qty'],axis = 1,inplace =True)

# %%
sale_data
# Out:
#                  Year
# prod_id size_id
# 1101    12       2013
#         12       2012
# 1107    233      2011
#         233      2006
# 11071   21       2013
# 1102    888      2015
# 11022   888      2016
# 2200    144      2017
# 3300    277      2016
# 999     477      2014
# 44      177      2015
# 66      2888     2017

# %% [markdown]
# # rename_axis

# %%
sale_data.rename_axis(['A','b'])
# Out:
#             Year
# A     b
# 1101  12    2013
#       12    2012
# 1107  233   2011
#       233   2006
# 11071 21    2013
# 1102  888   2015
# 11022 888   2016
# 2200  144   2017
# 3300  277   2016
# 999   477   2014
# 44    177   2015
# 66    2888  2017

# %%
sale_data.reset_index(inplace = True)

# %% [markdown]
# # sum(axis=1)

# %%
sale_data['sum'] = sale_data[['size_id','Year']].sum(axis=1)
sale_data
# Out:
#    prod_id  size_id  Year   sum
# 0     1101       12  2013  2025
# 1     1101       12  2012  2024
# 2     1107      233  2011  2244
# 3     1107      233  2006  2239
# 4    11071       21  2013  2034
# 5     1102      888  2015  2903
# 6    11022      888  2016  2904
# 7     2200      144  2017  2161
# 8     3300      277  2016  2293
# 9      999      477  2014  2491
# 10      44      177  2015  2192
# 11      66     2888  2017  4905

# %% [markdown]
# # datetime

# %%
import datetime as dt

# %%
date_dec = dt.datetime.now().date()

# %%
date_dec
# Out:
# datetime.date(2019, 4, 9)

# %%
date_cut = pd.to_datetime(date_dec - dt.timedelta(days= 7))

# %%
date_cut
# Out:
# Timestamp('2019-04-02 00:00:00')

# %% [markdown]
# # 时间间隔对象

# %%
testtime = dt.timedelta(days = 7)

# %%
testtime
# Out:
# datetime.timedelta(7)

# %%
kk3 = pd.to_datetime('2030-5-10')
kk3
# Out:
# Timestamp('2030-05-10 00:00:00')

# %%
kk3 > date_cut
# Out:
# True

# %%
df
# Out:
#           A         B         C         D     sumCD      test
# a  0.000000 -0.512248 -0.369929  0.972781  0.602851 -3.633527
# b  0.000000  0.141740  0.163930  0.000000  0.163930 -3.633527
# c -0.764427 -0.792664  0.061916  1.936459  1.998375 -3.633527
# d -0.186104 -1.432157  0.863699  1.670368  2.534067 -3.633527
# e -1.132617  0.395906 -0.325871  0.036250 -0.289621 -3.633527
# f  0.000000 -0.337952  0.374892  0.574721  0.949613 -3.633527
# g -0.695758  1.228083  0.964450  0.000000  0.964450 -3.633527
# z -0.854621 -0.912551 -0.369441  0.000000 -0.369441 -3.633527

# %%
sale_copy
# Out:
#    prod_id  size_id  Year   sum
# 0     1101       12  2013  2025
# 1     1101       12  2012  2024
# 2     1107      233  2011  2244
# 3     1107      233  2006  2239
# 4    11071       21  2013  2034
# 5     1102      888  2015  2903
# 6    11022      888  2016  2904
# 7     2200      144  2017  2161
# 8     3300      277  2016  2293
# 9      999      477  2014  2491
# 10      44      177  2015  2192
# 11      66     2888  2017  4905

# %%
sale_copy.set_index(['prod_id','size_id']).groupby(['prod_id','size_id']).sum()
# Out:
#                  Year   sum
# prod_id size_id
# 1101    12       4025  4049
# 1102    888      2015  2903
# 11022   888      2016  2904
# 1107    233      4017  4483
# 11071   21       2013  2034
# 2200    144      2017  2161
# 3300    277      2016  2293
# 44      177      2015  2192
# 66      2888     2017  4905
# 999     477      2014  2491

# %%
sale_copy
# Out:
#    prod_id  size_id  Year   sum
# 0     1101       12  2013  2025
# 1     1101       12  2012  2024
# 2     1107      233  2011  2244
# 3     1107      233  2006  2239
# 4    11071       21  2013  2034
# 5     1102      888  2015  2903
# 6    11022      888  2016  2904
# 7     2200      144  2017  2161
# 8     3300      277  2016  2293
# 9      999      477  2014  2491
# 10      44      177  2015  2192
# 11      66     2888  2017  4905

# %%
sale_copy.index.drop_duplicates()
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
# sale_copy['size_id'].max(level = [])

# %%
sale_copy
# Out:
#    prod_id  size_id  Year   sum
# 0     1101       12  2013  2025
# 1     1101       12  2012  2024
# 2     1107      233  2011  2244
# 3     1107      233  2006  2239
# 4    11071       21  2013  2034
# 5     1102      888  2015  2903
# 6    11022      888  2016  2904
# 7     2200      144  2017  2161
# 8     3300      277  2016  2293
# 9      999      477  2014  2491
# 10      44      177  2015  2192
# 11      66     2888  2017  4905

# %%
sale_copy['col']=1

# %%
sale_copy_1 = sale_copy

# %%
p1 = sale_copy_1.reset_index('col', inplace = True)
p1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-2db4e4dea97d> in <module>
# ----> 1 p1 = sale_copy_1.reset_index('col', inplace = True)
#       2 p1
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4392             if not isinstance(level, (tuple, list)):
#    4393                 level = [level]
# -> 4394             level = [self.index._get_level_number(lev) for lev in level]
#    4395             if len(level) < self.index.nlevels:
#    4396                 new_index = self.index.droplevel(level)
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4392             if not isinstance(level, (tuple, list)):
#    4393                 level = [level]
# -> 4394             level = [self.index._get_level_number(lev) for lev in level]
#    4395             if len(level) < self.index.nlevels:
#    4396                 new_index = self.index.droplevel(level)
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1425
#    1426     def _get_level_number(self, level):
# -> 1427         self._validate_index_level(level)
#    1428         return 0
#    1429
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1422         elif level != self.name:
#    1423             raise KeyError('Level %s must be same as name (%s)' %
# -> 1424                            (level, self.name))
#    1425
#    1426     def _get_level_number(self, level):
#
# KeyError: 'Level col must be same as name (None)'

# %%
p = sale_copy.reset_index('col', inplace = True)
p
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-0bf05b5365d6> in <module>
# ----> 1 p = sale_copy.reset_index('col', inplace = True)
#       2 p
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4392             if not isinstance(level, (tuple, list)):
#    4393                 level = [level]
# -> 4394             level = [self.index._get_level_number(lev) for lev in level]
#    4395             if len(level) < self.index.nlevels:
#    4396                 new_index = self.index.droplevel(level)
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4392             if not isinstance(level, (tuple, list)):
#    4393                 level = [level]
# -> 4394             level = [self.index._get_level_number(lev) for lev in level]
#    4395             if len(level) < self.index.nlevels:
#    4396                 new_index = self.index.droplevel(level)
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1425
#    1426     def _get_level_number(self, level):
# -> 1427         self._validate_index_level(level)
#    1428         return 0
#    1429
#
# ~\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1422         elif level != self.name:
#    1423             raise KeyError('Level %s must be same as name (%s)' %
# -> 1424                            (level, self.name))
#    1425
#    1426     def _get_level_number(self, level):
#
# KeyError: 'Level col must be same as name (None)'

# %%
p1.join(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-01863164214e> in <module>
# ----> 1 p1.join(p)
#
# NameError: name 'p1' is not defined

# %%
sale_copy
# Out:
#    prod_id  size_id  Year   sum  col
# 0     1101       12  2013  2025    1
# 1     1101       12  2012  2024    1
# 2     1107      233  2011  2244    1
# 3     1107      233  2006  2239    1
# 4    11071       21  2013  2034    1
# 5     1102      888  2015  2903    1
# 6    11022      888  2016  2904    1
# 7     2200      144  2017  2161    1
# 8     3300      277  2016  2293    1
# 9      999      477  2014  2491    1
# 10      44      177  2015  2192    1
# 11      66     2888  2017  4905    1

# %%
import numpy as np
sale_copy['we'] = sale_copy['sum'].map(lambda x: 1/(  1 + np.exp(-10 * (x+1))))

# %%
sale_copy
# Out:
#    prod_id  size_id  Year   sum  col   we
# 0     1101       12  2013  2025    1  1.0
# 1     1101       12  2012  2024    1  1.0
# 2     1107      233  2011  2244    1  1.0
# 3     1107      233  2006  2239    1  1.0
# 4    11071       21  2013  2034    1  1.0
# 5     1102      888  2015  2903    1  1.0
# 6    11022      888  2016  2904    1  1.0
# 7     2200      144  2017  2161    1  1.0
# 8     3300      277  2016  2293    1  1.0
# 9      999      477  2014  2491    1  1.0
# 10      44      177  2015  2192    1  1.0
# 11      66     2888  2017  4905    1  1.0

# %%
x =lambda x: 1/(1 + np.exp(-10 * (x+1)))

# %%
x
# Out:
# <function __main__.<lambda>(x)>

# %%
sale_data
# Out:
#    prod_id  size_id  Year   sum  col   we
# 0     1101       12  2013  2025    1  1.0
# 1     1101       12  2012  2024    1  1.0
# 2     1107      233  2011  2244    1  1.0
# 3     1107      233  2006  2239    1  1.0
# 4    11071       21  2013  2034    1  1.0
# 5     1102      888  2015  2903    1  1.0
# 6    11022      888  2016  2904    1  1.0
# 7     2200      144  2017  2161    1  1.0
# 8     3300      277  2016  2293    1  1.0
# 9      999      477  2014  2491    1  1.0
# 10      44      177  2015  2192    1  1.0
# 11      66     2888  2017  4905    1  1.0

# %% [markdown]
# # prod 返回请求轴的乘积

# %%
sale_data[['sum','we']].prod(axis=1)
# Out:
# 0     2025.0
# 1     2024.0
# 2     2244.0
# 3     2239.0
# 4     2034.0
# 5     2903.0
# 6     2904.0
# 7     2161.0
# 8     2293.0
# 9     2491.0
# 10    2192.0
# 11    4905.0
# dtype: float64

# %%
#copy

# %%
sale_data
# Out:
#    prod_id  size_id  Year   sum  col   we
# 0     1101       12  2013  2025    1  1.0
# 1     1101       12  2012  2024    1  1.0
# 2     1107      233  2011  2244    1  1.0
# 3     1107      233  2006  2239    1  1.0
# 4    11071       21  2013  2034    1  1.0
# 5     1102      888  2015  2903    1  1.0
# 6    11022      888  2016  2904    1  1.0
# 7     2200      144  2017  2161    1  1.0
# 8     3300      277  2016  2293    1  1.0
# 9      999      477  2014  2491    1  1.0
# 10      44      177  2015  2192    1  1.0
# 11      66     2888  2017  4905    1  1.0

# %%
sale_pp = sale_data.loc[sale_data['Year'] == 2013, ['prod_id','size_id']].copy()

# %%
sale_pp
# Out:
#   prod_id  size_id
# 0    1101       12
# 4   11071       21

# %%
cols_grp2 = ['prod_id', 'color_id', 'mng_reg_id', 'size']

# %%
cols_grp2[2]
# Out:
# 'mng_reg_id'

# %%
sale_data
# Out:
#    prod_id  size_id  Year   sum  col   we
# 0     1101       12  2013  2025    1  1.0
# 1     1101       12  2012  2024    1  1.0
# 2     1107      233  2011  2244    1  1.0
# 3     1107      233  2006  2239    1  1.0
# 4    11071       21  2013  2034    1  1.0
# 5     1102      888  2015  2903    1  1.0
# 6    11022      888  2016  2904    1  1.0
# 7     2200      144  2017  2161    1  1.0
# 8     3300      277  2016  2293    1  1.0
# 9      999      477  2014  2491    1  1.0
# 10      44      177  2015  2192    1  1.0
# 11      66     2888  2017  4905    1  1.0

# %%
sale_data.set_index(['prod_id','size_id'], inplace = True)

# %%
sale_data
# Out:
#                  Year   sum  col   we
# prod_id size_id
# 1101    12       2013  2025    1  1.0
#         12       2012  2024    1  1.0
# 1107    233      2011  2244    1  1.0
#         233      2006  2239    1  1.0
# 11071   21       2013  2034    1  1.0
# 1102    888      2015  2903    1  1.0
# 11022   888      2016  2904    1  1.0
# 2200    144      2017  2161    1  1.0
# 3300    277      2016  2293    1  1.0
# 999     477      2014  2491    1  1.0
# 44      177      2015  2192    1  1.0
# 66      2888     2017  4905    1  1.0

# %%
sale_data['sum'].max(level = ['prod_id','size_id'])
# Out:
# prod_id  size_id
# 1101     12         2025
# 1107     233        2244
# 11071    21         2034
# 1102     888        2903
# 11022    888        2904
# 2200     144        2161
# 3300     277        2293
# 999      477        2491
# 44       177        2192
# 66       2888       4905
# Name: sum, dtype: int64

# %%
sale_data['sum'].max()
# Out:
# 4905

# %%
sale_data
# Out:
#                  Year   sum  col   we
# prod_id size_id
# 1101    12       2013  2025    1  1.0
#         12       2012  2024    1  1.0
# 1107    233      2011  2244    1  1.0
#         233      2006  2239    1  1.0
# 11071   21       2013  2034    1  1.0
# 1102    888      2015  2903    1  1.0
# 11022   888      2016  2904    1  1.0
# 2200    144      2017  2161    1  1.0
# 3300    277      2016  2293    1  1.0
# 999     477      2014  2491    1  1.0
# 44      177      2015  2192    1  1.0
# 66      2888     2017  4905    1  1.0

# %%
sale_data['sum'].mean(level = ['prod_id','size_id'])
# Out:
# prod_id  size_id
# 1101     12         2024.5
# 1107     233        2241.5
# 11071    21         2034.0
# 1102     888        2903.0
# 11022    888        2904.0
# 2200     144        2161.0
# 3300     277        2293.0
# 999      477        2491.0
# 44       177        2192.0
# 66       2888       4905.0
# Name: sum, dtype: float64

# %%
sale_data[['col','sum']].prod(axis =1)
# Out:
# prod_id  size_id
# 1101     12         2025
#          12         2024
# 1107     233        2244
#          233        2239
# 11071    21         2034
# 1102     888        2903
# 11022    888        2904
# 2200     144        2161
# 3300     277        2293
# 999      477        2491
# 44       177        2192
# 66       2888       4905
# dtype: int64

# %%
sale_data
# Out:
#                  Year   sum  col   we
# prod_id size_id
# 1101    12       2013  2025    1  1.0
#         12       2012  2024    1  1.0
# 1107    233      2011  2244    1  1.0
#         233      2006  2239    1  1.0
# 11071   21       2013  2034    1  1.0
# 1102    888      2015  2903    1  1.0
# 11022   888      2016  2904    1  1.0
# 2200    144      2017  2161    1  1.0
# 3300    277      2016  2293    1  1.0
# 999     477      2014  2491    1  1.0
# 44      177      2015  2192    1  1.0
# 66      2888     2017  4905    1  1.0

# %%
sale_data['col'].reset_index(['prod_id','size_id'])
# Out:
#    prod_id  size_id  col
# 0     1101       12    1
# 1     1101       12    1
# 2     1107      233    1
# 3     1107      233    1
# 4    11071       21    1
# 5     1102      888    1
# 6    11022      888    1
# 7     2200      144    1
# 8     3300      277    1
# 9      999      477    1
# 10      44      177    1
# 11      66     2888    1

# %%
sale_data
# Out:
#                  Year   sum  col   we
# prod_id size_id
# 1101    12       2013  2025    1  1.0
#         12       2012  2024    1  1.0
# 1107    233      2011  2244    1  1.0
#         233      2006  2239    1  1.0
# 11071   21       2013  2034    1  1.0
# 1102    888      2015  2903    1  1.0
# 11022   888      2016  2904    1  1.0
# 2200    144      2017  2161    1  1.0
# 3300    277      2016  2293    1  1.0
# 999     477      2014  2491    1  1.0
# 44      177      2015  2192    1  1.0
# 66      2888     2017  4905    1  1.0

# %%
sale_data['yes'] = sale_data[['col','we']].sum(axis=1)

# %%
sale_data
# Out:
#                  Year   sum  col   we  yes
# prod_id size_id
# 1101    12       2013  2025    1  1.0  2.0
#         12       2012  2024    1  1.0  2.0
# 1107    233      2011  2244    1  1.0  2.0
#         233      2006  2239    1  1.0  2.0
# 11071   21       2013  2034    1  1.0  2.0
# 1102    888      2015  2903    1  1.0  2.0
# 11022   888      2016  2904    1  1.0  2.0
# 2200    144      2017  2161    1  1.0  2.0
# 3300    277      2016  2293    1  1.0  2.0
# 999     477      2014  2491    1  1.0  2.0
# 44      177      2015  2192    1  1.0  2.0
# 66      2888     2017  4905    1  1.0  2.0

# %%
sale_data.loc[sale_data['sum']>sale_data['col'], 'we'] =  sale_data.loc[sale_data['sum']>sale_data['col'],'sum']
# Out:
# C:\Users\liuju\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\IPython\core\interactiveshell.py:2848: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)

# %%
sale_data
# Out:
#                  Year   sum  col    we  yes
# prod_id size_id
# 1101    12       2013  2025    1  2025  2.0
#         12       2012  2024    1  2024  2.0
# 1107    233      2011  2244    1  2244  2.0
#         233      2006  2239    1  2239  2.0
# 11071   21       2013  2034    1  2034  2.0
# 1102    888      2015  2903    1  2903  2.0
# 11022   888      2016  2904    1  2904  2.0
# 2200    144      2017  2161    1  2161  2.0
# 3300    277      2016  2293    1  2293  2.0
# 999     477      2014  2491    1  2491  2.0
# 44      177      2015  2192    1  2192  2.0
# 66      2888     2017  4905    1  4905  2.0

# %% [markdown]
# # multiprocessing

# %%
import multiprocessing
from multiprocessing import Pool, cpu_count

# %%
cpu_count()
# Out:
# 6

# %% [markdown]
# # map(func, iterable[, chunksize=None])
# # Pool类中的map方法，与内置的map函数用法行为基本一致，它会使进程阻塞直到返回结果。
# # 注意，虽然第二个参数是一个迭代器，但在实际使用中，必须在整个队列都就绪后，程序才会运行子进程。

# %%
sale_data
# Out:
#                  Year   sum  col    we  yes
# prod_id size_id
# 1101    12       2013  2025    1  2025  2.0
#         12       2012  2024    1  2024  2.0
# 1107    233      2011  2244    1  2244  2.0
#         233      2006  2239    1  2239  2.0
# 11071   21       2013  2034    1  2034  2.0
# 1102    888      2015  2903    1  2903  2.0
# 11022   888      2016  2904    1  2904  2.0
# 2200    144      2017  2161    1  2161  2.0
# 3300    277      2016  2293    1  2293  2.0
# 999     477      2014  2491    1  2491  2.0
# 44      177      2015  2192    1  2192  2.0
# 66      2888     2017  4905    1  4905  2.0

# %%
sale_data.index.get_level_values(level = 'size_id')
# Out:
# Int64Index([12, 12, 233, 233, 21, 888, 888, 144, 277, 477, 177, 2888], dtype='int64', name='size_id')

# %% [markdown]
# # get_level_values uique()

# %%
sale_data.index.get_level_values(level = 'size_id').unique()
# Out:
# Int64Index([12, 233, 21, 888, 144, 277, 477, 177, 2888], dtype='int64', name='size_id')

# %%
gg = sale_data.index.get_level_values(level = 'size_id').unique()

# %%
gg
# Out:
# Int64Index([12, 233, 21, 888, 144, 277, 477, 177, 2888], dtype='int64', name='size_id')

# %%
gg.shape[0]
# Out:
# 9

# %%
import math
skc_num_sum = 30
skc_num_grp = 30
range(math.ceil(skc_num_sum / skc_num_grp))
# Out:
# range(0, 1)

# %% [markdown]
# # at

# %%
sale_data.reset_index().at[0,'we']
# Out:
# 2025

# %%
sale_data.reset_index(inplace = True)

# %%
sale_data.set_index(['prod_id','size_id'], inplace = True)

# %%
sale_data
# Out:
#                  Year   sum  col    we  yes
# prod_id size_id
# 1101    12       2013  2025    1  2025  2.0
#         12       2012  2024    1  2024  2.0
# 1107    233      2011  2244    1  2244  2.0
#         233      2006  2239    1  2239  2.0
# 11071   21       2013  2034    1  2034  2.0
# 1102    888      2015  2903    1  2903  2.0
# 11022   888      2016  2904    1  2904  2.0
# 2200    144      2017  2161    1  2161  2.0
# 3300    277      2016  2293    1  2293  2.0
# 999     477      2014  2491    1  2491  2.0
# 44      177      2015  2192    1  2192  2.0
# 66      2888     2017  4905    1  4905  2.0

# %%
# sale_data.at[('2200','144'), 'we']

# %%
cols_mov = ['prod_id', 'color_id', 'size', 'org_send_id', 'org_rec_id']

    # Moving records
q = pd.DataFrame(columns=cols_mov + ['quant_mov']).set_index(cols_mov)

# %%
q
# Out:
# Empty DataFrame
# Columns: [quant_mov]
# Index: []

# %%
cols_stc = ['prod_id', 'color_id', 'size', 'org_id']

# %%
cols_stc[-2]
# Out:
# 'size'

# %%
sale_data.reset_index()
# Out:
#    prod_id  size_id  Year   sum  col    we  yes
# 0     1101       12  2013  2025    1  2025  2.0
# 1     1101       12  2012  2024    1  2024  2.0
# 2     1107      233  2011  2244    1  2244  2.0
# 3     1107      233  2006  2239    1  2239  2.0
# 4    11071       21  2013  2034    1  2034  2.0
# 5     1102      888  2015  2903    1  2903  2.0
# 6    11022      888  2016  2904    1  2904  2.0
# 7     2200      144  2017  2161    1  2161  2.0
# 8     3300      277  2016  2293    1  2293  2.0
# 9      999      477  2014  2491    1  2491  2.0
# 10      44      177  2015  2192    1  2192  2.0
# 11      66     2888  2017  4905    1  4905  2.0

# %%
test0 = sale_data.index.get_level_values('size_id').unique()

# %%
mub=test0.shape[0]

# %%
mub
# Out:
# 9

# %%
grap = 3

# %% [markdown]
# # 分组 math.ceil

# %%
for i in range (math.ceil(mub/grap)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
sale_data
# Out:
#                  Year   sum  col    we  yes
# prod_id size_id
# 1101    12       2013  2025    1  2025  2.0
#         12       2012  2024    1  2024  2.0
# 1107    233      2011  2244    1  2244  2.0
#         233      2006  2239    1  2239  2.0
# 11071   21       2013  2034    1  2034  2.0
# 1102    888      2015  2903    1  2903  2.0
# 11022   888      2016  2904    1  2904  2.0
# 2200    144      2017  2161    1  2161  2.0
# 3300    277      2016  2293    1  2293  2.0
# 999     477      2014  2491    1  2491  2.0
# 44      177      2015  2192    1  2192  2.0
# 66      2888     2017  4905    1  4905  2.0

# %% [markdown]
# # dict sum( .values())

# %%
dict1 = {'a': 10, 'b': 2, 'c': 3}

# %%
dict1
# Out:
# {'a': 10, 'b': 2, 'c': 3}

# %%
sum(dict1.values())
# Out:
# 15
