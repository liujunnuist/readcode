# %%
from pyscipopt import Model,quicksum, multidict
import numpy as np
import pandas as pd
import openpyxl
import datetime as dt
import os

# %%
ospwd = os.getcwd()

# %%
data = pd.read_excel(ospwd+'\LiNingAllData.xlsx')

# %%
# data

# %%
clo_data = data[data['class_0'].isin(['服装'])]

# %%
# clo_data

# %%
#归一化

# %%
# test1 = clo_data.copy()

# %%
# test1

# %%
# test1copy = test1.groupby(['class_2','org_id'])['qty'].sum().reset_index()

# %%
# test1copy

# %%
# test1 = pd.merge(test1, test1copy.rename(columns= {'qty':'sum'}),how = "left")

# %%
# test1

# %%
# test1['sumqty_ratio'] = test1['qty']/test1['sum']

# %%
# test1

# %%
# test2 = test1.groupby(['class_2','org_id'])['qty'].sum().reset_index().rename(columns = {'qty':'org_sum'})

# %%
# test2

# %%
# test2copy= test2.groupby(['class_2'])['org_sum'].sum().reset_index().rename(columns = {'org_sum':'all_org_sum'})

# %%
# test2copy

# %%
# test2 = pd.merge(test2, test2copy,how = "left")

# %%
# test2 ['oneorg_ratio'] = test2['org_sum']/test2['all_org_sum']

# %%
# test2

# %%
test3 = clo_data.copy()

# %%
test3.set_index(['class_2', 'size'], inplace = True)

# %%
test3['qty_max'] = test3['qty'].max(level = ['class_2', 'size'])

# %%
test3['qty_min'] = test3['qty'].min(level = ['class_2', 'size'])

# %%
test3
# Out:
#              class_0        org_name   org_id  qty     ratio  qty_max  qty_min
# class_2 size
# 1201    3XL       服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000       10        0
#         4XL       服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000        0        0
#         L         服装  大连悦奥体育用品销售有限公司  A21089A    3  1.000000       52        3
#         M         服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000       20        0
#         S         服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000       12        0
#         XL        服装  大连悦奥体育用品销售有限公司  A21089A    2  0.666667       43        1
#         XS        服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000        0        0
#         XXL       服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000       17        0
#         XXS       服装  大连悦奥体育用品销售有限公司  A21089A    0  0.000000        0        0
#         3XL       服装  南京一动体育用品销售有限公司  A32028A    5  0.156250       10        0
#         4XL       服装  南京一动体育用品销售有限公司  A32028A    0  0.000000        0        0
#         L         服装  南京一动体育用品销售有限公司  A32028A   32  1.000000       52        3
#         M         服装  南京一动体育用品销售有限公司  A32028A   19  0.593750       20        0
#         S         服装  南京一动体育用品销售有限公司  A32028A    0  0.000000       12        0
#         XL        服装  南京一动体育用品销售有限公司  A32028A   31  0.968750       43        1
#         XS        服装  南京一动体育用品销售有限公司  A32028A    0  0.000000        0        0
#         XXL       服装  南京一动体育用品销售有限公司  A32028A    1  0.031250       17        0
#         XXS       服装  南京一动体育用品销售有限公司  A32028A    0  0.000000        0        0
#         3XL       服装    温州一动体育用品有限公司  A33116A    9  0.264706       10        0
#         4XL       服装    温州一动体育用品有限公司  A33116A    0  0.000000        0        0
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# 5      0.023810
# 6      0.000000
# 7      0.000000
# 8      0.000000
# 9      0.500000
# 10     0.000000
# 11     0.591837
# 12     0.950000
# 13     0.000000
# 14     0.714286
# 15     0.000000
# 16     0.058824
# 17     0.000000
# 18     0.900000
# 19     0.000000
# 20     0.510204
# 21     0.450000
# 22     0.750000
# 23     0.785714
# 24     0.000000
# 25     0.176471
# 26     0.000000
# 27     0.400000
# 28     0.000000
# 29     0.183673
# ...         ...
# 21704  0.000000
# 21705  0.090909
# 21706  0.000000
# 21707  0.000000
# 21708  0.000000
# 21709  0.000000
# 21710  0.000000
# 21711  0.000000
# 21712  0.076923
# 21713  0.000000
# 21714  0.510204
# 21715  0.583333
# 21716  0.400000
# 21717  0.365079
# 21718  0.000000
# 21719  0.090909
# 21720  0.000000
# 21721  0.000000
# 21722  0.000000
# 21723  0.000000
# 21724  0.000000
# 21725  0.000000
# 21726  0.000000
# 21727  0.000000
# 21728  0.367347
# 21729  0.125000
# 21730  0.000000
# 21731  0.206349
# 21732  0.000000
# 21733  0.393939
#
# [21734 rows x 8 columns]

# %%
# clo_data['min'] = clo_data.groupby(['class_2','org_id']).max()
# clo_data['min'] = clo_data['qty'].max(level = ['class_2','org_id'])
clo_data = clo_data.set_index(['class_2','org_id']).groupby(['class_2','org_id'])
#  org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']

# %%
# clo_data

# %%
# clo_data

# %%
# clo_data

# %%
# clo_data = clo_data[~clo_data['class_2'].isin([1201])]#删除1201

clo_data = in_test[~in_test['class_2'].isin([1201])]#删除1201

# %%
clo_data = clo_data.drop(['org_name','class_0'],axis=1).reset_index().drop('index',axis=1)

# %%
clo_data
# Out:
#                       class_2 size   org_id       qty     ratio       nor
# 0      2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL  A12001A  0.000000  0.000000  0.000000
# 1      2合1运动短裤（外-运动短裤/内-紧身长裤）    L  A12001A  0.000000  0.000000  0.000000
# 2      2合1运动短裤（外-运动短裤/内-紧身长裤）    M  A12001A  0.200000  1.000000  0.200000
# 3      2合1运动短裤（外-运动短裤/内-紧身长裤）    S  A12001A  0.000000  0.000000  0.000000
# 4      2合1运动短裤（外-运动短裤/内-紧身长裤）   XL  A12001A  0.500000  1.000000  0.500000
# 5      2合1运动短裤（外-运动短裤/内-紧身长裤）   XS  A12001A  0.000000  0.000000  0.000000
# 6      2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL  A12001A  1.000000  1.000000  1.000000
# 7      2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL  A21001A  0.000000  0.000000  0.000000
# 8      2合1运动短裤（外-运动短裤/内-紧身长裤）    L  A21001A  0.333333  1.000000  0.333333
# 9      2合1运动短裤（外-运动短裤/内-紧身长裤）    M  A21001A  0.200000  1.000000  0.200000
# 10     2合1运动短裤（外-运动短裤/内-紧身长裤）    S  A21001A  0.000000  0.000000  0.000000
# 11     2合1运动短裤（外-运动短裤/内-紧身长裤）   XL  A21001A  0.500000  1.000000  0.500000
# 12     2合1运动短裤（外-运动短裤/内-紧身长裤）   XS  A21001A  0.000000  0.000000  0.000000
# 13     2合1运动短裤（外-运动短裤/内-紧身长裤）  XX
# 21644                   长袖紧身衣  175  A65026A  0.000000  0.000000  0.000000
# 21645                   长袖紧身衣  3XL  A65026A  0.000000  0.000000  0.000000
# 21646                   长袖紧身衣  4XL  A65026A  0.000000  0.000000  0.000000
# 21647                   长袖紧身衣    L  A65026A  0.367347  1.000000  0.367347
# 21648                   长袖紧身衣    M  A65026A  0.125000  0.150000  0.125000
# 21649                   长袖紧身衣    S  A65026A  0.000000  0.000000  0.000000
# 21650                   长袖紧身衣   XL  A65026A  0.206349  0.650000  0.206349
# 21651                   长袖紧身衣   XS  A65026A  0.000000  0.000000  0.000000
# 21652                   长袖紧身衣  XXL  A65026A  0.393939  0.650000  0.393939
#
# [21653 rows x 6 columns]

# %%
class_list = clo_data['class_2'].drop_duplicates().reset_index().drop('index',axis =1)

# %%
class_arry = class_list['class_2'].values

# %%
# class_arry

# %%
len(class_arry) #删除了1201
# Out:
# 56

# %%
#获取尺码数量
# ospwd

# %%
BoxSize = pd.read_excel(ospwd+'/ClothesSize.xlsx')

# %%
BoxSize = BoxSize.dropna().reset_index().drop('index',axis=1).rename(columns = {'小类':'class_2','装箱量加权平均值':'minput'})

# %%
# BoxSize

# %%
BoxSize['minput'] = (BoxSize['minput']).apply(np.round)

# %%
# BoxSize

# %%
BoxSize_dict = BoxSize.set_index('class_2').T.to_dict()
# BoxSize_dict = BoxSize.set_index('class_2').to_dict()

# %%
# BoxSize_dict

# %%
def cal_clothes_model_1(data_result,minput):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    #     辅助等式  绝对值变量
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
    
    dfx = data_result.reset_index('org_id')
    # 决策变量X，每个尺码的件数
    for idx_s in dfx.index.unique(): #class size
        X[idx_s] = model.addVar(vtype="I", name="X")
#         print(idx_s,'**********',X[idx_s])
        
    
    # 设置
    df_s = data_result.reset_index(['size'])  #'class_2','org_id'

    for class_2, org_id in df_s.index.unique():
        #获取 class org ratio的ratio的最大值的尺码
        idx = (class_2, org_id)
        org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']
#         print(org_xmax)
#         print(org_xmax)
        print(idx,'最大尺码-------------', org_xmax)
        po =df_s.loc[[(class_2, org_id)]].reset_index().set_index(['class_2','org_id','size']) #?多了一个index
        for idx in po.index.unique(): #class org size
            myratio = po.loc[idx,'ratio']
            class_2, org_id, size = idx
#             print('-------------org',org_id)
#             print('-------------class size',class_2,size)
#             print('*'*10, idx)
#             print('diff:',diff[idx])
#             print('X[class_2, size]:',X[class_2, size])
#             print('X[class_2, org_max]:', X[class_2, org_max])
        
            model.addCons(diff[idx] == X[class_2, size] - myratio * X[class_2, org_xmax])
            model.addCons(diffabs[idx] >= diff[idx])
            model.addCons(diffabs[idx] >= -1 * diff[idx])
            model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
            model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])  
            
        
    df = data_result.reset_index('size')
#     df_1 = data_result.reset_index(['org_id','size'])
#     for idx in df_1.index.unique():
#         class_2 = idx
#         model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
    #设置目标
    for idx in data_result.index.unique():
#         if data_result.loc[idx,'qty']>0:
#         model.setObjective(diffabs[idx], clear = False)
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)

    
#     for idx in data_result.index.unique():
# #         print('idx*************',idx)
#         myratio = data_result.loc[idx,'ratio']
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio)

#         model.addCons(diffabs[idx] >= diff[idx])
#         model.addCons(diffabs[idx] >= -1 * diff[idx])
#         model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
#         model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
    
    # 约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 获取输出值
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
#         for idx11 in Xmax:
#             print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    return OutX

# %%
class_arry =class_arry[0:10]

# %%
class_arry
# Out:
# array(['2合1运动短裤（外-运动短裤/内-紧身长裤）', '三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)',
#        '三合一(内-短棉服/外-运动风衣)', '三合一(内-紧身运动长裤/外-运动短裤)', '中棉服', '中羽绒服', '九分卫裤',
#        '休闲外套', '休闲长裤', '卫裤'], dtype=object)

# %%
clo_data_test = clo_data.loc[clo_data['class_2']=='2合1运动短裤（外-运动短裤/内-紧身长裤）']
clo_data_test = clo_data_test.reset_index().drop('index',axis=1)

# test = clo_data_test.set_index(['class_2','org_id'])
# for idx in test.index.unique():

# %%
# clo_data_test

# %%
Clothes_result =pd.DataFrame(columns=('小类','尺码','尺码件数'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
#     print(clo_data_test)
    minput = BoxSize_dict[class_name]['minput']
    print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_1(clo_data_test,minput)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码']).reset_index()
    print(liningResult)
    Clothes_result = pd.concat([Clothes_result,liningResult],ignore_index=True)
# Out:
# boxsize ======================= 56.0
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A') 最大尺码------------- M
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A') 最大尺码------------- L
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A') 最大尺码------------- L
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A') 最大尺码------------- M
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A') 最大尺码------------- XL
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A') 最大尺码------------- L
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A') 最大尺码------------- L
# ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A') 最大尺码------------- M
#                        小类   尺码  尺码件数
# 0  2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL    56
# 1  2合1运动短裤（外-运动短裤/内-紧身长裤）    L     0
# 2  2合1运动短裤（外-运动短裤/内-紧身长裤）    M     0
# 3  2合1运动短裤（外-运动短裤/内-紧身长裤）    S     0
# 4  2合1运动短裤（外-运动短裤/内-紧身长裤）   XL     0
# 5  2合1运动短裤（外-运动短裤/内-紧身长裤）   XS     0
# 6  2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL     0
# boxsize ======================= 11.0
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A') 最大尺码------------- XXL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A') 最大尺码------------- 3XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A') 最大尺码------------- XL
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A') 最大尺码------------- L
# ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A') 最大尺码------------- XL
#                          小类   尺码  尺码件数
# 0   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  110    11
# 1   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  120     0
# 2   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  130     0
# 3   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  140     0
# 4   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  150     0
# 5   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  160     0
# 6   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  165     0
# 7   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  170     0
# 8   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  175     0
# 9   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  3XL     0
# 10  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  4XL     0
# 11  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    L     0
# 12  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    M     0
# 13  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    S     0
# 14  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XL     0
# 15  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XS     0
# 16  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  XXL     0
# boxsize ======================= 11.0
# ('三合一(内-短棉服/外-运动风衣)', 'A34037A') 最大尺码------------- L
# ('三合一(内-短棉服/外-运动风衣)', 'A35020A') 最大尺码------------- XL
#                    小类   尺码  尺码件数
# 0   三合一(内-短棉服/外-运动风衣)  110    11
# 1   三合一(内-短棉服/外-运动风衣)  120     0
# 2   三合一(内-短棉服/外-运动风衣)  130     0
# 3   三合一(内-短棉服/外-运动风衣)  140     0
# 4   三合一(内-短棉服/外-运动风衣)  150     0
# 5   三合一(内-短棉服/外-运动风衣)  160     0
# 6   三合一(内-短棉服/外-运动风衣)  165     0
# 7   三合一(内-短棉服/外-运动风衣)  170     0
# 8   三合一(内-短棉服/外-运动风衣)  175     0
# 9   三合一(内-短棉服/外-运动风衣)  3XL     0
# 10  三合一(内-短棉服/外-运动风衣)  4XL     0
# 11  三合一(内-短棉服/外-运动风衣)    L     0
# 12  三合一(内-短棉服/外-运动风衣)    M     0
# 13  三合一(内-短棉服/外-运动风衣)    S     0
# 14  三合一(内-短棉服/外-运动风衣)   XL     0
# 15  三合一(内-短棉服/外-运动风衣)   XS     0
# 16  三合一(内-短棉服/外-运动风衣)  XXL     0
# boxsize ======================= 11.0
# ('三合一(内-紧身运动长裤/外-运动短裤)', 'A35020A') 最大尺码------------- M
# ('三合一(内-紧身运动长裤/外-运动短裤)', 'A44001A') 最大尺码------------- M
# ('三合一(内-紧身运动长裤/外-运动短裤)', 'A44190A') 最大尺码------------- M
# ('三合一(内-紧身运动长裤/外-运动短裤)', 'A53013A') 最大尺码------------- L
#                      小类   尺码  尺码件数
# 0  三合一(内-紧身运动长裤/外-运动短裤)    L     0
# 1  三合一(内-紧身运动长裤/外-运动短裤)    M     0
# 2  三合一(内-紧身运动长裤/外-运动短裤)    S     0
# 3  三合一(内-紧身运动长裤/外-运动短裤)   XL     0
# 4  三合一(内-紧身运动长裤/外-运动短裤)   XS    11
# 5  三合一(内-紧身运动长裤/外-运动短裤)  XXL     0
# boxsize ======================= 11.0
# ('中棉服', 'A11001A') 最大尺码------------- XXL
# ('中棉服', 'A12001A') 最大尺码------------- XXL
# ('中棉服', 'A21001A') 最大尺码------------- XL
# ('中棉服', 'A21089A') 最大尺码------------- XXL
# ('中棉服', 'A23047A') 最大尺码------------- XL
# ('中棉服', 'A23048A') 最大尺码------------- XL
# ('中棉服', 'A31002A') 最大尺码------------- L
# ('中棉服', 'A32028A') 最大尺码------------- XL
# ('中棉服', 'A33064A') 最大尺码------------- XL
# ('中棉服', 'A33116A') 最大尺码------------- L
# ('中棉服', 'A34037A') 最大尺码------------- L
# ('中棉服', 'A35020A') 最大尺码------------- XXL
# ('中棉服', 'A37001A') 最大尺码------------- L
# ('中棉服', 'A41001A') 最大尺码------------- L
# ('中棉服', 'A42001A') 最大尺码------------- M
# ('中棉服', 'A43001A') 最大尺码------------- M
# ('中棉服', 'A44001A') 最大尺码------------- XL
# ('中棉服', 'A44190A') 最大尺码------------- XL
# ('中棉服', 'A45001A') 最大尺码------------- L
# ('中棉服', 'A51050A') 最大尺码------------- XL
# ('中棉服', 'A51210A') 最大尺码------------- M
# ('中棉服', 'A52035A') 最大尺码------------- M
# ('中棉服', 'A53013A') 最大尺码------------- M
# ('中棉服', 'A61010A') 最大尺码------------- M
# ('中棉服', 'A62039A') 最大尺码------------- L
# ('中棉服', 'A65026A') 最大尺码------------- L
#      小类   尺码  尺码件数
# 0   中棉服  100    11
# 1   中棉服  110     0
# 2   中棉服  115     0
# 3   中棉服  120     0
# 4   中棉服  125     0
# 5   中棉服  130     0
# 6   中棉服  135     0
# 7   中棉服  140     0
# 8   中棉服  145     0
# 9   中棉服  150     0
# 10  中棉服  155     0
# 11  中棉服  160     0
# 12  中棉服  165     0
# 13  中棉服  170     0
# 14  中棉服  175     0
# 15  中棉服  180     0
# 16  中棉服  185     0
# 17  中棉服  190     0
# 18  中棉服  195     0
# 19  中棉服  200     0
# 20  中棉服  205     0
# 21  中棉服  210     0
# 22  中棉服  215     0
# 23  中棉服  220     0
# 24  中棉服  3XL     0
# 25  中棉服  4XL     0
# 26  中棉服  5XL     0
# 27  中棉服   60     0
# 28  中棉服   70     0
# 29  中棉服   80     0
# 30  中棉服   90     0
# 31  中棉服    L     0
# 32  中棉服    M     0
# 33  中棉服    S     0
# 34  中棉服   XL     0
# 35  中棉服   XS     0
# 36  中棉服  XXL     0
# 37  中棉服  XXS     0
# boxsize ======================= 11.0
# ('中羽绒服', 'A11001A') 最大尺码------------- XL
# ('中羽绒服', 'A12001A') 最大尺码------------- XL
# ('中羽绒服', 'A21001A') 最大尺码------------- L
# ('中羽绒服', 'A21089A') 最大尺码------------- L
# ('中羽绒服', 'A23047A') 最大尺码------------- L
# ('中羽绒服', 'A23048A') 最大尺码------------- L
# ('中羽绒服', 'A31002A') 最大尺码------------- L
# ('中羽绒服', 'A32028A') 最大尺码------------- XL
# ('中羽绒服', 'A33064A') 最大尺码------------- L
# ('中羽绒服', 'A33115A') 最大尺码------------- XXL
# ('中羽绒服', 'A33116A') 最大尺码------------- M
# ('中羽绒服', 'A34037A') 最大尺码------------- L
# ('中羽绒服', 'A35020A') 最大尺码------------- L
# ('中羽绒服', 'A37001A') 最大尺码------------- L
# ('中羽绒服', 'A41001A') 最大尺码------------- XL
# ('中羽绒服', 'A42001A') 最大尺码------------- L
# ('中羽绒服', 'A43001A') 最大尺码------------- M
# ('中羽绒服', 'A44001A') 最大尺码------------- L
# ('中羽绒服', 'A44190A') 最大尺码------------- M
# ('中羽绒服', 'A45001A') 最大尺码------------- L
# ('中羽绒服', 'A51050A') 最大尺码------------- L
# ('中羽绒服', 'A51210A') 最大尺码------------- L
# ('中羽绒服', 'A52035A') 最大尺码------------- L
# ('中羽绒服', 'A53013A') 最大尺码------------- L
# ('中羽绒服', 'A61010A') 最大尺码------------- L
# ('中羽绒服', 'A62039A') 最大尺码------------- L
# ('中羽绒服', 'A65026A') 最大尺码------------- L
#       小类   尺码  尺码件数
# 0   中羽绒服  100    11
# 1   中羽绒服  110     0
# 2   中羽绒服  115     0
# 3   中羽绒服  120     0
# 4   中羽绒服  125     0
# 5   中羽绒服  130     0
# 6   中羽绒服  135     0
# 7   中羽绒服  140     0
# 8   中羽绒服  145     0
# 9   中羽绒服  150     0
# 10  中羽绒服  155     0
# 11  中羽绒服  160     0
# 12  中羽绒服  165     0
# 13  中羽绒服  170     0
# 14  中羽绒服  175     0
# 15  中羽绒服  180     0
# 16  中羽绒服  185     0
# 17  中羽绒服  190     0
# 18  中羽绒服  195     0
# 19  中羽绒服  200     0
# 20  中羽绒服  205     0
# 21  中羽绒服  210     0
# 22  中羽绒服  215     0
# 23  中羽绒服  220     0
# 24  中羽绒服  3XL     0
# 25  中羽绒服  4XL     0
# 26  中羽绒服  5XL     0
# 27  中羽绒服   60     0
# 28  中羽绒服  6XL     0
# 29  中羽绒服   70     0
# 30  中羽绒服  7XL     0
# 31  中羽绒服   80     0
# 32  中羽绒服  8XL     0
# 33  中羽绒服   90     0
# 34  中羽绒服    L     0
# 35  中羽绒服    M     0
# 36  中羽绒服    S     0
# 37  中羽绒服   XL     0
# 38  中羽绒服   XS     0
# 39  中羽绒服  XXL     0
# 40  中羽绒服  XXS     0
# boxsize ======================= 27.0
# ('九分卫裤', 'A11001A') 最大尺码------------- L
# ('九分卫裤', 'A12001A') 最大尺码------------- L
# ('九分卫裤', 'A21001A') 最大尺码------------- L
# ('九分卫裤', 'A23047A') 最大尺码------------- L
# ('九分卫裤', 'A23048A') 最大尺码------------- L
# ('九分卫裤', 'A31002A') 最大尺码------------- M
# ('九分卫裤', 'A32028A') 最大尺码------------- M
# ('九分卫裤', 'A33064A') 最大尺码------------- M
# ('九分卫裤', 'A33115A') 最大尺码------------- L
# ('九分卫裤', 'A33116A') 最大尺码------------- M
# ('九分卫裤', 'A34037A') 最大尺码------------- M
# ('九分卫裤', 'A35020A') 最大尺码------------- M
# ('九分卫裤', 'A37001A') 最大尺码------------- XL
# ('九分卫裤', 'A41001A') 最大尺码------------- M
# ('九分卫裤', 'A42001A') 最大尺码------------- M
# ('九分卫裤', 'A43001A') 最大尺码------------- M
# ('九分卫裤', 'A44001A') 最大尺码------------- M
# ('九分卫裤', 'A44190A') 最大尺码------------- M
# ('九分卫裤', 'A45001A') 最大尺码------------- L
# ('九分卫裤', 'A51050A') 最大尺码------------- L
# ('九分卫裤', 'A51210A') 最大尺码------------- M
# ('九分卫裤', 'A53013A') 最大尺码------------- M
# ('九分卫裤', 'A61010A') 最大尺码------------- M
# ('九分卫裤', 'A62039A') 最大尺码------------- L
# ('九分卫裤', 'A65026A') 最大尺码------------- L
#      小类   尺码  尺码件数
# 0  九分卫裤  3XL     0
# 1  九分卫裤    L     0
# 2  九分卫裤    M     0
# 3  九分卫裤    S     0
# 4  九分卫裤   XL     0
# 5  九分卫裤   XS     0
# 6  九分卫裤  XXL     0
# 7  九分卫裤  XXS    27
# boxsize ======================= 39.0
# ('休闲外套', 'A51050A') 最大尺码------------- L
#      小类   尺码  尺码件数
# 0  休闲外套  3XL    39
# 1  休闲外套  4XL     0
# 2  休闲外套  5XL     0
# 3  休闲外套    L     0
# 4  休闲外套    M     0
# 5  休闲外套    S     0
# 6  休闲外套   XL     0
# 7  休闲外套  XXL     0
# boxsize ======================= 39.0
# ('休闲长裤', 'A11001A') 最大尺码------------- L
# ('休闲长裤', 'A12001A') 最大尺码------------- XL
# ('休闲长裤', 'A21001A') 最大尺码------------- XL
# ('休闲长裤', 'A21089A') 最大尺码------------- L
# ('休闲长裤', 'A23047A') 最大尺码------------- XL
# ('休闲长裤', 'A23048A') 最大尺码------------- XXL
# ('休闲长裤', 'A31002A') 最大尺码------------- M
# ('休闲长裤', 'A32028A') 最大尺码------------- L
# ('休闲长裤', 'A33064A') 最大尺码------------- L
# ('休闲长裤', 'A33116A') 最大尺码------------- M
# ('休闲长裤', 'A34037A') 最大尺码------------- L
# ('休闲长裤', 'A35020A') 最大尺码------------- M
# ('休闲长裤', 'A37001A') 最大尺码------------- L
# ('休闲长裤', 'A41001A') 最大尺码------------- L
# ('休闲长裤', 'A42001A') 最大尺码------------- L
# ('休闲长裤', 'A43001A') 最大尺码------------- L
# ('休闲长裤', 'A44001A') 最大尺码------------- L
# ('休闲长裤', 'A44190A') 最大尺码------------- L
# ('休闲长裤', 'A45001A') 最大尺码------------- M
# ('休闲长裤', 'A51050A') 最大尺码------------- M
# ('休闲长裤', 'A51210A') 最大尺码------------- L
# ('休闲长裤', 'A52035A') 最大尺码------------- L
# ('休闲长裤', 'A53013A') 最大尺码------------- L
# ('休闲长裤', 'A61010A') 最大尺码------------- L
# ('休闲长裤', 'A62039A') 最大尺码------------- L
# ('休闲长裤', 'A65026A') 最大尺码------------- XL
#       小类    尺码  尺码件数
# 0   休闲长裤  10XL    39
# 1   休闲长裤   3XL     0
# 2   休闲长裤   3XS     0
# 3   休闲长裤   4XL     0
# 4   休闲长裤   5XL     0
# 5   休闲长裤   6XL     0
# 6   休闲长裤   7XL     0
# 7   休闲长裤   8XL     0
# 8   休闲长裤   9XL     0
# 9   休闲长裤     L     0
# 10  休闲长裤     M     0
# 11  休闲长裤     S     0
# 12  休闲长裤    XL     0
# 13  休闲长裤    XS     0
# 14  休闲长裤   XXL     0
# 15  休闲长裤   XXS     0
# boxsize ======================= 27.0
# ('卫裤', 'A11001A') 最大尺码------------- XL
# ('卫裤', 'A12001A') 最大尺码------------- XL
# ('卫裤', 'A21001A') 最大尺码------------- XL
# ('卫裤', 'A21089A') 最大尺码------------- XL
# ('卫裤', 'A23047A') 最大尺码------------- XL
# ('卫裤', 'A23048A') 最大尺码------------- XL
# ('卫裤', 'A31002A') 最大尺码------------- L
# ('卫裤', 'A32028A') 最大尺码------------- L
# ('卫裤', 'A33064A') 最大尺码------------- L
# ('卫裤', 'A33115A') 最大尺码------------- L
# ('卫裤', 'A33116A') 最大尺码------------- L
# ('卫裤', 'A34037A') 最大尺码------------- L
# ('卫裤', 'A35020A') 最大尺码------------- L
# ('卫裤', 'A37001A') 最大尺码------------- XL
# ('卫裤', 'A41001A') 最大尺码------------- L
# ('卫裤', 'A42001A') 最大尺码------------- L
# ('卫裤', 'A43001A') 最大尺码------------- L
# ('卫裤', 'A44001A') 最大尺码------------- L
# ('卫裤', 'A44190A') 最大尺码------------- L
# ('卫裤', 'A45001A') 最大尺码------------- L
# ('卫裤', 'A51050A') 最大尺码------------- L
# ('卫裤', 'A51210A') 最大尺码------------- L
# ('卫裤', 'A52035A') 最大尺码------------- L
# ('卫裤', 'A53013A') 最大尺码------------- L
# ('卫裤', 'A61010A') 最大尺码------------- L
# ('卫裤', 'A62039A') 最大尺码------------- L
# ('卫裤', 'A65026A') 最大尺码------------- L
#     小类    尺码  尺码件数
# 0   卫裤   100    27
# 1   卫裤  10XL     0
# 2   卫裤   110     0
# 3   卫裤   115     0
# 4   卫裤   120     0
# 5   卫裤   125     0
# 6   卫裤   130     0
# 7   卫裤   135     0
# 8   卫裤   140     0
# 9   卫裤   145     0
# 10  卫裤   150     0
# 11  卫裤   155     0
# 12  卫裤   160     0
# 13  卫裤   165     0
# 14  卫裤   170     0
# 15  卫裤   175     0
# 16  卫裤   180     0
# 17  卫裤   185     0
# 18  卫裤   190     0
# 19  卫裤   195     0
# 20  卫裤   200     0
# 21  卫裤   205     0
# 22  卫裤   210     0
# 23  卫裤   215     0
# 24  卫裤   220     0
# 25  卫裤   3XL     0
# 26  卫裤   3XS     0
# 27  卫裤   4XL     0
# 28  卫裤   4XS     0
# 29  卫裤   5XL     0
# 30  卫裤    60     0
# 31  卫裤   6XL     0
# 32  卫裤    70     0
# 33  卫裤   7XL     0
# 34  卫裤    80     0
# 35  卫裤   8XL     0
# 36  卫裤    90     0
# 37  卫裤   9XL     0
# 38  卫裤     L     0
# 39  卫裤     M     0
# 40  卫裤     S     0
# 41  卫裤    XL     0
# 42  卫裤    XS     0
# 43  卫裤   XXL     0
# 44  卫裤   XXS     0

# %%
 data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    #     辅助等式  绝对值变量
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
    
    dfx = data_result.reset_index('org_id')
    # 决策变量X，每个尺码的件数
    for idx_s in dfx.index.unique(): #class size
        X[idx_s] = model.addVar(vtype="I", name="X")
        print(idx_s,'**********',X[idx_s])
        

    # 设置
    df_s = data_result.reset_index(['size'])  #'class_2','org_id'

    for class_2, org_id in df_s.index.unique():
        #获取 class org ratio的ratio的最大值的尺码
        idx = (class_2, org_id)
        org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']
        print(org_xmax)
#         print(idx,'org_xmax-------------', org_xmax)
        po =df_s.loc[[(class_2, org_id)]].reset_index().set_index(['class_2','org_id','size']) #?多了一个index
        for idx in po.index.unique(): #class org size
            myratio = po.loc[idx,'ratio']
            class_2, org_id, size = idx
#             print('-------------org',org_id)
#             print('-------------class size',class_2,size)
#             print('*'*10, idx)
#             print('diff:',diff[idx])
#             print('X[class_2, size]:',X[class_2, size])
            print('X[class_2, org_max]:', X[class_2, org_max])
        
            model.addCons(diff[idx] == X[class_2, size] - myratio * X[class_2, org_max])
            model.addCons(diffabs[idx] >= diff[idx])
            model.addCons(diffabs[idx] >= -1 * diff[idx])
            model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
            model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])  
            
            
    #辅助变量 max 尺码件数X中的最大值Xmax
#     dfmax = data_result.reset_index(['size','org_id']) 
#     for idx_s in dfx.index.unique():
#         class_2, size = idx_s
#         if class_2 not in Xmax:
#             Xmax[class_2] = model.addVar(vtype ='I', name = "Xmax")
#         bl[idx_s] = model.addVar(vtype="B", name="bl")

#         model.addCons(Xmax[class_2] - X[idx_s] >= 0)
#         model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
#         model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
        
    df = data_result.reset_index('size')
#     df_1 = data_result.reset_index(['org_id','size'])
#     for idx in df_1.index.unique():
#         class_2 = idx
#         model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
    

    
    #设置目标
    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
    
#     for idx in data_result.index.unique():
# #         print('idx*************',idx)
#         myratio = data_result.loc[idx,'ratio']
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio)

#         model.addCons(diffabs[idx] >= diff[idx])
#         model.addCons(diffabs[idx] >= -1 * diff[idx])
#         model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
#         model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
    
    # 约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 获取输出值
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
#         for idx11 in Xmax:
#             print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-613-b5fec669aca1> in <module>
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
diff[('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', '3XL')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-590-ef05eee0850f> in <module>
# ----> 1 diff[('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', '3XL')]
#
# NameError: name 'diff' is not defined

# %%
# clo_data_test = clo_data.reset_index(['class_2','org_id'])
# for idx in clo_data_test.index.unique():
#     print(idx,'----------------------')
#     print(max(clo_data_test.at[idx,'qty']))
#     for size in clo_data_test.groupby('size').groups:
#         print(org_id,size)
#         clo_data_test.loc[(org_id, size),['qty']].values.ravel()

# clo_data_test.groupby(['class_2','org_id']).rank(ascending=False, method='max')
# df.loc[idx_s, ['size']].values.ravel()
# clo_data_test.loc(['class_2','org_id'])

# %%
# clo_data_test

# %%
clo_data_test = clo_data.loc[clo_data['class_2']=='2合1运动短裤（外-运动短裤/内-紧身长裤）']
# clo_data_test

# %%
# clo_data_test.reset_index(['class_2','org_id'])

# %%
# for class_name in class_arry:
clo_data_test = clo_data.loc[clo_data['class_2']=='2合1运动短裤（外-运动短裤/内-紧身长裤）']
clo_data_test = clo_data_test.reset_index().drop('index',axis=1)

# test = clo_data_test.set_index(['class_2','org_id'])
for idx in test.index.unique():
#     print('class_2 org----------------',idx)
#     class_2, org_id = idx
#     print(max(clo_data_test.at[idx,'qty']))
#     clo_ind = clo_data_test.reset_index(['class_2','org_id','size'])
#     print('-----',test.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1))
#     print('maxL',test.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size'])
#     print('maxL',test.loc[idx].sort_values(by = 'qty',axis = 0,ascending = False).head(1).loc[:,'size'])

    print('zuidade xiaosho=====================',(max(test.loc[idx,'ratio'])))
#     print(test.loc[idx])


#     for indx in test.reset_index([idx,'size']).index.unique():
#         print(indx)
        
        
#         print(clo_data_test.at[idx,'qty'])
#         print(indx,'--------qty',clo_ind.loc[indx, 'qty'])
#         print('class org size',indx)
#     print(clo_data_test)
    
#     print(clo_data_test)
#     minput = BoxSize_dict[class_name]['minput']
#     print('boxsize =======================',minput)   
#     class_result = {}
#     class_result = cal_clothes_model_1(clo_data_test,minput)
# Out:
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A12001A    M    1    1.0
# maxL M
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A21001A    L    1    1.0
# maxL L
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A23048A    L    2    1.0
# maxL L
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A31002A    M    5    1.0
# maxL M
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A34037A   XL    1    1.0
# maxL XL
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A43001A    L    2    1.0
# maxL L
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A45001A    L    2    1.0
# maxL L
# zuidade xiaosho===================== 1.0
# -----                                size  qty  ratio
# class_2                org_id
# 2合1运动短裤（外-运动短裤/内-紧身长裤） A53013A    M    5    1.0
# maxL M
# zuidade xiaosho===================== 1.0

# %%
# clo_data_test.groupby(['class_2','org_id']).max()

# %%
# for k1,l2,k3 in clo_data_test.groupby(['class_2','size','org_id']):
# #     clo_data_test.loc[idx]
#     print(k1,k2,k3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-5ff2ee7546e9> in <module>
# ----> 1 for k1,l2,k3 in clo_data_test.groupby(['class_2','size','org_id']):
#       2 #     clo_data_test.loc[idx]
#       3     print(k1,k2,k3)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
Clothes_result =pd.DataFrame(columns=('小类','尺码','尺码件数'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
#     print(clo_data_test)
    minput = BoxSize_dict[class_name]['minput']
    print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_1(clo_data_test,minput)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码']).reset_index()
    print(liningResult)
    Clothes_result = pd.concat([Clothes_result,liningResult],ignore_index=True)
# Out:
# boxsize ======================= 56.0
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A21001A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A23048A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A31002A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A34037A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A43001A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A45001A', 'XXL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', '3XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', 'L')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', 'M')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', 'S')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', 'XL')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', 'XS')
# ************* ('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A53013A', 'XXL')
# Xmax-- 2合1运动短裤（外-运动短裤/内-紧身长裤） =  8.999999999999963 ======
#                        小类   尺码  尺码件数
# 0  2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL     9
# 1  2合1运动短裤（外-运动短裤/内-紧身长裤）    L     9
# 2  2合1运动短裤（外-运动短裤/内-紧身长裤）    M     9
# 3  2合1运动短裤（外-运动短裤/内-紧身长裤）    S     6
# 4  2合1运动短裤（外-运动短裤/内-紧身长裤）   XL     5
# 5  2合1运动短裤（外-运动短裤/内-紧身长裤）   XS     9
# 6  2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL     9
# boxsize ======================= 11.0
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A11001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A12001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A21089A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A23048A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A31002A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A32028A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33064A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A33116A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A34037A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A35020A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A41001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A42001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A43001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A44190A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A45001A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A53013A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A62039A', 'XXL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 110)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 120)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 130)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 140)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 150)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 160)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 165)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 170)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 175)
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', '3XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', '4XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 'L')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 'M')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 'S')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 'XL')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 'XS')
# ************* ('三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)', 'A65026A', 'XXL')
# Xmax-- 三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣) =  1.0 ======
#                          小类   尺码  尺码件数
# 0   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  110     1
# 1   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  120     1
# 2   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  130     1
# 3   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  140     1
# 4   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  150     0
# 5   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  160     1
# 6   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  165     0
# 7   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  170     0
# 8   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  175     1
# 9   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  3XL     0
# 10  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  4XL     0
# 11  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    L     1
# 12  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    M     1
# 13  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    S     0
# 14  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XL     1
# 15  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XS     1
# 16  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  XXL     1

# %%
# exl_time = dt.datetime.now().strftime('%Y%m%d%H%M')
# locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningClothesResult'+exl_time+'.xlsx'
# Clothes_result.to_excel(locaurl, index = False)
# Clothes_result

# %%
# clo_data

# %% [markdown]
# # Model2

# %%
def cal_clothes_model_2(data_result):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    dfx = data_result.reset_index('org_id')
    
    #决策变量X，每个尺码的比例
    for idx_s in dfx.index.unique():
        X[idx_s] = model.addVar(vtype="C", name="X")
        
    #辅助变量 max 尺码件数X中的最大值Xmax
    dfmax = data_result.reset_index(['size','org_id'])
    
    for idx_s in dfx.index.unique():
        class_2, size = idx_s
        if class_2 not in Xmax:
            Xmax[class_2] = model.addVar(vtype ='C', name = "Xmax")
        bl[idx_s] = model.addVar(vtype="B", name="bl")

        model.addCons(Xmax[class_2] - X[idx_s] >= 0)
        model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
        model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
    
    #辅助等式  绝对值计算 及约束确定
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
#         if myratio!=0:
#             print(idx,'==========',myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
#       diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs', obj = data_result.loc[idx, 'qty'])
    
    #设置目标

    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
#     for idx in data_result.index.unique():
#         model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
# #         model.setObjective(diffabs[idx], clear = False)

    #绝对值
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        class_2, org_id, size = idx
        
#         if myratio!=0:
#             print('==========',myratio)
        model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])

        model.addCons(diffabs[idx] >= diff[idx])
        model.addCons(diffabs[idx] >= -1 * diff[idx])
        model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
        model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
        
        
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])
    
    df = data_result.reset_index('size')
    df_1 = data_result.reset_index(['org_id','size'])
    for idx in df_1.index.unique():
        class_2 = idx
        model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
#     约束： 每个尺码的件数之和 等于 最小装箱数
#     for idx_s in df.index.unique():
#         class_2, org_id = idx_s
#         model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 输出到出X为excle到本地
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
        for idx11 in Xmax:
            print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    return OutX
        
#     print(OutX)
#     print(liningResult)
    
#     return OutX

# %%
# clo_data

# %%
# clo_data2 = clo_data.copy()

# %%
# clo_data2.loc[clo_data2['ratio'] ==0 ,'ratio'] =0.01
# clo_data2.loc[clo_data2['qty'] ==0 ,'qty'] =0.01

# %%
# clo_data2.loc[clo_data2['ratio'],'ratio']
# clo_data2['ratio']= clo_data2['ratio']*100

# %%
# clo_data

# %%
# class_arry1 = class_arry

# %%
# class_arry1

# %%
Clothes_result_2 =pd.DataFrame(columns=('小类','尺码','尺码比例'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
    #     print(clo_data_test)
    #     minput = BoxSize_dict[class_name]['minput']
    #     print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_2(clo_data_test)
    liningResult = pd.DataFrame(class_result, index =['尺码比例']).T.rename_axis(['小类','尺码']).reset_index()
#     liningResult['尺码比例'] = liningResult['尺码比例']/100
    print(liningResult)
    Clothes_result_2 = pd.concat([Clothes_result_2,liningResult],ignore_index=True)
# Out:
# Xmax-- 2合1运动短裤（外-运动短裤/内-紧身长裤） =  0.0 ======
#                        小类   尺码  尺码比例
# 0  2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL     0
# 1  2合1运动短裤（外-运动短裤/内-紧身长裤）    L     0
# 2  2合1运动短裤（外-运动短裤/内-紧身长裤）    M     0
# 3  2合1运动短裤（外-运动短裤/内-紧身长裤）    S     0
# 4  2合1运动短裤（外-运动短裤/内-紧身长裤）   XL     0
# 5  2合1运动短裤（外-运动短裤/内-紧身长裤）   XS     0
# 6  2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL     0
# Xmax-- 三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣) =  0.0 ======
#                          小类   尺码  尺码比例
# 0   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  110     0
# 1   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  120     0
# 2   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  130     0
# 3   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  140     0
# 4   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  150     0
# 5   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  160     0
# 6   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  165     0
# 7   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  170     0
# 8   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  175     0
# 9   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  3XL     0
# 10  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  4XL     0
# 11  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    L     0
# 12  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    M     0
# 13  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    S     0
# 14  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XL     0
# 15  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XS     0
# 16  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  XXL     0
# Xmax-- 三合一(内-短棉服/外-运动风衣) =  0.0 ======
#                    小类   尺码  尺码比例
# 0   三合一(内-短棉服/外-运动风衣)  110     0
# 1   三合一(内-短棉服/外-运动风衣)  120     0
# 2   三合一(内-短棉服/外-运动风衣)  130     0
# 3   三合一(内-短棉服/外-运动风衣)  140     0
# 4   三合一(内-短棉服/外-运动风衣)  150     0
# 5   三合一(内-短棉服/外-运动风衣)  160     0
# 6   三合一(内-短棉服/外-运动风衣)  165     0
# 7   三合一(内-短棉服/外-运动风衣)  170     0
# 8   三合一(内-短棉服/外-运动风衣)  175     0
# 9   三合一(内-短棉服/外-运动风衣)  3XL     0
# 10  三合一(内-短棉服/外-运动风衣)  4XL     0
# 11  三合一(内-短棉服/外-运动风衣)    L     0
# 12  三合一(内-短棉服/外-运动风衣)    M     0
# 13  三合一(内-短棉服/外-运动风衣)    S     0
# 14  三合一(内-短棉服/外-运动风衣)   XL     0
# 15  三合一(内-短棉服/外-运动风衣)   XS     0
# 16  三合一(内-短棉服/外-运动风衣)  XXL     0
# Xmax-- 三合一(内-紧身运动长裤/外-运动短裤) =  0.0 ======
#                      小类   尺码  尺码比例
# 0  三合一(内-紧身运动长裤/外-运动短裤)    L     0
# 1  三合一(内-紧身运动长裤/外-运动短裤)    M     0
# 2  三合一(内-紧身运动长裤/外-运动短裤)    S     0
# 3  三合一(内-紧身运动长裤/外-运动短裤)   XL     0
# 4  三合一(内-紧身运动长裤/外-运动短裤)   XS     0
# 5  三合一(内-紧身运动长裤/外-运动短裤)  XXL     0
# Xmax-- 中棉服 =  0.0 ======
#      小类   尺码  尺码比例
# 0   中棉服  100     0
# 1   中棉服  110     0
# 2   中棉服  115     0
# 3   中棉服  120     0
# 4   中棉服  125     0
# 5   中棉服  130     0
# 6   中棉服  135     0
# 7   中棉服  140     0
# 8   中棉服  145     0
# 9   中棉服  150     0
# 10  中棉服  155     0
# 11  中棉服  160     0
# 12  中棉服  165     0
# 13  中棉服  170     0
# 14  中棉服  175     0
# 15  中棉服  180     0
# 16  中棉服  185     0
# 17  中棉服  190     0
# 18  中棉服  195     0
# 19  中棉服  200     0
# 20  中棉服  205     0
# 21  中棉服  210     0
# 22  中棉服  215     0
# 23  中棉服  220     0
# 24  中棉服  3XL     0
# 25  中棉服  4XL     0
# 26  中棉服  5XL     0
# 27  中棉服   60     0
# 28  中棉服   70     0
# 29  中棉服   80     0
# 30  中棉服   90     0
# 31  中棉服    L     0
# 32  中棉服    M     0
# 33  中棉服    S     0
# 34  中棉服   XL     0
# 35  中棉服   XS     0
# 36  中棉服  XXL     0
# 37  中棉服  XXS     0
# Xmax-- 中羽绒服 =  0.0 ======
#       小类   尺码  尺码比例
# 0   中羽绒服  100     0
# 1   中羽绒服  110     0
# 2   中羽绒服  115     0
# 3   中羽绒服  120     0
# 4   中羽绒服  125     0
# 5   中羽绒服  130     0
# 6   中羽绒服  135     0
# 7   中羽绒服  140     0
# 8   中羽绒服  145     0
# 9   中羽绒服  150     0
# 10  中羽绒服  155     0
# 11  中羽绒服  160     0
# 12  中羽绒服  165     0
# 13  中羽绒服  170     0
# 14  中羽绒服  175     0
# 15  中羽绒服  180     0
# 16  中羽绒服  185     0
# 17  中羽绒服  190     0
# 18  中羽绒服  195     0
# 19  中羽绒服  200     0
# 20  中羽绒服  205     0
# 21  中羽绒服  210     0
# 22  中羽绒服  215     0
# 23  中羽绒服  220     0
# 24  中羽绒服  3XL     0
# 25  中羽绒服  4XL     0
# 26  中羽绒服  5XL     0
# 27  中羽绒服   60     0
# 28  中羽绒服  6XL     0
# 29  中羽绒服   70     0
# 30  中羽绒服  7XL     0
# 31  中羽绒服   80     0
# 32  中羽绒服  8XL     0
# 33  中羽绒服   90     0
# 34  中羽绒服    L     0
# 35  中羽绒服    M     0
# 36  中羽绒服    S     0
# 37  中羽绒服   XL     0
# 38  中羽绒服   XS     0
# 39  中羽绒服  XXL     0
# 40  中羽绒服  XXS     0
# Xmax-- 九分卫裤 =  0.0 ======
#      小类   尺码  尺码比例
# 0  九分卫裤  3XL     0
# 1  九分卫裤    L     0
# 2  九分卫裤    M     0
# 3  九分卫裤    S     0
# 4  九分卫裤   XL     0
# 5  九分卫裤   XS     0
# 6  九分卫裤  XXL     0
# 7  九分卫裤  XXS     0
# Xmax-- 休闲外套 =  0.0 ======
#      小类   尺码  尺码比例
# 0  休闲外套  3XL     0
# 1  休闲外套  4XL     0
# 2  休闲外套  5XL     0
# 3  休闲外套    L     0
# 4  休闲外套    M     0
# 5  休闲外套    S     0
# 6  休闲外套   XL     0
# 7  休闲外套  XXL     0
# Xmax-- 休闲长裤 =  0.0 ======
#       小类    尺码  尺码比例
# 0   休闲长裤  10XL     0
# 1   休闲长裤   3XL     0
# 2   休闲长裤   3XS     0
# 3   休闲长裤   4XL     0
# 4   休闲长裤   5XL     0
# 5   休闲长裤   6XL     0
# 6   休闲长裤   7XL     0
# 7   休闲长裤   8XL     0
# 8   休闲长裤   9XL     0
# 9   休闲长裤     L     0
# 10  休闲长裤     M     0
# 11  休闲长裤     S     0
# 12  休闲长裤    XL     0
# 13  休闲长裤    XS     0
# 14  休闲长裤   XXL     0
# 15  休闲长裤   XXS     0
# Xmax-- 卫裤 =  0.0 ======
#     小类    尺码  尺码比例
# 0   卫裤   100     0
# 1   卫裤  10XL     0
# 2   卫裤   110     0
# 3   卫裤   115     0
# 4   卫裤   120     0
# 5   卫裤   125     0
# 6   卫裤   130     0
# 7   卫裤   135     0
# 8   卫裤   140     0
# 9   卫裤   145     0
# 10  卫裤   150     0
# 11  卫裤   155     0
# 12  卫裤   160     0
# 13  卫裤   165     0
# 14  卫裤   170     0
# 15  卫裤   175     0
# 16  卫裤   180     0
# 17  卫裤   185     0
# 18  卫裤   190     0
# 19  卫裤   195     0
# 20  卫裤   200     0
# 21  卫裤   205     0
# 22  卫裤   210     0
# 23  卫裤   215     0
# 24  卫裤   220     0
# 25  卫裤   3XL     0
# 26  卫裤   3XS     0
# 27  卫裤   4XL     0
# 28  卫裤   4XS     0
# 29  卫裤   5XL     0
# 30  卫裤    60     0
# 31  卫裤   6XL     0
# 32  卫裤    70     0
# 33  卫裤   7XL     0
# 34  卫裤    80     0
# 35  卫裤   8XL     0
# 36  卫裤    90     0
# 37  卫裤   9XL     0
# 38  卫裤     L     0
# 39  卫裤     M     0
# 40  卫裤     S     0
# 41  卫裤    XL     0
# 42  卫裤    XS     0
# 43  卫裤   XXL     0
# 44  卫裤   XXS     0
# Xmax-- 夹克 =  0.0 ======
#     小类    尺码  尺码比例
# 0   夹克  10XL     0
# 1   夹克   3XL     0
# 6  开衫连帽摇粒绒卫衣   XS     0
# 7  开衫连帽摇粒绒卫衣  XXL     0
# 8  开衫连帽摇粒绒卫衣  XXS     0
# Xmax-- 拼接休闲裤 =  0.0 ======
#       小类   尺码  尺码比例
# 0  拼接休闲裤  3XL     0
# 1  拼接休闲裤    L     0
# 2  拼接休闲裤    M     0
# 3  拼接休闲裤    S     0
# 4  拼接休闲裤   XL     0
# 5  拼接休闲裤  XXL     0
# Xmax-- 拼接卫裤 =  0.0 ======
#      小类   尺码  尺码比例
# 0  拼接卫裤  3XL     0
# 1  拼接卫裤    L     0
# 2  拼接卫裤    M     0
# 3  拼接卫裤    S     0
# 4  拼接卫裤   XL     0
# 5  拼接卫裤  XXL     0
# Xmax-- 拼接套头无帽卫衣 =  0.0 ======
#          小类   尺码  尺码比例
# 0  拼接套头无帽卫衣  3XL     0
# 1  拼接套头无帽卫衣    L     0
# 2  拼接套头无帽卫衣    M     0
# 3  拼接套头无帽卫衣    S     0
# 4  拼接套头无帽卫衣   XL     0
# 5  拼接套头无帽卫衣  XXL     0
# Xmax-- 拼接棉茄克 =  0.0 ======
#       小类   尺码  尺码比例
# 0  拼接棉茄克  3XL     0
# 1  拼接棉茄克    L     0
# 2  拼接棉茄克    M     0
# 3  拼接棉茄克    S     0
# 4  拼接棉茄克   XL     0
# 5  拼接棉茄克   XS     0
# 6  拼接棉茄克  XXL     0
# Xmax-- 拼接紧身运动长裤 =  0.0 ======
#          小类   尺码  尺码比例
# 0  拼接紧身运动长裤    L     0
# 1  拼接紧身运动长裤    M     0
# 2  拼接紧身运动长裤    S     0
# 3  拼接紧身运动长裤   XL     0
# 4  拼接紧身运动长裤   XS     0
# 5  拼接紧身运动长裤  XXL     0
# Xmax-- 棉夹克 =  0.0 ======
#      小类    尺码  尺码比例
# 0   棉夹克   100     0
# 1   棉夹克  10XL     0
# 2   棉夹克   110     0
# 3   棉夹克   115     0
# 4   棉夹克   120     0
# 5   棉夹克   125     0
# 6   棉夹克   130     0
# 7   棉夹克   135     0
# 8   棉夹克   140     0
# 9   棉夹克   145     0
# 10  棉夹克   150     0
# 11  棉夹克   155     0
# 12  棉夹克   160     0
# 13  棉夹克   165     0
# 14  棉夹克   170     0
# 15  棉夹克   175     0
# 16  棉夹克   180     0
# 17  棉夹克   185     0
# 18  棉夹克   190     0
# 19  棉夹克   195     0
# 20  棉夹克   200     0
# 21  棉夹克   205     0
# 22  棉夹克   210     0
# 23  棉夹克   215     0
# 24  棉夹克   220     0
# 25  棉夹克   3XL     0
# 26  棉夹克   3XS     0
# 27  棉夹克   4XL     0
# 28  棉夹克   5XL     0
# 29  棉夹克    60     0
# 30  棉夹克   6XL     0
# 31  棉夹克    70     0
# 32  棉夹克   7XL     0
# 33  棉夹克    80     0
# 34  棉夹克   8XL     0
# 35  棉夹克    90     0
# 36  棉夹克   9XL     0
# 37  棉夹克     L     0
# 38  棉夹克     M     0
# 39  棉夹克     S     0
# 40  棉夹克    XL     0
# 41  棉夹克    XS     0
# 42  棉夹克   XXL     0
# 1   运动风衣  10XL     0
# 2   运动风衣   110     0
# 3   运动风衣   115     0
# 4   运动风衣   120     0
# 5   运动风衣   125     0
# 6   运动风衣   130     0
# 7   运动风衣   135     0
# 8   运动风衣   140     0
# 9   运动风衣   145     0
# 10  运动风衣   150     0
# 11  运动风衣   155     0
# 12  运动风衣   160     0
# 13  运动风衣   165     0
# 14  运动风衣   170     0
# 15  运动风衣   175     0
# 16  运动风衣   180     0
# 17  运动风衣   185     0
# 18  运动风衣   190     0
# 19  运动风衣   195     0
# 20  运动风衣   200     0
# 21  运动风衣   205     0
# 22  运动风衣   210     0
# 23  运动风衣   215     0
# 24  运动风衣   220     0
# 25  运动风衣   3XL     0
# 26  运动风衣   3XS     0
# 27  运动风衣   4XL     0
# 28  运动风衣   4XS     0
# 29  运动风衣   5XL     0
# 30  运动风衣    60     0
# 31  运动风衣   6XL     0
# 32  运动风衣    70     0
# 33  运动风衣   7XL     0
# 34  运动风衣    80     0
# 35  运动风衣   8XL     0
# 36  运动风衣    90     0
# 37  运动风衣   9XL     0
# 38  运动风衣     L     0
# 39  运动风衣     M     0
# 40  运动风衣     S     0
# 41  运动风衣    XL     0
# 42  运动风衣    XS     0
# 43  运动风衣   XXL     0
# 44  运动风衣   XXS     0
# Xmax-- 连衣裙 =  0.0 ======
#     小类   尺码  尺码比例
# 0  连衣裙  3XL     0
# 1  连衣裙    L     0
# 2  连衣裙    M     0
# 3  连衣裙    S     0
# 4  连衣裙   XL     0
# 5  连衣裙   XS     0
# 6  连衣裙  XXL     0
# 7  连衣裙  XXS     0
# Xmax-- 速干长裤 =  0.0 ======
#      小类   尺码  尺码比例
# 0  速干长裤  3XL     0
# 1  速干长裤  4XL     0
# 2  速干长裤    L     0
# 3  速干长裤    M     0
# 4  速干长裤    S     0
# 5  速干长裤   XL     0
# 6  速干长裤   XS     0
# 7  速干长裤  XXL     0
# Xmax-- 针织休闲裤 =  0.0 ======
#       小类   尺码  尺码比例
# 0  针织休闲裤  3XL     0
# 1  针织休闲裤    L     0
# 2  针织休闲裤    M     0
# 3  针织休闲裤    S     0
# 4  针织休闲裤   XL     0
# 5  针织休闲裤  XXL     0
# Xmax-- 针织外套 =  0.0 ======
#      小类   尺码  尺码比例
# 0  针织外套  3XL     0
# 1  针织外套  4XL     0
# 2  针织外套    L     0
# 3  针织外套    M     0
# 4  针织外套    S     0
# 5  针织外套   XL     0
# 6  针织外套   XS     0
# 7  针织外套  XXL     0
# Xmax-- 针织运动上衣 =  0.0 ======
#        小类   尺码  尺码比例
# 0  针织运动上衣  3XL     0
# 1  针织运动上衣  4XL     0
# 2  针织运动上衣    L     0
# 3  针织运动上衣    M     0
# 4  针织运动上衣    S     0
# 5  针织运动上衣   XL     0
# 6  针织运动上衣   XS     0
# 7  针织运动上衣  XXL     0
# 8  针织运动上衣  XXS     0
# Xmax-- 针织运动裤 =  0.0 ======
#       小类   尺码  尺码比例
# 0  针织运动裤  3XL     0
# 1  针织运动裤  4XL     0
# 2  针织运动裤    L     0
# 3  针织运动裤    M     0
# 4  针织运动裤    S     0
# 5  针织运动裤   XL     0
# 6  针织运动裤   XS     0
# 7  针织运动裤  XXL     0
# Xmax-- 针织长袖衫 =  0.0 ======
#       小类   尺码  尺码比例
# 0  针织长袖衫  3XL     0
# 1  针织长袖衫  4XL     0
# 2  针织长袖衫  5XL     0
# 3  针织长袖衫    L     0
# 4  针织长袖衫    M     0
# 5  针织长袖衫    S     0
# 6  针织长袖衫   XL     0
# 7  针织长袖衫  XXL     0
# Xmax-- 针织阔腿裤 =  0.0 ======
#       小类   尺码  尺码比例
# 0  针织阔腿裤  3XL     0
# 1  针织阔腿裤    L     0
# 2  针织阔腿裤    M     0
# 3  针织阔腿裤    S     0
# 4  针织阔腿裤   XL     0
# 5  针织阔腿裤   XS     0
# 6  针织阔腿裤  XXL     0
# 7  针织阔腿裤  XXS     0
# Xmax-- 长棉服 =  0.0 ======
#      小类    尺码  尺码比例
# 0   长棉服  10XL     0
# 1   长棉服   3XL     0
# 2   长棉服   3XS     0
# 3   长棉服   4XL     0
# 4   长棉服   5XL     0
# 5   长棉服   6XL     0
# 6   长棉服   7XL     0
# 7   长棉服   8XL     0
# 8   长棉服   9XL     0
# 9   长棉服     L     0
# 10  长棉服     M     0
# 11  长棉服     S     0
# 12  长棉服    XL     0
# 13  长棉服    XS     0
# 14  长棉服   XXL     0
# 15  长棉服   XXS     0
# Xmax-- 长羽绒服 =  0.0 ======
#       小类    尺码  尺码比例
# 0   长羽绒服   100     0
# 1   长羽绒服  10XL     0
# 2   长羽绒服   110     0
# 3   长羽绒服   115     0
# 4   长羽绒服   120     0
# 5   长羽绒服   125     0
# 6   长羽绒服   130     0
# 7   长羽绒服   135     0
# 8   长羽绒服   140     0
# 9   长羽绒服   145     0
# 10  长羽绒服   150     0
# 11  长羽绒服   155     0
# 12  长羽绒服   160     0
# 13  长羽绒服   165     0
# 14  长羽绒服   170     0
# 15  长羽绒服   175     0
# 16  长羽绒服   180     0
# 17  长羽绒服   185     0
# 18  长羽绒服   190     0
# 19  长羽绒服   195     0
# 20  长羽绒服   200     0
# 21  长羽绒服   205     0
# 22  长羽绒服   210     0
# 23  长羽绒服   215     0
# 24  长羽绒服   220     0
# 25  长羽绒服   3XL     0
# 26  长羽绒服   3XS     0
# 27  长羽绒服   4XL     0
# 28  长羽绒服   4XS     0
# 29  长羽绒服   5XL     0
# 30  长羽绒服    60     0
# 31  长羽绒服   6XL     0
# 32  长羽绒服    70     0
# 33  长羽绒服   7XL     0
# 34  长羽绒服    80     0
# 35  长羽绒服   8XL     0
# 36  长羽绒服    90     0
# 37  长羽绒服   9XL     0
# 38  长羽绒服     L     0
# 39  长羽绒服     M     0
# 40  长羽绒服     S     0
# 41  长羽绒服    XL     0
# 42  长羽绒服    XS     0
# 43  长羽绒服   XXL     0
# 44  长羽绒服   XXS     0
# Xmax-- 长袖Polo =  0.0 ======
#         小类   尺码  尺码比例
# 0   长袖Polo  3XL     0
# 1   长袖Polo  3XS     0
# 2   长袖Polo  4XL     0
# 3   长袖Polo  4XS     0
# 4   长袖Polo  5XL     0
# 5   长袖Polo  6XL     0
# 6   长袖Polo  7XL     0
# 7   长袖Polo  8XL     0
# 8   长袖Polo    L     0
# 9   长袖Polo    M     0
# 10  长袖Polo    S     0
# 11  长袖Polo   XL     0
# 12  长袖Polo   XS     0
# 13  长袖Polo  XXL     0
# 14  长袖Polo  XXS     0
# Xmax-- 长袖T恤 =  0.0 ======
#       小类    尺码  尺码比例
# 0   长袖T恤  10XL     0
# 1   长袖T恤   130     0
# 2   长袖T恤   140     0
# 3   长袖T恤   150     0
# 4   长袖T恤   160     0
# 5   长袖T恤   170     0
# 6   长袖T恤   3XL     0
# 7   长袖T恤   3XS     0
# 8   长袖T恤   4XL     0
# 9   长袖T恤   5XL     0
# 10  长袖T恤   6XL     0
# 11  长袖T恤   7XL     0
# 12  长袖T恤   8XL     0
# 13  长袖T恤   9XL     0
# 14  长袖T恤     L     0
# 15  长袖T恤     M     0
# 16  长袖T恤     S     0
# 17  长袖T恤    XL     0
# 18  长袖T恤    XS     0
# 19  长袖T恤   XXL     0
# 20  长袖T恤   XXS     0
# Xmax-- 长袖套头衫 =  0.0 ======
#       小类   尺码  尺码比例
# 0  长袖套头衫  3XL     0
# 1  长袖套头衫  4XL     0
# 2  长袖套头衫    L     0
# 3  长袖套头衫    M     0
# 4  长袖套头衫    S     0
# 5  长袖套头衫   XL     0
# 6  长袖套头衫   XS     0
# 7  长袖套头衫  XXL     0
# Xmax-- 长袖文化衫 =  0.0 ======
#        小类    尺码  尺码比例
# 0   长袖文化衫  10XL     0
# 1   长袖文化衫   3XL     0
# 2   长袖文化衫   3XS     0
# 3   长袖文化衫   4XL     0
# 4   长袖文化衫   5XL     0
# 5   长袖文化衫   6XL     0
# 6   长袖文化衫   7XL     0
# 7   长袖文化衫   8XL     0
# 8   长袖文化衫   9XL     0
# 9   长袖文化衫     L     0
# 10  长袖文化衫     M     0
# 11  长袖文化衫     S     0
# 12  长袖文化衫    XL     0
# 13  长袖文化衫    XS     0
# 14  长袖文化衫   XXL     0
# 15  长袖文化衫   XXS     0
# Xmax-- 长袖紧身衣 =  0.0 ======
#        小类   尺码  尺码比例
# 0   长袖紧身衣  135     0
# 1   长袖紧身衣  140     0
# 2   长袖紧身衣  150     0
# 3   长袖紧身衣  160     0
# 4   长袖紧身衣  170     0
# 5   长袖紧身衣  175     0
# 6   长袖紧身衣  3XL     0
# 7   长袖紧身衣  4XL     0
# 8   长袖紧身衣    L     0
# 9   长袖紧身衣    M     0
# 10  长袖紧身衣    S     0
# 11  长袖紧身衣   XL     0
# 12  长袖紧身衣   XS     0
# 13  长袖紧身衣  XXL     0

# %%
# Clothes_result_2

# %%
result = pd.merge(Clothes_result, Clothes_result_2, how='right', on=['小类', '尺码'])

# %%
result

# %%
exl_time = dt.datetime.now().strftime('%Y%m%d')
locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningClothesResult555'+exl_time+'.xlsx'
result.to_excel(locaurl, index = False)
