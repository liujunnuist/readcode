# %%
from pyscipopt import Model,quicksum, multidict
import numpy as np
import pandas as pd
import openpyxl
import datetime as dt
import os

# %%
ospwd = os.getcwd()

# %%
data = pd.read_excel(ospwd+'\Dealed_AllData.xlsx')

# %%
# data

# %%
clo_data = data[data['class_0'].isin(['服装'])]

# %%
clo_data
# Out:
#       class_0  class_2   org_id        org_name sex  size  qty     ratio
# 0          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童   6XL    0  0.000000
# 1          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   中    XL   89  1.000000
# 2          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女    XS    1  0.003546
# 3          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   中     M   88  0.988764
# 4          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女   9XL    0  0.000000
# 5          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女   5XL    0  0.000000
# 6          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男   3XL  169  0.449468
# 7          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男   6XL    0  0.000000
# 8          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   中   5XL    0  0.000000
# 9          服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女  10XL    0  0.000000
# 10         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女    XL  207  0.734043
# 11         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女   6XL    0  0.000000
# 12         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童  10XL    0  0.000000
# 13         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童   8XL    0  0.000000
# 14         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男     M  239  0.635638
# 15         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女   7XL    0  0.000000
# 16         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男   XXL  275  0.731383
# 17         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童     L    0  0.000000
# 18         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童   3XL    0  0.000000
# 19         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童    XS    0  0.000000
# 20         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童   5XL    0  0.000000
# 21         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男   8XL    0  0.000000
# 22         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   童     S    0  0.000000
# 23         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女     L  275  0.975177
# 24         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女   4XL    0  0.000000
# 25         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男   5XL    0  0.000000
# 26         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   女   3XL    8  0.028369
# 27         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   中    XS    1  0.011236
# 28         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男   9XL    0  0.000000
# 29         服装     长羽绒服  A11001A  北京李宁体育用品销售有限公司   男  10XL    0  0.000000
# ...       ...      ...      ...             ...  ..   ...  ...       ...
# 34791      服装  套头无帽编织衫  A43001A  长沙一动体育用品销售有限公司   女   XXL    0  0.000000
# 34792      服装  套头无帽编织衫  A43001A  长沙一动体育用品销售有限公司   女    XL    0  0.000000
# 34793      服装  套头无帽编织衫  A43001A  长沙一动体育用品销售有限公司   女   XXS    0  0.000000
# 34794      服装  套头无帽编织衫  A43001A  长沙一动体育用品销售有限公司   女    XS    0  0.000000
# 34795      服装  套头无帽编织衫  A43001A  长沙一动体育用品销售有限公司   女     L    0  0.000000
# 34796      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女   3XL    0  0.000000
# 34797      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女     S    0  0.000000
# 34798      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女     M    0  0.000000
# 34799      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女   4XL    0  0.000000
# 34800      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女   XXL    0  0.000000
# 34801      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女    XL    0  0.000000
# 34802      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女   XXS    0  0.000000
# 34803      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女    XS    0  0.000000
# 34804      服装  套头无帽编织衫  A45001A  南宁一动体育用品销售有限公司   女     L    2  1.000000
# 34805      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男     L    1  0.500000
# 34806      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男   XXL    0  0.000000
# 34807      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男    XS    0  0.000000
# 34808      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男    XL    2  1.000000
# 34809      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男   4XL    0  0.000000
# 34810      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男   3XL    0  0.000000
# 34811      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男     M    2  1.000000
# 34812      服装  开衫无帽编织衫  A41001A  郑州一动体育用品销售有限公司   男     S    1  0.500000
# 34813      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男     L    0  0.000000
# 34814      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男   XXL    0  0.000000
# 34815      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男    XS    0  0.000000
# 34816      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男    XL    0  0.000000
# 34817      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男   4XL    0  0.000000
# 34818      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男   3XL    0  0.000000
# 34819      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男     M    1  1.000000
# 34820      服装  开衫无帽编织衫  A44190A      深圳悦奥商贸有限公司   男     S    1  1.000000
#
# [22843 rows x 8 columns]

# %%
# clo_data.loc[clo_data['class_2']=='背心']

# %%
# class_list = clo_data['class_2'].drop_duplicates().reset_index().drop('index',axis =1)

# %%
# class_list

# %%
# class_arry = class_list['class_2'].values

# %%
# class_arry

# %%
# len(class_arry)

# %% [markdown]
# ### 归一化

# %%
# test1 = clo_data.copy()

# %%
# test1

# %%
# test1copy = test1.groupby(['class_2','org_id'])['qty'].sum().reset_index()

# %%
# test1copy

# %%
# test1 = pd.merge(test1, test1copy.rename(columns= {'qty':'sum'}),how = "left")

# %%
# test1

# %%
# test1['sumqty_ratio'] = test1['qty']/test1['sum']

# %%
# test1

# %%
# test2 = test1.groupby(['class_2','org_id'])['qty'].sum().reset_index().rename(columns = {'qty':'org_sum'})

# %%
# test2

# %%
# test2copy= test2.groupby(['class_2'])['org_sum'].sum().reset_index().rename(columns = {'org_sum':'all_org_sum'})

# %%
# test2copy

# %%
# test2 = pd.merge(test2, test2copy,how = "left")

# %%
# test2 ['oneorg_ratio'] = test2['org_sum']/test2['all_org_sum']

# %%
# test2

# %%
test3 = clo_data.copy()

# %%
# test3

# %%
test3 = test3.reset_index().drop('index',axis =1)

# %%
# test3

# %%
test3.set_index(['class_2','size','sex'], inplace = True)

# %%
test3
# Out:
#                  class_0   org_id        org_name  qty     ratio
# class_2 size sex
# 长羽绒服    6XL  童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         XL   中        服装  A11001A  北京李宁体育用品销售有限公司   89  1.000000
#         XS   女        服装  A11001A  北京李宁体育用品销售有限公司    1  0.003546
#         M    中        服装  A11001A  北京李宁体育用品销售有限公司   88  0.988764
#         9XL  女        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         5XL  女        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         3XL  男        服装  A11001A  北京李宁体育用品销售有限公司  169  0.449468
#         6XL  男        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         5XL  中        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         10XL 女        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         XL   女        服装  A11001A  北京李宁体育用品销售有限公司  207  0.734043
#         6XL  女        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         10XL 童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         8XL  童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         M    男        服装  A11001A  北京李宁体育用品销售有限公司  239  0.635638
#         7XL  女        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         XXL  男        服装  A11001A  北京李宁体育用品销售有限公司  275  0.731383
#         L    童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         3XL  童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         XS   童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         5XL  童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         8XL  男        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         S    童        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         L    女        服装  A11001A  北京李宁体育用品销售有限公司  275  0.975177
#         4XL  女        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         5XL  男        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         3XL  女        服装  A11001A  北京李宁体育用品销售有限公司    8  0.028369
#         XS   中        服装  A11001A  北京李宁体育用品销售有限公司    1  0.011236
#         9XL  男        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
#         10XL 男        服装  A11001A  北京李宁体育用品销售有限公司    0  0.000000
# ...                  ...      ...             ...  ...       ...
# 套头无帽编织衫 XXL  女        服装  A43001A  长沙一动体育用品销售有限公司    0  0.000000
#         XL   女        服装  A43001A  长沙一动体育用品销售有限公司    0  0.000000
#         XXS  女        服装  A43001A  长沙一动体育用品销售有限公司    0  0.000000
#         XS   女        服装  A43001A  长沙一动体育用品销售有限公司    0  0.000000
#         L    女        服装  A43001A  长沙一动体育用品销售有限公司    0  0.000000
#         3XL  女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         S    女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         M    女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         4XL  女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         XXL  女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         XL   女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         XXS  女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         XS   女        服装  A45001A  南宁一动体育用品销售有限公司    0  0.000000
#         L    女        服装  A45001A  南宁一动体育用品销售有限公司    2  1.000000
# 开衫无帽编织衫 L    男        服装  A41001A  郑州一动体育用品销售有限公司    1  0.500000
#         XXL  男        服装  A41001A  郑州一动体育用品销售有限公司    0  0.000000
#         XS   男        服装  A41001A  郑州一动体育用品销售有限公司    0  0.000000
#         XL   男        服装  A41001A  郑州一动体育用品销售有限公司    2  1.000000
#         4XL  男        服装  A41001A  郑州一动体育用品销售有限公司    0  0.000000
#         3XL  男        服装  A41001A  郑州一动体育用品销售有限公司    0  0.000000
#         M    男        服装  A41001A  郑州一动体育用品销售有限公司    2  1.000000
#         S    男        服装  A41001A  郑州一动体育用品销售有限公司    1  0.500000
#         L    男        服装  A44190A      深圳悦奥商贸有限公司    0  0.000000
#         XXL  男        服装  A44190A      深圳悦奥商贸有限公司    0  0.000000
#         XS   男        服装  A44190A      深圳悦奥商贸有限公司    0  0.000000
#         XL   男        服装  A44190A      深圳悦奥商贸有限公司    0  0.000000
#         4XL  男        服装  A44190A      深圳悦奥商贸有限公司    0  0.000000
#         3XL  男        服装  A44190A      深圳悦奥商贸有限公司    0  0.000000
#         M    男        服装  A44190A      深圳悦奥商贸有限公司    1  1.000000
#         S    男        服装  A44190A      深圳悦奥商贸有限公司    1  1.000000
#
# [22843 rows x 5 columns]

# %%
test3['qty_max'] = test3['qty'].max(level = ['class_2', 'size','sex'])

# %%
test3['qty_min'] = test3['qty'].min(level = ['class_2', 'size','sex'])

# %%
# test3

# %%
# hah =test3.reset_index()
# hah.loc[hah['class_2']=='背心']

# %%
test3['nor'] =(test3['qty_max']-test3['qty'])/(test3['qty_max']-test3['qty_min']+ 1.0E-10)

# %%
test3['nor'] = test3['nor'].map(lambda x: np.exp(x - 1))

# %%
# test3

# %%
test3.reset_index(inplace = True)

# %%
in_clo_data = test3.drop(['qty_max','qty_min'],axis =1)

# %%
in_clo_data[in_clo_data['class_2']==1201]
# Out:
#       class_2 size sex class_0   org_id        org_name  qty     ratio  \
# 12106    1201    S   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12107    1201  3XL   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12108    1201    L   男      服装  A21089A  大连悦奥体育用品销售有限公司    3  1.000000
# 12109    1201    M   男      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12110    1201  XXL   男      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12111    1201  3XL   男      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12112    1201  XXL   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12113    1201    S   男      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12114    1201   XS   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12115    1201  XXS   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12116    1201   XL   男      服装  A21089A  大连悦奥体育用品销售有限公司    2  0.666667
# 12117    1201    M   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12118    1201   XL   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12119    1201    L   女      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12120    1201  4XL   男      服装  A21089A  大连悦奥体育用品销售有限公司    0  0.000000
# 12121    1201    S   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12122    1201  3XL   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12123    1201    L   男      服装  A32028A  南京一动体育用品销售有限公司   32  1.000000
# 12124    1201    M   男      服装  A32028A  南京一动体育用品销售有限公司   19  0.593750
# 12125    1201  XXL   男      服装  A32028A  南京一动体育用品销售有限公司    1  0.031250
# 12126    1201  3XL   男      服装  A32028A  南京一动体育用品销售有限公司    5  0.156250
# 12127    1201  XXL   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12128    1201    S   男      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12129    1201   XS   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12130    1201  XXS   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12131    1201   XL   男      服装  A32028A  南京一动体育用品销售有限公司   31  0.968750
# 12132    1201    M   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12133    1201   XL   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12134    1201    L   女      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# 12135    1201  4XL   男      服装  A32028A  南京一动体育用品销售有限公司    0  0.000000
# ...       ...  ...  ..     ...      ...             ...  ...       ...
# 12211    1201    S   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12212    1201  3XL   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12213    1201    L   男      服装  A51210A  重庆悦奥体育用品销售有限公司   52  1.000000
# 12214    1201    M   男      服装  A51210A  重庆悦奥体育用品销售有限公司   20  0.384615
# 12215    1201  XXL   男      服装  A51210A  重庆悦奥体育用品销售有限公司   17  0.326923
# 12216    1201  3XL   男      服装  A51210A  重庆悦奥体育用品销售有限公司   10  0.192308
# 12217    1201  XXL   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12218    1201    S   男      服装  A51210A  重庆悦奥体育用品销售有限公司   12  0.230769
# 12219    1201   XS   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12220    1201  XXS   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12221    1201   XL   男      服装  A51210A  重庆悦奥体育用品销售有限公司   43  0.826923
# 12222    1201    M   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12223    1201   XL   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12224    1201    L   女      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12225    1201  4XL   男      服装  A51210A  重庆悦奥体育用品销售有限公司    0  0.000000
# 12226    1201    S   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12227    1201  3XL   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12228    1201    L   男      服装  A65026A  新疆一动体育用品销售有限公司    3  1.000000
# 12229    1201    M   男      服装  A65026A  新疆一动体育用品销售有限公司    1  0.333333
# 12230    1201  XXL   男      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12231    1201  3XL   男      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12232    1201  XXL   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12233    1201    S   男      服装  A65026A  新疆一动体育用品销售有限公司    1  0.333333
# 12234    1201   XS   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12235    1201  XXS   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12236    1201   XL   男      服装  A65026A  新疆一动体育用品销售有限公司    1  0.333333
# 12237    1201    M   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12238    1201   XL   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12239    1201    L   女      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
# 12240    1201  4XL   男      服装  A65026A  新疆一动体育用品销售有限公司    0  0.000000
#
#             nor
# 12106  0.367879
# 12107  0.367879
# 12108  1.000000
# 12109  1.000000
# 12110  1.000000
# 12111  1.000000
# 12112  0.367879
# 12113  1.000000
# 12114  0.367879
# 12115  0.367879
# 12116  0.976472
# 12117  0.367879
# 12118  0.367879
# 12119  0.367879
# 12120  0.367879
# 12121  0.367879
# 12122  0.367879
# 12123  0.553310
# 12124  0.386741
# 12125  0.942873
# 12126  0.606531
# 12127  0.367879
# 12128  1.000000
# 12129  0.367879
# 12130  0.367879
# 12131  0.489542
# 12132  0.367879
# 12133  0.367879
# 12134  0.367879
# 12135  0.367879
# ...         ...
# 12211  0.367879
# 12212  0.367879
# 12213  0.367879
# 12214  0.367879
# 12215  0.367879
# 12216  0.367879
# 12217  0.367879
# 12218  0.367879
# 12219  0.367879
# 12220  0.367879
# 12221  0.367879
# 12222  0.367879
# 12223  0.367879
# 12224  0.367879
# 12225  0.367879
# 12226  0.367879
# 12227  0.367879
# 12228  1.000000
# 12229  0.951229
# 12230  1.000000
# 12231  1.000000
# 12232  0.367879
# 12233  0.920044
# 12234  0.367879
# 12235  0.367879
# 12236  1.000000
# 12237  0.367879
# 12238  0.367879
# 12239  0.367879
# 12240  0.367879
#
# [135 rows x 9 columns]

# %%
# clo_data['min'] = clo_data.groupby(['class_2','org_id']).max()
# clo_data['min'] = clo_data['qty'].max(level = ['class_2','org_id'])
# clo_data = clo_data.set_index(['class_2','org_id']).groupby(['class_2','org_id'])
#  org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']

# %%
# clo_data = clo_data[~clo_data['class_2'].isin([1201])]#删除1201
clo_data = in_clo_data[~in_clo_data['class_2'].isin([1201])]#删除1201

# %%
clo_data = clo_data.drop(['org_name','class_0'],axis=1).reset_index().drop('index',axis=1)

# %%
clo_data
# Out:
#        class_2  size sex   org_id  qty     ratio       nor
# 0         长羽绒服   6XL   童  A11001A    0  0.000000  0.367879
# 1         长羽绒服    XL   中  A11001A   89  1.000000  0.367879
# 2         长羽绒服    XS   女  A11001A    1  0.003546  0.920044
# 3         长羽绒服     M   中  A11001A   88  0.988764  0.367879
# 4         长羽绒服   9XL   女  A11001A    0  0.000000  0.367879
# 5         长羽绒服   5XL   女  A11001A    0  0.000000  0.367879
# 6         长羽绒服   3XL   男  A11001A  169  0.449468  0.367879
# 7         长羽绒服   6XL   男  A11001A    0  0.000000  0.367879
# 8         长羽绒服   5XL   中  A11001A    0  0.000000  0.367879
# 9         长羽绒服  10XL   女  A11001A    0  0.000000  0.367879
# 10        长羽绒服    XL   女  A11001A  207  0.734043  0.367879
# 11        长羽绒服   6XL   女  A11001A    0  0.000000  0.367879
# 12        长羽绒服  10XL   童  A11001A    0  0.000000  0.367879
# 13        长羽绒服   8XL   童  A11001A    0  0.000000  0.367879
# 14        长羽绒服     M   男  A11001A  239  0.635638  0.367879
# 15        长羽绒服   7XL   女  A11001A    0  0.000000  0.367879
# 16        长羽绒服   XXL   男  A11001A  275  0.731383  0.367879
# 17        长羽绒服     L   童  A11001A    0  0.000000  0.367879
# 18        长羽绒服   3XL   童  A11001A    0  0.000000  0.367879
# 19        长羽绒服    XS   童  A11001A    0  0.000000  0.367879
# 20        长羽绒服   5XL   童  A11001A    0  0.000000  0.367879
# 21        长羽绒服   8XL   男  A11001A    0  0.000000  0.367879
# 22        长羽绒服     S   童  A11001A    0  0.000000  0.367879
# 23        长羽绒服     L   女  A11001A  275  0.975177  0.367879
# 24        长羽绒服   4XL   女  A11001A    0  0.000000  0.367879
# 25        长羽绒服   5XL   男  A11001A    0  0.000000  1.000000
# 26        长羽绒服   3XL   女  A11001A    8  0.028369  0.367879
# 27        长羽绒服    XS   中  A11001A    1  0.011236  0.818731
# 28        长羽绒服   9XL   男  A11001A    0  0.000000  0.367879
# 29        长羽绒服  10XL   男  A11001A    0  0.000000  0.367879
# ...        ...   ...  ..      ...  ...       ...       ...
# 22678  套头无帽编织衫   XXL   女  A43001A    0  0.000000  1.000000
# 22679  套头无帽编织衫    XL   女  A43001A    0  0.000000  1.000000
# 22680  套头无帽编织衫   XXS   女  A43001A    0  0.000000  0.367879
# 22681  套头无帽编织衫    XS   女  A43001A    0  0.000000  0.367879
# 22682  套头无帽编织衫     L   女  A43001A    0  0.000000  1.000000
# 22683  套头无帽编织衫   3XL   女  A45001A    0  0.000000  0.367879
# 22684  套头无帽编织衫     S   女  A45001A    0  0.000000  1.000000
# 22685  套头无帽编织衫     M   女  A45001A    0  0.000000  1.000000
# 22686  套头无帽编织衫   4XL   女  A45001A    0  0.000000  0.367879
# 22687  套头无帽编织衫   XXL   女  A45001A    0  0.000000  1.000000
# 22688  套头无帽编织衫    XL   女  A45001A    0  0.000000  1.000000
# 22689  套头无帽编织衫   XXS   女  A45001A    0  0.000000  0.367879
# 22690  套头无帽编织衫    XS   女  A45001A    0  0.000000  0.367879
# 22691  套头无帽编织衫     L   女  A45001A    2  1.000000  0.670320
# 22692  开衫无帽编织衫     L   男  A41001A    1  0.500000  0.367879
# 22693  开衫无帽编织衫   XXL   男  A41001A    0  0.000000  0.367879
# 22694  开衫无帽编织衫    XS   男  A41001A    0  0.000000  0.367879
# 22695  开衫无帽编织衫    XL   男  A41001A    2  1.000000  0.367879
# 22696  开衫无帽编织衫   4XL   男  A41001A    0  0.000000  0.367879
# 22697  开衫无帽编织衫   3XL   男  A41001A    0  0.000000  0.367879
# 22698  开衫无帽编织衫     M   男  A41001A    2  1.000000  0.367879
# 22699  开衫无帽编织衫     S   男  A41001A    1  0.500000  0.367879
# 22700  开衫无帽编织衫     L   男  A44190A    0  0.000000  1.000000
# 22701  开衫无帽编织衫   XXL   男  A44190A    0  0.000000  0.367879
# 22702  开衫无帽编织衫    XS   男  A44190A    0  0.000000  0.367879
# 22703  开衫无帽编织衫    XL   男  A44190A    0  0.000000  1.000000
# 22704  开衫无帽编织衫   4XL   男  A44190A    0  0.000000  0.367879
# 22705  开衫无帽编织衫   3XL   男  A44190A    0  0.000000  0.367879
# 22706  开衫无帽编织衫     M   男  A44190A    1  1.000000  1.000000
# 22707  开衫无帽编织衫     S   男  A44190A    1  1.000000  0.367879
#
# [22708 rows x 7 columns]

# %%
class_list = clo_data['class_2'].drop_duplicates().reset_index().drop('index',axis =1)

# %%
class_arry = class_list['class_2'].values

# %%
class_arry
# Out:
# array(['长羽绒服', '运动风衣', '套头连帽卫衣', '长袖Polo', '软壳长裤', '三合一(内-短棉服/外-运动风衣)',
#        '卫裤', '长袖文化衫', '开衫连帽卫衣', '套头无帽卫衣', '背心', '开衫无帽卫衣', '比赛上衣', '短棉服',
#        '夹克', '针织长袖衫', '短袖文化衫', '针织运动裤', '紧身运动长裤', '运动长裤', '短袖Polo',
#        '休闲长裤', '短袖T恤', '开衫连帽摇粒绒卫衣', '针织运动上衣', '中棉服', '羽绒马甲', '长袖T恤',
#        '棉夹克', '连衣裙', '长袖紧身衣', '运动短裤', '速干长裤', '三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)',
#        '针织外套', '长棉服', '九分卫裤', '短羽绒服', '针织阔腿裤', '开衫无帽卫衣套装', '中羽绒服', '比赛裤',
#        '2合1运动短裤（外-运动短裤/内-紧身长裤）', '三合一(内-紧身运动长裤/外-运动短裤)', '长袖套头衫', '休闲外套',
#        '运动文胸', '套头无帽编织衫', '开衫无帽编织衫'], dtype=object)

# %%
len(class_arry) #删除了1201
# Out:
# 49

# %% [markdown]
# ### 获取装箱尺码

# %%
BoxSize = pd.read_excel(ospwd+'/ClothesSize_minput.xlsx')

# %%
BoxSize = BoxSize.dropna().reset_index().drop('index',axis=1).rename(columns = {'小类':'class_2','装箱量加权平均值':'minput'})

# %%
BoxSize['minput'] = (BoxSize['minput']).apply(np.round)

# %%
BoxSize_dict = BoxSize.set_index('class_2').T.to_dict()

# %%
# BoxSize_dict

# %%
# for class_name in class_arry:
#     minput = BoxSize_dict[class_name]['minput']
#     print(minput)

# %% [markdown]
# ### 建模

# %%
# clo_data

# %%
Clothes_result =pd.DataFrame(columns=('小类','尺码','性别','尺码件数'))


clo_data_test = clo_data.loc[clo_data['class_2']== '背心']
clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
#     print(clo_data_test)
minput = BoxSize_dict['背心']['minput']
print('boxsize =======================',minput)   
# class_result = {}
# class_result = cal_clothes_model_1(clo_data_test,minput)
# liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码','性别']).reset_index()
# print(liningResult)
# Clothes_result = pd.concat([Clothes_result,liningResult],ignore_index=True)
# Out:
# boxsize ======================= 72.0

# %%
clo_data_test
# Out:
#    class_2 size sex   org_id  qty     ratio       nor
# 0       背心  4XL   男  A31002A    0  0.000000  0.367879
# 1       背心    L   男  A31002A    2  1.000000  1.000000
# 2       背心  XXL   女  A31002A    0  0.000000  1.000000
# 3       背心  3XL   男  A31002A    0  0.000000  1.000000
# 4       背心   XS   男  A31002A    0  0.000000  0.367879
# 5       背心    S   男  A31002A    0  0.000000  1.000000
# 6       背心  4XS   男  A31002A    0  0.000000  0.367879
# 7       背心  XXS   女  A31002A    0  0.000000  0.367879
# 8       背心  3XS   男  A31002A    0  0.000000  0.367879
# 9       背心   XS   女  A31002A    0  0.000000  0.367879
# 10      背心  7XL   男  A31002A    0  0.000000  0.367879
# 11      背心  3XL   女  A31002A    0  0.000000  0.367879
# 12      背心    L   女  A31002A    0  0.000000  1.000000
# 13      背心  5XL   男  A31002A    0  0.000000  0.367879
# 14      背心  8XL   男  A31002A    0  0.000000  0.367879
# 15      背心   XL   男  A31002A    1  0.500000  1.000000
# 16      背心    M   男  A31002A    0  0.000000  1.000000
# 17      背心  XXL   男  A31002A    0  0.000000  1.000000
# 18      背心  6XL   男  A31002A    0  0.000000  0.367879
# 19      背心   XL   女  A31002A    0  0.000000  1.000000
# 20      背心    M   女  A31002A    0  0.000000  1.000000
# 21      背心  4XL   女  A31002A    0  0.000000  0.367879
# 22      背心    S   女  A31002A    0  0.000000  1.000000
# 23      背心  XXS   男  A31002A    0  0.000000  0.367879
# 24      背心  4XL   男  A33064A    0  0.000000  0.367879
# 25      背心    L   男  A33064A   17  1.000000  0.367879
# 26      背心  XXL   女  A33064A    1  0.333333  0.367879
# 27      背心  3XL   男  A33064A    6  0.352941  0.367879
# 28      背心   XS   男  A33064A    0  0.000000  0.367879
# 29      背心    S   男  A33064A    5  0.294118  0.367879
# 30      背心  4XS   男  A33064A    0  0.000000  0.367879
# 31      背心  XXS   女  A33064A    0  0.000000  0.367879
# 32      背心  3XS   男  A33064A    0  0.000000  0.367879
# 33      背心   XS   女  A33064A    0  0.000000  0.367879
# 34      背心  7XL   男  A33064A    0  0.000000  0.367879
# 35      背心  3XL   女  A33064A    0  0.000000  0.367879
# 36      背心    L   女  A33064A    1  0.333333  0.367879
# 37      背心  5XL   男  A33064A    0  0.000000  0.367879
# 38      背心  8XL   男  A33064A    0  0.000000  0.367879
# 39      背心   XL   男  A33064A   15  0.882353  0.367879
# 40      背心    M   男  A33064A   17  1.000000  0.367879
# 41      背心  XXL   男  A33064A   11  0.647059  0.367879
# 42      背心  6XL   男  A33064A    0  0.000000  0.367879
# 43      背心   XL   女  A33064A    1  0.333333  0.367879
# 44      背心    M   女  A33064A    3  1.000000  0.367879
# 45      背心  4XL   女  A33064A    0  0.000000  0.367879
# 46      背心    S   女  A33064A    2  0.666667  0.367879
# 47      背心  XXS   男  A33064A    0  0.000000  0.367879

# %%
data_result = clo_data_test.set_index(['class_2','org_id','size','sex'])

# %%
# data_result

# %%
#建立模型
model = Model("LiNingExample")

#  变量及参数定义
M = 100000   #极大值
diffabs = {} #绝对值
bl = {} #bool
X = {} #决策变量
Xmax = {} # X 的最大值
dllb = {}
diff = {}

# %%
#     辅助等式  绝对值变量
for idx in data_result.index.unique(): #class org size 
    print(idx)
    myratio = data_result.loc[idx,'ratio']
    # print('myration:', myratio)
    dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
    diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
    diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
# Out:
# ('背心', 'A31002A', '4XL', '男')
# ('背心', 'A31002A', 'L', '男')
# ('背心', 'A31002A', 'XXL', '女')
# ('背心', 'A31002A', '3XL', '男')
# ('背心', 'A31002A', 'XS', '男')
# ('背心', 'A31002A', 'S', '男')
# ('背心', 'A31002A', '4XS', '男')
# ('背心', 'A31002A', 'XXS', '女')
# ('背心', 'A31002A', '3XS', '男')
# ('背心', 'A31002A', 'XS', '女')
# ('背心', 'A31002A', '7XL', '男')
# ('背心', 'A31002A', '3XL', '女')
# ('背心', 'A31002A', 'L', '女')
# ('背心', 'A31002A', '5XL', '男')
# ('背心', 'A31002A', '8XL', '男')
# ('背心', 'A31002A', 'XL', '男')
# ('背心', 'A31002A', 'M', '男')
# ('背心', 'A31002A', 'XXL', '男')
# ('背心', 'A31002A', '6XL', '男')
# ('背心', 'A31002A', 'XL', '女')
# ('背心', 'A31002A', 'M', '女')
# ('背心', 'A31002A', '4XL', '女')
# ('背心', 'A31002A', 'S', '女')
# ('背心', 'A31002A', 'XXS', '男')
# ('背心', 'A33064A', '4XL', '男')
# ('背心', 'A33064A', 'L', '男')
# ('背心', 'A33064A', 'XXL', '女')
# ('背心', 'A33064A', '3XL', '男')
# ('背心', 'A33064A', 'XS', '男')
# ('背心', 'A33064A', 'S', '男')
# ('背心', 'A33064A', '4XS', '男')
# ('背心', 'A33064A', 'XXS', '女')
# ('背心', 'A33064A', '3XS', '男')
# ('背心', 'A33064A', 'XS', '女')
# ('背心', 'A33064A', '7XL', '男')
# ('背心', 'A33064A', '3XL', '女')
# ('背心', 'A33064A', 'L', '女')
# ('背心', 'A33064A', '5XL', '男')
# ('背心', 'A33064A', '8XL', '男')
# ('背心', 'A33064A', 'XL', '男')
# ('背心', 'A33064A', 'M', '男')
# ('背心', 'A33064A', 'XXL', '男')
# ('背心', 'A33064A', '6XL', '男')
# ('背心', 'A33064A', 'XL', '女')
# ('背心', 'A33064A', 'M', '女')
# ('背心', 'A33064A', '4XL', '女')
# ('背心', 'A33064A', 'S', '女')
# ('背心', 'A33064A', 'XXS', '男')

# %%
len(data_result.index.unique())
# Out:
# 48

# %%
dfx = data_result.reset_index('org_id')
# 决策变量X，每个尺码的件数
for idx_s in dfx.index.unique(): #class size sex
    X[idx_s] = model.addVar(vtype="I", name="X")
#     print(idx_s,'**********',X[idx_s])
# Out:
# ('背心', '4XL', '男') ********** X
# ('背心', 'L', '男') ********** X
# ('背心', 'XXL', '女') ********** X
# ('背心', '3XL', '男') ********** X
# ('背心', 'XS', '男') ********** X
# ('背心', 'S', '男') ********** X
# ('背心', '4XS', '男') ********** X
# ('背心', 'XXS', '女') ********** X
# ('背心', '3XS', '男') ********** X
# ('背心', 'XS', '女') ********** X
# ('背心', '7XL', '男') ********** X
# ('背心', '3XL', '女') ********** X
# ('背心', 'L', '女') ********** X
# ('背心', '5XL', '男') ********** X
# ('背心', '8XL', '男') ********** X
# ('背心', 'XL', '男') ********** X
# ('背心', 'M', '男') ********** X
# ('背心', 'XXL', '男') ********** X
# ('背心', '6XL', '男') ********** X
# ('背心', 'XL', '女') ********** X
# ('背心', 'M', '女') ********** X
# ('背心', '4XL', '女') ********** X
# ('背心', 'S', '女') ********** X
# ('背心', 'XXS', '男') ********** X

# %%
len (dfx.index.unique())
# Out:
# 24

# %%
# 设置
df_s = data_result.reset_index(['size'])  #class_2 org_id sex

for class_2, org_id,sex in df_s.index.unique():
    #获取 class org ratio的ratio的最大值的尺码
    idx = (class_2, org_id, sex)
    org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']
#     print(org_xmax)
#     print(org_xmax)
    print(idx,'最大尺码-------------', org_xmax)
    po =df_s.loc[[(class_2, org_id, sex)]].reset_index().set_index(['class_2','org_id','size','sex']) #?多了一个index
    for idx in po.index.unique(): #class org size
        print(idx)
        myratio = po.loc[idx,'ratio']
        class_2, org_id, size,sex = idx
#             print('-------------org',org_id)
#             print('-------------class size',class_2,size)
#             print('*'*10, idx)
#             print('diff:',diff[idx])
#             print('X[class_2, size]:',X[class_2, size])
#             print('X[class_2, org_max]:', X[class_2, org_max])
#         print(class_2, org_xmax,sex)
        model.addCons(diff[idx] == X[class_2, size, sex] - myratio * X[class_2, org_xmax,sex])
        model.addCons(diffabs[idx] >= diff[idx])
        model.addCons(diffabs[idx] >= -1 * diff[idx])
        model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
        model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])  



#     df_1 = data_result.reset_index(['org_id','size'])
#     for idx in df_1.index.unique():
#         class_2 = idx
#         model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)

#设置目标
for idx in data_result.index.unique():
#     print(idx)
    model.setObjective(data_result.loc[idx, 'nor']*diffabs[idx], clear = False)


#     for idx in data_result.index.unique():
# #         print('idx*************',idx)
#         myratio = data_result.loc[idx,'ratio']
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio)

#         model.addCons(diffabs[idx] >= diff[idx])
#         model.addCons(diffabs[idx] >= -1 * diff[idx])
#         model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
#         model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
# Out:
# ('背心', 'A31002A', '男') 最大尺码------------- L
# ('背心', 'A31002A', '4XL', '男')
# ('背心', 'A31002A', 'L', '男')
# ('背心', 'A31002A', '3XL', '男')
# ('背心', 'A31002A', 'XS', '男')
# ('背心', 'A31002A', 'S', '男')
# ('背心', 'A31002A', '4XS', '男')
# ('背心', 'A31002A', '3XS', '男')
# ('背心', 'A31002A', '7XL', '男')
# ('背心', 'A31002A', '5XL', '男')
# ('背心', 'A31002A', '8XL', '男')
# ('背心', 'A31002A', 'XL', '男')
# ('背心', 'A31002A', 'M', '男')
# ('背心', 'A31002A', 'XXL', '男')
# ('背心', 'A31002A', '6XL', '男')
# ('背心', 'A31002A', 'XXS', '男')
# ('背心', 'A31002A', '女') 最大尺码------------- XXL
# ('背心', 'A31002A', 'XXL', '女')
# ('背心', 'A31002A', 'XXS', '女')
# ('背心', 'A31002A', 'XS', '女')
# ('背心', 'A31002A', '3XL', '女')
# ('背心', 'A31002A', 'L', '女')
# ('背心', 'A31002A', 'XL', '女')
# ('背心', 'A31002A', 'M', '女')
# ('背心', 'A31002A', '4XL', '女')
# ('背心', 'A31002A', 'S', '女')
# ('背心', 'A33064A', '男') 最大尺码------------- L
# ('背心', 'A33064A', '4XL', '男')
# ('背心', 'A33064A', 'L', '男')
# ('背心', 'A33064A', '3XL', '男')
# ('背心', 'A33064A', 'XS', '男')
# ('背心', 'A33064A', 'S', '男')
# ('背心', 'A33064A', '4XS', '男')
# ('背心', 'A33064A', '3XS', '男')
# ('背心', 'A33064A', '7XL', '男')
# ('背心', 'A33064A', '5XL', '男')
# ('背心', 'A33064A', '8XL', '男')
# ('背心', 'A33064A', 'XL', '男')
# ('背心', 'A33064A', 'M', '男')
# ('背心', 'A33064A', 'XXL', '男')
# ('背心', 'A33064A', '6XL', '男')
# ('背心', 'A33064A', 'XXS', '男')
# ('背心', 'A33064A', '女') 最大尺码------------- M
# ('背心', 'A33064A', 'XXL', '女')
# ('背心', 'A33064A', 'XXS', '女')
# ('背心', 'A33064A', 'XS', '女')
# ('背心', 'A33064A', '3XL', '女')
# ('背心', 'A33064A', 'L', '女')
# ('背心', 'A33064A', 'XL', '女')
# ('背心', 'A33064A', 'M', '女')
# ('背心', 'A33064A', '4XL', '女')
# ('背心', 'A33064A', 'S', '女')
# C:\Users\liuju\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\ipykernel_launcher.py:7: PerformanceWarning: indexing past lexsort depth may impact performance.
#   import sys
# C:\Users\liuju\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\ipykernel_launcher.py:7: PerformanceWarning: indexing past lexsort depth may impact performance.
#   import sys
# C:\Users\liuju\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\ipykernel_launcher.py:7: PerformanceWarning: indexing past lexsort depth may impact performance.
#   import sys
# C:\Users\liuju\AppData\Local\Continuum\anaconda3\envs\python3.6\lib\site-packages\ipykernel_launcher.py:7: PerformanceWarning: indexing past lexsort depth may impact performance.
#   import sys

# %%
# df_s

# %%
# 约束： 每个尺码的件数之和 等于 最小装箱数
df = data_result.reset_index('size')
for idx_s in df.index.unique(): #class_2	org_id	sex
#     print(idx_s)
    class_2, org_id, sex = idx_s
#     print('--------------------',class_2,org_id,sex)
#     for size_1 in df.loc[idx_s, ['size']].values.ravel():
#         print(size_1)
    model.addCons(quicksum(X[class_2,size_1,sex] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

# %%
# df

# %%
model.setMinimize()
model.optimize()
status = model.getStatus()

# %%
# 获取输出值
OutX = {}
if model.getStatus() =='optimal':
#     print("out")
#     print(X)
    for i in X:
        OutX[i] = round(model.getVal(X[i]))
#     for i in X:
#         print(i)
# #         for idx11 in Xmax:
# #             print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    liningResult = pd.DataFrame(OutX, index =['尺码件数']).T.rename_axis(['小类','尺码','']).reset_index()
    print(liningResult)

else:
    print("status",'*'*30, model.getStatus())
    print("obj:", model.getObjVal())
    print("gap:", model.getGap())
# Out:
# out
# {('背心', '4XL', '男'): X, ('背心', 'L', '男'): X, ('背心', 'XXL', '女'): X, ('背心', '3XL', '男'): X, ('背心', 'XS', '男'): X, ('背心', 'S', '男'): X, ('背心', '4XS', '男'): X, ('背心', 'XXS', '女'): X, ('背心', '3XS', '男'): X, ('背心', 'XS', '女'): X, ('背心', '7XL', '男'): X, ('背心', '3XL', '女'): X, ('背心', 'L', '女'): X, ('背心', '5XL', '男'): X, ('背心', '8XL', '男'): X, ('背心', 'XL', '男'): X, ('背心', 'M', '男'): X, ('背心', 'XXL', '男'): X, ('背心', '6XL', '男'): X, ('背心', 'XL', '女'): X, ('背心', 'M', '女'): X, ('背心', '4XL', '女'): X, ('背心', 'S', '女'): X, ('背心', 'XXS', '男'): X}
#     小类   尺码     尺码件数
# 0   背心  4XL  男     0
# 1   背心    L  男    18
# 2   背心  XXL  女     0
# 3   背心  3XL  男     6
# 4   背心   XS  男     0
# 5   背心    S  男     5
# 6   背心  4XS  男     0
# 7   背心  XXS  女    72
# 8   背心  3XS  男     0
# 9   背心   XS  女     0
# 10  背心  7XL  男     0
# 11  背心  3XL  女     0
# 12  背心    L  女     0
# 13  背心  5XL  男     0
# 14  背心  8XL  男     0
# 15  背心   XL  男    15
# 16  背心    M  男    17
# 17  背心  XXL  男    11
# 18  背心  6XL  男     0
# 19  背心   XL  女     0
# 20  背心    M  女     0
# 21  背心  4XL  女     0
# 22  背心    S  女     0
# 23  背心  XXS  男     0

# %%
def cal_clothes_model_1(data_result,minput):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size','sex'])
        
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    #     辅助等式  绝对值变量
    for idx in data_result.index.unique():
        print(idx)
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
#     break
    
    dfx = data_result.reset_index('org_id')
    # 决策变量X，每个尺码的件数
    for idx_s in dfx.index.unique(): #class size
        X[idx_s] = model.addVar(vtype="I", name="X")
#         print(idx_s,'**********',X[idx_s])
        
    
    # 设置
    df_s = data_result.reset_index(['size'])  #'class_2','org_id'

    for class_2, org_id in df_s.index.unique():
        #获取 class org ratio的ratio的最大值的尺码
        idx = (class_2, org_id)
        org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']
#         print(org_xmax)
#         print(org_xmax)
        print(idx,'最大尺码-------------', org_xmax)
        po =df_s.loc[[(class_2, org_id)]].reset_index().set_index(['class_2','org_id','size']) #?多了一个index
        for idx in po.index.unique(): #class org size
            myratio = po.loc[idx,'ratio']
            class_2, org_id, size = idx
#             print('-------------org',org_id)
#             print('-------------class size',class_2,size)
#             print('*'*10, idx)
#             print('diff:',diff[idx])
#             print('X[class_2, size]:',X[class_2, size])
#             print('X[class_2, org_max]:', X[class_2, org_max])
        
            model.addCons(diff[idx] == X[class_2, size] - myratio * X[class_2, org_xmax])
            model.addCons(diffabs[idx] >= diff[idx])
            model.addCons(diffabs[idx] >= -1 * diff[idx])
            model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
            model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])  
            
        
    df = data_result.reset_index('size')
#     df_1 = data_result.reset_index(['org_id','size'])
#     for idx in df_1.index.unique():
#         class_2 = idx
#         model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
    #设置目标
    for idx in data_result.index.unique():
#         if data_result.loc[idx,'qty']>0:
#         model.setObjective(diffabs[idx], clear = False)
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)

    
#     for idx in data_result.index.unique():
# #         print('idx*************',idx)
#         myratio = data_result.loc[idx,'ratio']
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio)

#         model.addCons(diffabs[idx] >= diff[idx])
#         model.addCons(diffabs[idx] >= -1 * diff[idx])
#         model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
#         model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
    
    # 约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 获取输出值
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
#         for idx11 in Xmax:
#             print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    return OutX

# %% [markdown]
# ### 数据测试

# %%
# clo_data

# %%
class_arry =class_arry[5:7]

# %%
class_arry

# %%
# clo_data_test = clo_data.loc[clo_data['class_2']=='2合1运动短裤（外-运动短裤/内-紧身长裤）']
# clo_data_test = clo_data_test.reset_index().drop('index',axis=1)

# test = clo_data_test.set_index(['class_2','org_id'])
# for idx in test.index.unique():

# %%
# clo_data= clo_data.loc[clo_data['class_2']=='背心']

# %%
# clo_data

# %%
Clothes_result =pd.DataFrame(columns=('小类','尺码','性别','尺码件数'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
#     print(clo_data_test)
    minput = BoxSize_dict[class_name]['minput']
    print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_1(clo_data_test,minput)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码','']).reset_index()
    print(liningResult)
    Clothes_result = pd.concat([Clothes_result,liningResult],ignore_index=True)

# %%
 data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    #     辅助等式  绝对值变量
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
    
    dfx = data_result.reset_index('org_id')
    # 决策变量X，每个尺码的件数
    for idx_s in dfx.index.unique(): #class size
        X[idx_s] = model.addVar(vtype="I", name="X")
        print(idx_s,'**********',X[idx_s])
        

    # 设置
    df_s = data_result.reset_index(['size'])  #'class_2','org_id'

    for class_2, org_id in df_s.index.unique():
        #获取 class org ratio的ratio的最大值的尺码
        idx = (class_2, org_id)
        org_xmax = df_s.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size']
        print(org_xmax)
#         print(idx,'org_xmax-------------', org_xmax)
        po =df_s.loc[[(class_2, org_id)]].reset_index().set_index(['class_2','org_id','size']) #?多了一个index
        for idx in po.index.unique(): #class org size
            myratio = po.loc[idx,'ratio']
            class_2, org_id, size = idx
#             print('-------------org',org_id)
#             print('-------------class size',class_2,size)
#             print('*'*10, idx)
#             print('diff:',diff[idx])
#             print('X[class_2, size]:',X[class_2, size])
            print('X[class_2, org_max]:', X[class_2, org_max])
        
            model.addCons(diff[idx] == X[class_2, size] - myratio * X[class_2, org_max])
            model.addCons(diffabs[idx] >= diff[idx])
            model.addCons(diffabs[idx] >= -1 * diff[idx])
            model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
            model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])  
            
            
    #辅助变量 max 尺码件数X中的最大值Xmax
#     dfmax = data_result.reset_index(['size','org_id']) 
#     for idx_s in dfx.index.unique():
#         class_2, size = idx_s
#         if class_2 not in Xmax:
#             Xmax[class_2] = model.addVar(vtype ='I', name = "Xmax")
#         bl[idx_s] = model.addVar(vtype="B", name="bl")

#         model.addCons(Xmax[class_2] - X[idx_s] >= 0)
#         model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
#         model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
        
    df = data_result.reset_index('size')
#     df_1 = data_result.reset_index(['org_id','size'])
#     for idx in df_1.index.unique():
#         class_2 = idx
#         model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
    

    
    #设置目标
    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
    
#     for idx in data_result.index.unique():
# #         print('idx*************',idx)
#         myratio = data_result.loc[idx,'ratio']
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio)

#         model.addCons(diffabs[idx] >= diff[idx])
#         model.addCons(diffabs[idx] >= -1 * diff[idx])
#         model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
#         model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
    
    # 约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 获取输出值
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
#         for idx11 in Xmax:
#             print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    
    break

# %%
diff[('2合1运动短裤（外-运动短裤/内-紧身长裤）', 'A12001A', '3XL')]

# %%
# clo_data_test = clo_data.reset_index(['class_2','org_id'])
# for idx in clo_data_test.index.unique():
#     print(idx,'----------------------')
#     print(max(clo_data_test.at[idx,'qty']))
#     for size in clo_data_test.groupby('size').groups:
#         print(org_id,size)
#         clo_data_test.loc[(org_id, size),['qty']].values.ravel()

# clo_data_test.groupby(['class_2','org_id']).rank(ascending=False, method='max')
# df.loc[idx_s, ['size']].values.ravel()
# clo_data_test.loc(['class_2','org_id'])

# %%
# clo_data_test

# %%
clo_data_test = clo_data.loc[clo_data['class_2']=='2合1运动短裤（外-运动短裤/内-紧身长裤）']
# clo_data_test

# %%
# clo_data_test.reset_index(['class_2','org_id'])

# %%
# for class_name in class_arry:
clo_data_test = clo_data.loc[clo_data['class_2']=='2合1运动短裤（外-运动短裤/内-紧身长裤）']
clo_data_test = clo_data_test.reset_index().drop('index',axis=1)

# test = clo_data_test.set_index(['class_2','org_id'])
for idx in test.index.unique():
#     print('class_2 org----------------',idx)
#     class_2, org_id = idx
#     print(max(clo_data_test.at[idx,'qty']))
#     clo_ind = clo_data_test.reset_index(['class_2','org_id','size'])
#     print('-----',test.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1))
#     print('maxL',test.loc[idx].sort_values(by = 'ratio',axis = 0,ascending = False).head(1).loc[idx,'size'])
#     print('maxL',test.loc[idx].sort_values(by = 'qty',axis = 0,ascending = False).head(1).loc[:,'size'])

    print('zuidade xiaosho=====================',(max(test.loc[idx,'ratio'])))
#     print(test.loc[idx])


#     for indx in test.reset_index([idx,'size']).index.unique():
#         print(indx)
        
        
#         print(clo_data_test.at[idx,'qty'])
#         print(indx,'--------qty',clo_ind.loc[indx, 'qty'])
#         print('class org size',indx)
#     print(clo_data_test)
    
#     print(clo_data_test)
#     minput = BoxSize_dict[class_name]['minput']
#     print('boxsize =======================',minput)   
#     class_result = {}
#     class_result = cal_clothes_model_1(clo_data_test,minput)

# %%
# clo_data_test.groupby(['class_2','org_id']).max()

# %%
# for k1,l2,k3 in clo_data_test.groupby(['class_2','size','org_id']):
# #     clo_data_test.loc[idx]
#     print(k1,k2,k3)

# %%
Clothes_result =pd.DataFrame(columns=('小类','尺码','尺码件数'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
#     print(clo_data_test)
    minput = BoxSize_dict[class_name]['minput']
    print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_1(clo_data_test,minput)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码']).reset_index()
    print(liningResult)
    Clothes_result = pd.concat([Clothes_result,liningResult],ignore_index=True)

# %%
# exl_time = dt.datetime.now().strftime('%Y%m%d%H%M')
# locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningClothesResult'+exl_time+'.xlsx'
# Clothes_result.to_excel(locaurl, index = False)
# Clothes_result

# %%
# clo_data

# %% [markdown]
# # Model2

# %%
def cal_clothes_model_2(data_result):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    dfx = data_result.reset_index('org_id')
    
    #决策变量X，每个尺码的比例
    for idx_s in dfx.index.unique():
        X[idx_s] = model.addVar(vtype="C", name="X")
        
    #辅助变量 max 尺码件数X中的最大值Xmax
    dfmax = data_result.reset_index(['size','org_id'])
    
    for idx_s in dfx.index.unique():
        class_2, size = idx_s
        if class_2 not in Xmax:
            Xmax[class_2] = model.addVar(vtype ='C', name = "Xmax")
        bl[idx_s] = model.addVar(vtype="B", name="bl")

        model.addCons(Xmax[class_2] - X[idx_s] >= 0)
        model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
        model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
    
    #辅助等式  绝对值计算 及约束确定
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
#         if myratio!=0:
#             print(idx,'==========',myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
#       diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs', obj = data_result.loc[idx, 'qty'])
    
    #设置目标

    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
#     for idx in data_result.index.unique():
#         model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
# #         model.setObjective(diffabs[idx], clear = False)

    #绝对值
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        class_2, org_id, size = idx
        
#         if myratio!=0:
#             print('==========',myratio)
        model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])

        model.addCons(diffabs[idx] >= diff[idx])
        model.addCons(diffabs[idx] >= -1 * diff[idx])
        model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
        model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
        
        
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])
    
    df = data_result.reset_index('size')
    df_1 = data_result.reset_index(['org_id','size'])
    for idx in df_1.index.unique():
        class_2 = idx
        model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
#     约束： 每个尺码的件数之和 等于 最小装箱数
#     for idx_s in df.index.unique():
#         class_2, org_id = idx_s
#         model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 输出到出X为excle到本地
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
        for idx11 in Xmax:
            print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    return OutX
        
#     print(OutX)
#     print(liningResult)
    
#     return OutX

# %%
# clo_data

# %%
# clo_data2 = clo_data.copy()

# %%
# clo_data2.loc[clo_data2['ratio'] ==0 ,'ratio'] =0.01
# clo_data2.loc[clo_data2['qty'] ==0 ,'qty'] =0.01

# %%
# clo_data2.loc[clo_data2['ratio'],'ratio']
# clo_data2['ratio']= clo_data2['ratio']*100

# %%
# clo_data

# %%
# class_arry1 = class_arry

# %%
# class_arry1

# %%
Clothes_result_2 =pd.DataFrame(columns=('小类','尺码','尺码比例'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
    #     print(clo_data_test)
    #     minput = BoxSize_dict[class_name]['minput']
    #     print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_2(clo_data_test)
    liningResult = pd.DataFrame(class_result, index =['尺码比例']).T.rename_axis(['小类','尺码']).reset_index()
#     liningResult['尺码比例'] = liningResult['尺码比例']/100
    print(liningResult)
    Clothes_result_2 = pd.concat([Clothes_result_2,liningResult],ignore_index=True)

# %%
# Clothes_result_2

# %%
result = pd.merge(Clothes_result, Clothes_result_2, how='right', on=['小类', '尺码'])

# %%
result

# %%
exl_time = dt.datetime.now().strftime('%Y%m%d')
locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningClothesResult555'+exl_time+'.xlsx'
result.to_excel(locaurl, index = False)
