# %%
from pyscipopt import Model,quicksum, multidict
import numpy as np
import pandas as pd
import openpyxl
import datetime as dt
import os

# %%
str1 = os.getcwd()

# %%
str1
# Out:
# 'C:\\Users\\liuju\\Desktop\\readcode'

# %%
data = pd.read_excel(str1+'\\LiNingAllData.xlsx')

# %%
data
# Out:
#       class_0 class_2  size        org_name   org_id  qty     ratio
# 0          服装    1201   3XL  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 1          服装    1201   4XL  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 2          服装    1201     L  大连悦奥体育用品销售有限公司  A21089A    3  1.000000
# 3          服装    1201     M  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 4          服装    1201     S  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 5          服装    1201    XL  大连悦奥体育用品销售有限公司  A21089A    2  0.666667
# 6          服装    1201    XS  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 7          服装    1201   XXL  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 8          服装    1201   XXS  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 9          服装    1201   3XL  南京一动体育用品销售有限公司  A32028A    5  0.156250
# 10         服装    1201   4XL  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 11         服装    1201     L  南京一动体育用品销售有限公司  A32028A   32  1.000000
# 12         服装    1201     M  南京一动体育用品销售有限公司  A32028A   19  0.593750
# 13         服装    1201     S  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 14         服装    1201    XL  南京一动体育用品销售有限公司  A32028A   31  0.968750
# 15         服装    1201    XS  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 16         服装    1201   XXL  南京一动体育用品销售有限公司  A32028A    1  0.031250
# 17         服装    1201   XXS  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 18         服装    1201   3XL    温州一动体育用品有限公司  A33116A    9  0.264706
# 19         服装    1201   4XL    温州一动体育用品有限公司  A33116A    0  0.000000
# 20         服装    1201     L    温州一动体育用品有限公司  A33116A   28  0.823529
# 21         服装    1201     M    温州一动体育用品有限公司  A33116A    9  0.264706
# 22         服装    1201     S    温州一动体育用品有限公司  A33116A    9  0.264706
# 23         服装    1201    XL    温州一动体育用品有限公司  A33116A   34  1.000000
# 24         服装    1201    XS    温州一动体育用品有限公司  A33116A    0  0.000000
# 25         服装    1201   XXL    温州一动体育用品有限公司  A33116A    3  0.088235
# 26         服装    1201   XXS    温州一动体育用品有限公司  A33116A    0  0.000000
# 27         服装    1201   3XL      厦门悦奥商贸有限公司  A35020A    4  0.333333
# 28         服装    1201   4XL      厦门悦奥商贸有限公司  A35020A    0  0.000000
# 29         服装    1201     L      厦门悦奥商贸有限公司  A35020A   12  1.000000
# ...       ...     ...   ...             ...      ...  ...       ...
# 29346       鞋    轻质跑鞋     5  兰州一动体育用品销售有限公司  A62039A    0  0.000000
# 29347       鞋    轻质跑鞋   5.5  兰州一动体育用品销售有限公司  A62039A    5  0.071429
# 29348       鞋    轻质跑鞋     6  兰州一动体育用品销售有限公司  A62039A    4  0.057143
# 29349       鞋    轻质跑鞋   6.5  兰州一动体育用品销售有限公司  A62039A   31  0.442857
# 29350       鞋    轻质跑鞋     7  兰州一动体育用品销售有限公司  A62039A   38  0.542857
# 29351       鞋    轻质跑鞋   7.5  兰州一动体育用品销售有限公司  A62039A   64  0.914286
# 29352       鞋    轻质跑鞋     8  兰州一动体育用品销售有限公司  A62039A   70  1.000000
# 29353       鞋    轻质跑鞋   8.5  兰州一动体育用品销售有限公司  A62039A   30  0.428571
# 29354       鞋    轻质跑鞋     9  兰州一动体育用品销售有限公司  A62039A   49  0.700000
# 29355       鞋    轻质跑鞋   9.5  兰州一动体育用品销售有限公司  A62039A   24  0.342857
# 29356       鞋    轻质跑鞋    10  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29357       鞋    轻质跑鞋  10.5  新疆一动体育用品销售有限公司  A65026A    6  0.125000
# 29358       鞋    轻质跑鞋    11  新疆一动体育用品销售有限公司  A65026A    3  0.062500
# 29359       鞋    轻质跑鞋  11.5  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29360       鞋    轻质跑鞋    12  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29361       鞋    轻质跑鞋  12.5  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29362       鞋    轻质跑鞋    13  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29363       鞋    轻质跑鞋  13.5  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29364       鞋    轻质跑鞋    14  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29365       鞋    轻质跑鞋   4.5  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29366       鞋    轻质跑鞋     5  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29367       鞋    轻质跑鞋   5.5  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29368       鞋    轻质跑鞋     6  新疆一动体育用品销售有限公司  A65026A    0  0.000000
# 29369       鞋    轻质跑鞋   6.5  新疆一动体育用品销售有限公司  A65026A    7  0.145833
# 29370       鞋    轻质跑鞋     7  新疆一动体育用品销售有限公司  A65026A    3  0.062500
# 29371       鞋    轻质跑鞋   7.5  新疆一动体育用品销售有限公司  A65026A   23  0.479167
# 29372       鞋    轻质跑鞋     8  新疆一动体育用品销售有限公司  A65026A   30  0.625000
# 29373       鞋    轻质跑鞋   8.5  新疆一动体育用品销售有限公司  A65026A    1  0.020833
# 29374       鞋    轻质跑鞋     9  新疆一动体育用品销售有限公司  A65026A   48  1.000000
# 29375       鞋    轻质跑鞋   9.5  新疆一动体育用品销售有限公司  A65026A   18  0.375000
#
# [29376 rows x 7 columns]

# %%
shoes_data = data[data['class_0'].isin(['鞋'])]

# %%
shoes_data = shoes_data.drop(['org_name','class_0'],axis=1).reset_index().drop('index',axis=1)

# %%
shoes_data
# Out:
#      class_2  size   org_id   qty     ratio
# 0       减震跑鞋    10  A11001A    45  0.035239
# 1       减震跑鞋  10.5  A11001A   447  0.350039
# 2       减震跑鞋    11  A11001A   144  0.112764
# 3       减震跑鞋  11.5  A11001A     0  0.000000
# 4       减震跑鞋    12  A11001A    89  0.069695
# 5       减震跑鞋  12.5  A11001A     0  0.000000
# 6       减震跑鞋    13  A11001A     0  0.000000
# 7       减震跑鞋  13.5  A11001A     0  0.000000
# 8       减震跑鞋    14  A11001A     0  0.000000
# 9       减震跑鞋   4.5  A11001A     0  0.000000
# 10      减震跑鞋     5  A11001A     1  0.000783
# 11      减震跑鞋   5.5  A11001A    16  0.012529
# 12      减震跑鞋     6  A11001A   169  0.132341
# 13      减震跑鞋   6.5  A11001A   363  0.284260
# 14      减震跑鞋     7  A11001A   116  0.090838
# 15      减震跑鞋   7.5  A11001A  1032  0.808144
# 16      减震跑鞋     8  A11001A  1155  0.904464
# 17      减震跑鞋   8.5  A11001A    49  0.038371
# 18      减震跑鞋     9  A11001A  1277  1.000000
# 19      减震跑鞋   9.5  A11001A   743  0.581832
# 20      减震跑鞋    10  A12001A    27  0.045608
# 21      减震跑鞋  10.5  A12001A   249  0.420608
# 22      减震跑鞋    11  A12001A   128  0.216216
# 23      减震跑鞋  11.5  A12001A     0  0.000000
# 24      减震跑鞋    12  A12001A    41  0.069257
# 25      减震跑鞋  12.5  A12001A     0  0.000000
# 26      减震跑鞋    13  A12001A     0  0.000000
# 27      减震跑鞋  13.5  A12001A     0  0.000000
# 28      减震跑鞋    14  A12001A     0  0.000000
# 29      减震跑鞋   4.5  A12001A     0  0.000000
# ...      ...   ...      ...   ...       ...
# 7612    轻质跑鞋     5  A62039A     0  0.000000
# 7613    轻质跑鞋   5.5  A62039A     5  0.071429
# 7614    轻质跑鞋     6  A62039A     4  0.057143
# 7615    轻质跑鞋   6.5  A62039A    31  0.442857
# 7616    轻质跑鞋     7  A62039A    38  0.542857
# 7617    轻质跑鞋   7.5  A62039A    64  0.914286
# 7618    轻质跑鞋     8  A62039A    70  1.000000
# 7619    轻质跑鞋   8.5  A62039A    30  0.428571
# 7620    轻质跑鞋     9  A62039A    49  0.700000
# 7621    轻质跑鞋   9.5  A62039A    24  0.342857
# 7622    轻质跑鞋    10  A65026A     0  0.000000
# 7623    轻质跑鞋  10.5  A65026A     6  0.125000
# 7624    轻质跑鞋    11  A65026A     3  0.062500
# 7625    轻质跑鞋  11.5  A65026A     0  0.000000
# 7626    轻质跑鞋    12  A65026A     0  0.000000
# 7627    轻质跑鞋  12.5  A65026A     0  0.000000
# 7628    轻质跑鞋    13  A65026A     0  0.000000
# 7629    轻质跑鞋  13.5  A65026A     0  0.000000
# 7630    轻质跑鞋    14  A65026A     0  0.000000
# 7631    轻质跑鞋   4.5  A65026A     0  0.000000
# 7632    轻质跑鞋     5  A65026A     0  0.000000
# 7633    轻质跑鞋   5.5  A65026A     0  0.000000
# 7634    轻质跑鞋     6  A65026A     0  0.000000
# 7635    轻质跑鞋   6.5  A65026A     7  0.145833
# 7636    轻质跑鞋     7  A65026A     3  0.062500
# 7637    轻质跑鞋   7.5  A65026A    23  0.479167
# 7638    轻质跑鞋     8  A65026A    30  0.625000
# 7639    轻质跑鞋   8.5  A65026A     1  0.020833
# 7640    轻质跑鞋     9  A65026A    48  1.000000
# 7641    轻质跑鞋   9.5  A65026A    18  0.375000
#
# [7642 rows x 5 columns]

# %%
class_list = shoes_data['class_2'].drop_duplicates().reset_index().drop('index',axis =1)

# %%
class_arry = class_list['class_2'].values

# %%
class_arry
# Out:
# array(['减震跑鞋', '户外休闲鞋', '潮流休闲鞋', '潮流拖鞋', '灵动跑鞋', '灵活训练鞋', '稳定跑鞋',
#        '篮球专业比赛鞋', '篮球休闲鞋', '篮球场地鞋', '经典休闲鞋', '缓震训练鞋', '羽毛球专业鞋', '羽毛球训练鞋',
#        '街头潮流休闲鞋', '轻质跑鞋'], dtype=object)

# %%
def cal_shoes_model(data_result,minput):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    dfx = data_result.reset_index('org_id')
    # 决策变量X，每个尺码的件数
    for idx_s in dfx.index.unique():
        X[idx_s] = model.addVar(vtype="I", name="X")
    #辅助变量 max 尺码件数X中的最大值Xmax
    dfmax = data_result.reset_index(['size','org_id'])
    
    for idx_s in dfx.index.unique():
        class_2, size = idx_s
        if class_2 not in Xmax:
            Xmax[class_2] = model.addVar(vtype ='I', name = "Xmax")
        bl[idx_s] = model.addVar(vtype="B", name="bl")

        model.addCons(Xmax[class_2] - X[idx_s] >= 0)
        model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
        model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
    
    #辅助等式  绝对值计算 及约束确定
    
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
#         diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs', obj = data_result.loc[idx, 'qty'])
    
    #设置目标
    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)

    for idx in data_result.index.unique():
        class_2, org_id, size = idx
        model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])

        model.addCons(diffabs[idx] >= diff[idx])
        model.addCons(diffabs[idx] >= -1 * diff[idx])
        model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
        model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
    
    df = data_result.reset_index('size')
    df_1 = data_result.reset_index(['org_id','size'])
    for idx in df_1.index.unique():
        class_2 = idx
        model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
    # 约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 输出到出X为excle到本地
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
        break
    return OutX
        
#     print(OutX)
#     print(liningResult)
    
#     return OutX

# %%
def load_shoes_result(result, minput):
    exl_time = dt.datetime.now().strftime('%Y%m%d%H%M')
    locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningShoesResult-'+str(minput)+'双'+exl_time+'.xlsx'
    result.to_excel(locaurl, index = False)
    print('有解，且X已输出到本地')

# %%
shoes_result6 =pd.DataFrame(columns=('小类','尺码','尺码件数'))
shoes_result12 =pd.DataFrame(columns=('小类','尺码','尺码件数'))

minput12 = 12
minput6 = 6

for class_name in class_arry:
    shoes_data_test12 = shoes_data.loc[shoes_data['class_2']== class_name]
    shoes_data_test12 = shoes_data_test12.reset_index().drop('index',axis=1)
   
    class_result = {}
    class_result = cal_shoes_model(shoes_data_test12,minput12)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码']).reset_index()
    shoes_result12 = pd.concat([shoes_result12,liningResult],ignore_index=True)
load_shoes_result(shoes_result12,minput12)
# Out:
# 有解，且X已输出到本地

# %%
for class_name in class_arry:
    shoes_data_test = shoes_data.loc[shoes_data['class_2']== class_name]
    shoes_data_test = shoes_data_test.reset_index().drop('index',axis=1)
    class_result = {}
    class_result = cal_shoes_model(shoes_data_test,minput6)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码']).reset_index()
    shoes_result6 = pd.concat([shoes_result6,liningResult],ignore_index=True)
load_shoes_result(shoes_result6, minput6)
# Out:
# 有解，且X已输出到本地

# %%
shoes_result6
# Out:
#        小类    尺码 尺码件数
# 0    轻质跑鞋  10.0    0
# 1    轻质跑鞋  10.5    0
# 2    轻质跑鞋  11.0    0
# 3    轻质跑鞋  11.5    1
# 4    轻质跑鞋  12.0    0
# 5    轻质跑鞋  12.5    1
# 6    轻质跑鞋  13.0    1
# 7    轻质跑鞋  13.5    1
# 8    轻质跑鞋  14.0    1
# 9    轻质跑鞋   4.5    1
# 10   轻质跑鞋   5.0    0
# 11   轻质跑鞋   5.5    0
# 12   轻质跑鞋   6.0    0
# 13   轻质跑鞋   6.5    0
# 14   轻质跑鞋   7.0    0
# 15   轻质跑鞋   7.5    0
# 16   轻质跑鞋   8.0    0
# 17   轻质跑鞋   8.5    0
# 18   轻质跑鞋   9.0    0
# 19   轻质跑鞋   9.5    0
# 20   轻质跑鞋  10.0    0
# 21   轻质跑鞋  10.5    0
# 22   轻质跑鞋  11.0    0
# 23   轻质跑鞋  11.5    1
# 24   轻质跑鞋  12.0    0
# 25   轻质跑鞋  12.5    1
# 26   轻质跑鞋  13.0    1
# 27   轻质跑鞋  13.5    1
# 28   轻质跑鞋  14.0    1
# 29   轻质跑鞋   4.5    1
# ..    ...   ...  ...
# 290  轻质跑鞋   5.0    0
# 291  轻质跑鞋   5.5    0
# 292  轻质跑鞋   6.0    0
# 293  轻质跑鞋   6.5    0
# 294  轻质跑鞋   7.0    0
# 295  轻质跑鞋   7.5    0
# 296  轻质跑鞋   8.0    0
# 297  轻质跑鞋   8.5    0
# 298  轻质跑鞋   9.0    0
# 299  轻质跑鞋   9.5    0
# 300  轻质跑鞋  10.0    0
# 301  轻质跑鞋  10.5    0
# 302  轻质跑鞋  11.0    0
# 303  轻质跑鞋  11.5    1
# 304  轻质跑鞋  12.0    0
# 305  轻质跑鞋  12.5    1
# 306  轻质跑鞋  13.0    1
# 307  轻质跑鞋  13.5    1
# 308  轻质跑鞋  14.0    1
# 309  轻质跑鞋   4.5    1
# 310  轻质跑鞋   5.0    0
# 311  轻质跑鞋   5.5    0
# 312  轻质跑鞋   6.0    0
# 313  轻质跑鞋   6.5    0
# 314  轻质跑鞋   7.0    0
# 315  轻质跑鞋   7.5    0
# 316  轻质跑鞋   8.0    0
# 317  轻质跑鞋   8.5    0
# 318  轻质跑鞋   9.0    0
# 319  轻质跑鞋   9.5    0
#
# [320 rows x 3 columns]

# %%
shoes_result12
# Out:
#           小类    尺码 尺码件数
# 0       减震跑鞋    10    1
# 1       减震跑鞋  10.5    1
# 2       减震跑鞋    11    2
# 3       减震跑鞋  11.5    0
# 4       减震跑鞋    12    0
# 5       减震跑鞋  12.5    0
# 6       减震跑鞋    13    0
# 7       减震跑鞋  13.5    0
# 8       减震跑鞋    14    0
# 9       减震跑鞋   4.5    0
# 10      减震跑鞋     5    0
# 11      减震跑鞋   5.5    0
# 12      减震跑鞋     6    1
# 13      减震跑鞋   6.5    1
# 14      减震跑鞋     7    1
# 15      减震跑鞋   7.5    1
# 16      减震跑鞋     8    1
# 17      减震跑鞋   8.5    1
# 18      减震跑鞋     9    1
# 19      减震跑鞋   9.5    1
# 20     户外休闲鞋    10    1
# 21     户外休闲鞋  10.5    1
# 22     户外休闲鞋    11    1
# 23     户外休闲鞋   4.5    0
# 24     户外休闲鞋     5    0
# 25     户外休闲鞋   5.5    0
# 26     户外休闲鞋     6    2
# 27     户外休闲鞋   6.5    1
# 28     户外休闲鞋     7    1
# 29     户外休闲鞋   7.5    1
# ..       ...   ...  ...
# 304  街头潮流休闲鞋    11    4
# 305  街头潮流休闲鞋     5    1
# 306  街头潮流休闲鞋     6    1
# 307  街头潮流休闲鞋   6.5    1
# 308  街头潮流休闲鞋     7    1
# 309  街头潮流休闲鞋   7.5    1
# 310  街头潮流休闲鞋     8    1
# 311  街头潮流休闲鞋   8.5    0
# 312  街头潮流休闲鞋     9    1
# 313  街头潮流休闲鞋   9.5    1
# 314     轻质跑鞋    10    0
# 315     轻质跑鞋  10.5    1
# 316     轻质跑鞋    11    0
# 317     轻质跑鞋  11.5    0
# 318     轻质跑鞋    12    0
# 319     轻质跑鞋  12.5    0
# 320     轻质跑鞋    13    0
# 321     轻质跑鞋  13.5    0
# 322     轻质跑鞋    14    3
# 323     轻质跑鞋   4.5    0
# 324     轻质跑鞋     5    0
# 325     轻质跑鞋   5.5    0
# 326     轻质跑鞋     6    1
# 327     轻质跑鞋   6.5    1
# 328     轻质跑鞋     7    1
# 329     轻质跑鞋   7.5    1
# 330     轻质跑鞋     8    1
# 331     轻质跑鞋   8.5    1
# 332     轻质跑鞋     9    1
# 333     轻质跑鞋   9.5    1
#
# [334 rows x 3 columns]

# %%
result = pd.merge(shoes_result6, shoes_result12, how='right', on=['小类', '尺码'])

# %%
result
# Out:
#           小类    尺码 尺码件数_x 尺码件数_y
# 0       轻质跑鞋    10      0      0
# 1       轻质跑鞋    10      0      0
# 2       轻质跑鞋    10      0      0
# 3       轻质跑鞋    10      0      0
# 4       轻质跑鞋    10      0      0
# 5       轻质跑鞋    10      0      0
# 6       轻质跑鞋    10      0      0
# 7       轻质跑鞋    10      0      0
# 8       轻质跑鞋    10      0      0
# 9       轻质跑鞋    10      0      0
# 10      轻质跑鞋    10      0      0
# 11      轻质跑鞋    10      0      0
# 12      轻质跑鞋    10      0      0
# 13      轻质跑鞋    10      0      0
# 14      轻质跑鞋    10      0      0
# 15      轻质跑鞋    10      0      0
# 16      轻质跑鞋  10.5      0      1
# 17      轻质跑鞋  10.5      0      1
# 18      轻质跑鞋  10.5      0      1
# 19      轻质跑鞋  10.5      0      1
# 20      轻质跑鞋  10.5      0      1
# 21      轻质跑鞋  10.5      0      1
# 22      轻质跑鞋  10.5      0      1
# 23      轻质跑鞋  10.5      0      1
# 24      轻质跑鞋  10.5      0      1
# 25      轻质跑鞋  10.5      0      1
# 26      轻质跑鞋  10.5      0      1
# 27      轻质跑鞋  10.5      0      1
# 28      轻质跑鞋  10.5      0      1
# 29      轻质跑鞋  10.5      0      1
# ..       ...   ...    ...    ...
# 604   羽毛球训练鞋    12    NaN      0
# 605   羽毛球训练鞋  12.5    NaN      0
# 606   羽毛球训练鞋    13    NaN      0
# 607   羽毛球训练鞋  13.5    NaN      0
# 608   羽毛球训练鞋    14    NaN      0
# 609   羽毛球训练鞋     2    NaN      0
# 610   羽毛球训练鞋     3    NaN      0
# 611   羽毛球训练鞋     4    NaN      0
# 612   羽毛球训练鞋   4.5    NaN      0
# 613   羽毛球训练鞋     5    NaN      1
# 614   羽毛球训练鞋   5.5    NaN      1
# 615   羽毛球训练鞋     6    NaN      1
# 616   羽毛球训练鞋   6.5    NaN      1
# 617   羽毛球训练鞋     7    NaN      1
# 618   羽毛球训练鞋   7.5    NaN      1
# 619   羽毛球训练鞋     8    NaN      1
# 620   羽毛球训练鞋   8.5    NaN      1
# 621   羽毛球训练鞋     9    NaN      1
# 622   羽毛球训练鞋   9.5    NaN      1
# 623  街头潮流休闲鞋    10    NaN      0
# 624  街头潮流休闲鞋    11    NaN      4
# 625  街头潮流休闲鞋     5    NaN      1
# 626  街头潮流休闲鞋     6    NaN      1
# 627  街头潮流休闲鞋   6.5    NaN      1
# 628  街头潮流休闲鞋     7    NaN      1
# 629  街头潮流休闲鞋   7.5    NaN      1
# 630  街头潮流休闲鞋     8    NaN      1
# 631  街头潮流休闲鞋   8.5    NaN      0
# 632  街头潮流休闲鞋     9    NaN      1
# 633  街头潮流休闲鞋   9.5    NaN      1
#
# [634 rows x 4 columns]

# %%
exl_time = dt.datetime.now().strftime('%Y%m%d%H%M')
locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningShoesResult-6&12双'+exl_time+'.xlsx'
result.to_excel(locaurl, index = False)
