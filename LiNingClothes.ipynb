# %%
from pyscipopt import Model,quicksum, multidict
import numpy as np
import pandas as pd
import openpyxl
import datetime as dt
import os

# %%
ospwd = os.getcwd()

# %%
data = pd.read_excel(ospwd+'\\LiNingAllData.xlsx')

# %%
# data

# %%
clo_data = data[data['class_0'].isin(['服装'])]

# %%
clo_data
# Out:
#       class_0 class_2 size        org_name   org_id  qty     ratio
# 0          服装    1201  3XL  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 1          服装    1201  4XL  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 2          服装    1201    L  大连悦奥体育用品销售有限公司  A21089A    3  1.000000
# 3          服装    1201    M  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 4          服装    1201    S  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 5          服装    1201   XL  大连悦奥体育用品销售有限公司  A21089A    2  0.666667
# 6          服装    1201   XS  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 7          服装    1201  XXL  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 8          服装    1201  XXS  大连悦奥体育用品销售有限公司  A21089A    0  0.000000
# 9          服装    1201  3XL  南京一动体育用品销售有限公司  A32028A    5  0.156250
# 10         服装    1201  4XL  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 11         服装    1201    L  南京一动体育用品销售有限公司  A32028A   32  1.000000
# 12         服装    1201    M  南京一动体育用品销售有限公司  A32028A   19  0.593750
# 13         服装    1201    S  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 14         服装    1201   XL  南京一动体育用品销售有限公司  A32028A   31  0.968750
# 15         服装    1201   XS  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 16         服装    1201  XXL  南京一动体育用品销售有限公司  A32028A    1  0.031250
# 17         服装    1201  XXS  南京一动体育用品销售有限公司  A32028A    0  0.000000
# 18         服装    1201  3XL    温州一动体育用品有限公司  A33116A    9  0.264706
# 19         服装    1201  4XL    温州一动体育用品有限公司  A33116A    0  0.000000
# 20         服装    1201    L    温州一动体育用品有限公司  A33116A   28  0.823529
# 21         服装    1201    M    温州一动体育用品有限公司  A33116A    9  0.264706
# 22         服装    1201    S    温州一动体育用品有限公司  A33116A    9  0.264706
# 23         服装    1201   XL    温州一动体育用品有限公司  A33116A   34  1.000000
# 24         服装    1201   XS    温州一动体育用品有限公司  A33116A    0  0.000000
# 25         服装    1201  XXL    温州一动体育用品有限公司  A33116A    3  0.088235
# 26         服装    1201  XXS    温州一动体育用品有限公司  A33116A    0  0.000000
# 27         服装    1201  3XL      厦门悦奥商贸有限公司  A35020A    4  0.333333
# 28         服装    1201  4XL      厦门悦奥商贸有限公司  A35020A    0  0.000000
# 29         服装    1201    L      厦门悦奥商贸有限公司  A35020A   12  1.000000
# ...       ...     ...  ...             ...      ...  ...       ...
# 21704      服装   长袖紧身衣   XS  西安一动体育用品销售有限公司  A61010A    0  0.000000
# 21705      服装   长袖紧身衣  XXL  西安一动体育用品销售有限公司  A61010A    3  0.333333
# 21706      服装   长袖紧身衣  135  兰州一动体育用品销售有限公司  A62039A    0  0.000000
# 21707      服装   长袖紧身衣  140  兰州一动体育用品销售有限公司  A62039A    0  0.000000
# 21708      服装   长袖紧身衣  150  兰州一动体育用品销售有限公司  A62039A    0  0.000000
# 21709      服装   长袖紧身衣  160  兰州一动体育用品销售有限公司  A62039A    0  0.000000
合1运动短裤（外-运动短裤/内-紧身长裤）  XXL  A21001A    0  0.000000
# 14     2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL  A23048A    0  0.000000
# 15     2合1运动短裤（外-运动短裤/内-紧身长裤）    L  A23048A    2  1.000000
# 16     2合1运动短裤（外-运动短裤/内-紧身长裤）    M  A23048A    0  0.000000
# 17     2合1运动短裤（外-运动短裤/内-紧身长裤）    S  A23048A    0  0.000000
# 18     2合1运动短裤（外-运动短裤/内-紧身长裤）   XL  A23048A    1  0.500000
# 19     2合1运动短裤（外-运动短裤/内-紧身长裤）   XS  A23048A    0  0.000000
# 20     2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL  A23048A    0  0.000000
# 21     2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL  A31002A    0  0.000000
# 22     2合1运动短裤（外-运动短裤/内-紧身长裤）    L  A31002A    1  0.200000
# 23     2合1运动短裤（外-运动短裤/内-紧身长裤）    M  A31002A    5  1.000000
# 24     2合1运动短裤（外-运动短裤/内-紧身长裤）    S  A31002A    3  0.600000
# 25     2合1运动短裤（外-运动短裤/内-紧身长裤）   XL  A31002A    0  0.000000
# 26     2合1运动短裤（外-运动短裤/内-紧身长裤）   XS  A31002A    0  0.000000
# 27     2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL  A31002A    0  0.000000
# 28     2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL  A34037A    0  0.000000
# 29     2合1运动短裤（外-运动短裤/内-紧身长裤）    L  A34037A    0  0.000000
# ...                       ...  ...      ...  ...       ...
# 21623                   长袖紧身衣   XS  A61010A    0  0.000000
# 21624                   长袖紧身衣  XXL  A61010A    3  0.333333
# 21625                   长袖紧身衣  135  A62039A    0  0.000000
# 21626                   长袖紧身衣  140  A62039A    0  0.000000
# 21627                   长袖紧身衣  150  A62039A    0  0.000000
# 21628                   长袖紧身衣  160  A62039A    0  0.000000
# 21629                   长袖紧身衣  170  A62039A    0  0.000000
# 21630                   长袖紧身衣  175  A62039A    0  0.000000
# 21631                   长袖紧身衣  3XL  A62039A    1  0.037037
# 21632                   长袖紧身衣  4XL  A62039A    0  0.000000
# 21633                   长袖紧身衣    L  A62039A   27  1.000000
# 21634                   长袖紧身衣    M  A62039A   14  0.518519
# 21635                   长袖紧身衣    S  A62039A    2  0.074074
# 21636                   长袖紧身衣   XL  A62039A   23  0.851852
# 21637                   长袖紧身衣   XS  A62039A    0  0.000000
# 21638                   长袖紧身衣  XXL  A62039A    3  0.111111
# 21639                   长袖紧身衣  135  A65026A    0  0.000000
# 21640                   长袖紧身衣  140  A65026A    0  0.000000
# 21641                   长袖紧身衣  150  A65026A    0  0.000000
# 21642                   长袖紧身衣  160  A65026A    0  0.000000
# 21643                   长袖紧身衣  170  A65026A    0  0.000000
# 21644                   长袖紧身衣  175  A65026A    0  0.000000
# 21645                   长袖紧身衣  3XL  A65026A    0  0.000000
# 21646                   长袖紧身衣  4XL  A65026A    0  0.000000
# 21647                   长袖紧身衣    L  A65026A   20  1.000000
# 21648                   长袖紧身衣    M  A65026A    3  0.150000
# 21649                   长袖紧身衣    S  A65026A    0  0.000000
# 21650                   长袖紧身衣   XL  A65026A   13  0.650000
# 21651                   长袖紧身衣   XS  A65026A    0  0.000000
# 21652                   长袖紧身衣  XXL  A65026A   13  0.650000
#
# [21653 rows x 5 columns]

# %%
class_list = clo_data['class_2'].drop_duplicates().reset_index().drop('index',axis =1)

# %%
class_arry = class_list['class_2'].values

# %%
class_arry
# Out:
# array(['2合1运动短裤（外-运动短裤/内-紧身长裤）', '三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)',
#        '三合一(内-短棉服/外-运动风衣)', '三合一(内-紧身运动长裤/外-运动短裤)', '中棉服', '中羽绒服', '九分卫裤',
#        '休闲外套', '休闲长裤', '卫裤', '夹克', '套头无帽卫衣', '套头无帽编织衫', '套头连帽卫衣',
#        '开衫无帽卫衣', '开衫无帽卫衣套装', '开衫无帽编织衫', '开衫连帽卫衣', '开衫连帽摇粒绒卫衣', '拼接休闲裤',
#        '拼接卫裤', '拼接套头无帽卫衣', '拼接棉茄克', '拼接紧身运动长裤', '棉夹克', '比赛上衣', '比赛裤',
#        '短棉服', '短羽绒服', '短袖Polo', '短袖T恤', '短袖文化衫', '紧身运动长裤', '羽绒马甲', '背心',
#        '裤裙', '软壳长裤', '运动文胸', '运动短裤', '运动长裤', '运动风衣', '连衣裙', '速干长裤',
#        '针织休闲裤', '针织外套', '针织运动上衣', '针织运动裤', '针织长袖衫', '针织阔腿裤', '长棉服',
#        '长羽绒服', '长袖Polo', '长袖T恤', '长袖套头衫', '长袖文化衫', '长袖紧身衣'], dtype=object)

# %%
len(class_arry) #删除了1201
# Out:
# 56

# %%
#获取尺码数量
# ospwd

# %%
BoxSize = pd.read_excel(ospwd+'\\ClothesSize.xlsx')

# %%
BoxSize = BoxSize.dropna().reset_index().drop('index',axis=1).rename(columns = {'小类':'class_2','装箱量加权平均值':'minput'})

# %%
BoxSize
# Out:
#                     class_2     minput
# 0    2合1运动短裤（外-运动短裤/内-紧身长裤）  55.953562
# 1   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  11.167741
# 2         三合一(内-短棉服/外-运动风衣)  11.167741
# 3      三合一(内-紧身运动长裤/外-运动短裤)  11.167741
# 4                       中棉服  11.023791
# 5                      中羽绒服  11.059041
# 6                      九分卫裤  26.937490
# 7                      休闲外套  39.197556
# 8                      休闲长裤  39.188529
# 9                        卫裤  26.937490
# 10                       夹克  27.643893
# 11                   套头无帽卫衣  24.371965
# 12                  套头无帽编织衫  20.000000
# 13                   套头连帽卫衣  24.371965
# 14                   开衫无帽卫衣  24.371965
# 15                 开衫无帽卫衣套装  10.240065
# 16                  开衫无帽编织衫  20.000000
# 17                   开衫连帽卫衣  24.371965
# 18                开衫连帽摇粒绒卫衣  24.371965
# 19                    拼接休闲裤  39.188529
# 20                     拼接卫裤  26.937490
# 21                 拼接套头无帽卫衣  24.371965
# 22                    拼接棉茄克  10.708597
# 23                 拼接紧身运动长裤  65.281484
# 24                      棉夹克  10.708597
# 25                     比赛上衣  50.596607
# 26                      比赛裤  46.362309
# 27                      短棉服  10.708597
# 28                     短羽绒服  11.059041
# 29                   短袖Polo  50.708371
# 30                     短袖T恤  69.012823
# 31                    短袖文化衫  55.557254
# 32                   紧身运动长裤  65.281484
# 33                     羽绒马甲  21.233062
# 34                       背心  72.407714
# 35                       裤裙  32.529149
# 36                     软壳长裤  20.000000
# 37                     运动文胸  37.514165
# 38                     运动短裤  55.953562
# 39                     运动长裤  47.824487
# 40                     运动风衣  39.197556
# 41                      连衣裙  32.529149
# 42                     速干长裤  46.527816
# 43                    针织休闲裤  39.188529
# 44                     针织外套  39.197556
# 45                   针织运动上衣  24.371965
# 46                    针织运动裤  43.178671
# 47                    针织长袖衫  24.371965
# 48                    针织阔腿裤  26.937490
# 49                      长棉服  11.023791
# 50                     长羽绒服  11.059041
# 51                   长袖Polo  50.708371
# 52                     长袖T恤  44.428070
# 53                    长袖套头衫  50.000000
# 54                    长袖文化衫  55.557254
# 55                    长袖紧身衣  71.634287

# %%
BoxSize['minput'] = (BoxSize['minput']).apply(np.round)

# %%
# BoxSize

# %%
BoxSize_dict = BoxSize.set_index('class_2').T.to_dict()
# BoxSize_dict = BoxSize.set_index('class_2').to_dict()

# %%
BoxSize_dict
# Out:
# {'2合1运动短裤（外-运动短裤/内-紧身长裤）': {'minput': 56.0},
#  '三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)': {'minput': 11.0},
#  '三合一(内-短棉服/外-运动风衣)': {'minput': 11.0},
#  '三合一(内-紧身运动长裤/外-运动短裤)': {'minput': 11.0},
#  '中棉服': {'minput': 11.0},
#  '中羽绒服': {'minput': 11.0},
#  '九分卫裤': {'minput': 27.0},
#  '休闲外套': {'minput': 39.0},
#  '休闲长裤': {'minput': 39.0},
#  '卫裤': {'minput': 27.0},
#  '夹克': {'minput': 28.0},
#  '套头无帽卫衣': {'minput': 24.0},
#  '套头无帽编织衫': {'minput': 20.0},
#  '套头连帽卫衣': {'minput': 24.0},
#  '开衫无帽卫衣': {'minput': 24.0},
#  '开衫无帽卫衣套装': {'minput': 10.0},
#  '开衫无帽编织衫': {'minput': 20.0},
#  '开衫连帽卫衣': {'minput': 24.0},
#  '开衫连帽摇粒绒卫衣': {'minput': 24.0},
#  '拼接休闲裤': {'minput': 39.0},
#  '拼接卫裤': {'minput': 27.0},
#  '拼接套头无帽卫衣': {'minput': 24.0},
#  '拼接棉茄克': {'minput': 11.0},
#  '拼接紧身运动长裤': {'minput': 65.0},
#  '棉夹克': {'minput': 11.0},
#  '比赛上衣': {'minput': 51.0},
#  '比赛裤': {'minput': 46.0},
#  '短棉服': {'minput': 11.0},
#  '短羽绒服': {'minput': 11.0},
#  '短袖Polo': {'minput': 51.0},
#  '短袖T恤': {'minput': 69.0},
#  '短袖文化衫': {'minput': 56.0},
#  '紧身运动长裤': {'minput': 65.0},
#  '羽绒马甲': {'minput': 21.0},
#  '背心': {'minput': 72.0},
#  '裤裙': {'minput': 33.0},
#  '软壳长裤': {'minput': 20.0},
#  '运动文胸': {'minput': 38.0},
#  '运动短裤': {'minput': 56.0},
#  '运动长裤': {'minput': 48.0},
#  '运动风衣': {'minput': 39.0},
#  '连衣裙': {'minput': 33.0},
#  '速干长裤': {'minput': 47.0},
#  '针织休闲裤': {'minput': 39.0},
#  '针织外套': {'minput': 39.0},
#  '针织运动上衣': {'minput': 24.0},
#  '针织运动裤': {'minput': 43.0},
#  '针织长袖衫': {'minput': 24.0},
#  '针织阔腿裤': {'minput': 27.0},
#  '长棉服': {'minput': 11.0},
#  '长羽绒服': {'minput': 11.0},
#  '长袖Polo': {'minput': 51.0},
#  '长袖T恤': {'minput': 44.0},
#  '长袖套头衫': {'minput': 50.0},
#  '长袖文化衫': {'minput': 56.0},
#  '长袖紧身衣': {'minput': 72.0}}

# %%
def cal_clothes_model_1(data_result,minput):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    dfx = data_result.reset_index('org_id')
    # 决策变量X，每个尺码的件数
    for idx_s in dfx.index.unique():
        X[idx_s] = model.addVar(vtype="I", name="X")
    #辅助变量 max 尺码件数X中的最大值Xmax
    dfmax = data_result.reset_index(['size','org_id'])
    
    for idx_s in dfx.index.unique():
        class_2, size = idx_s
        if class_2 not in Xmax:
            Xmax[class_2] = model.addVar(vtype ='I', name = "Xmax")
        bl[idx_s] = model.addVar(vtype="B", name="bl")

        model.addCons(Xmax[class_2] - X[idx_s] >= 0)
        model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
        model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
    
    #辅助等式  绝对值计算 及约束确定
    
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
#         diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs', obj = data_result.loc[idx, 'qty'])
    
    #设置目标
    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)

    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        class_2, org_id, size = idx
        model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])

        model.addCons(diffabs[idx] >= diff[idx])
        model.addCons(diffabs[idx] >= -1 * diff[idx])
        model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
        model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
    
    df = data_result.reset_index('size')
    df_1 = data_result.reset_index(['org_id','size'])
    for idx in df_1.index.unique():
        class_2 = idx
        model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
    # 约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == minput)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 输出到出X为excle到本地
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
        for idx11 in Xmax:
            print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    return OutX
        
#     print(OutX)
#     print(liningResult)
    
#     return OutX

# %%
# class_arry =class_arry[0:2]

# %%
class_arry
# Out:
# array(['2合1运动短裤（外-运动短裤/内-紧身长裤）', '三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)',
#        '三合一(内-短棉服/外-运动风衣)', '三合一(内-紧身运动长裤/外-运动短裤)', '中棉服', '中羽绒服', '九分卫裤',
#        '休闲外套', '休闲长裤', '卫裤', '夹克', '套头无帽卫衣', '套头无帽编织衫', '套头连帽卫衣',
#        '开衫无帽卫衣', '开衫无帽卫衣套装', '开衫无帽编织衫', '开衫连帽卫衣', '开衫连帽摇粒绒卫衣', '拼接休闲裤',
#        '拼接卫裤', '拼接套头无帽卫衣', '拼接棉茄克', '拼接紧身运动长裤', '棉夹克', '比赛上衣', '比赛裤',
#        '短棉服', '短羽绒服', '短袖Polo', '短袖T恤', '短袖文化衫', '紧身运动长裤', '羽绒马甲', '背心',
#        '裤裙', '软壳长裤', '运动文胸', '运动短裤', '运动长裤', '运动风衣', '连衣裙', '速干长裤',
#        '针织休闲裤', '针织外套', '针织运动上衣', '针织运动裤', '针织长袖衫', '针织阔腿裤', '长棉服',
#        '长羽绒服', '长袖Polo', '长袖T恤', '长袖套头衫', '长袖文化衫', '长袖紧身衣'], dtype=object)

# %%
Clothes_result =pd.DataFrame(columns=('小类','尺码','尺码件数'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
#     print(clo_data_test)
    minput = BoxSize_dict[class_name]['minput']
    print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_1(clo_data_test,minput)
    liningResult = pd.DataFrame(class_result, index =['尺码件数']).T.rename_axis(['小类','尺码']).reset_index()
    print(liningResult)
    Clothes_result = pd.concat([Clothes_result,liningResult],ignore_index=True)
# Out:
# boxsize ======================= 56.0
# Xmax-- 2合1运动短裤（外-运动短裤/内-紧身长裤） =  8.999999999999963 ======
#                        小类   尺码  尺码件数
# 0  2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL     9
# 1  2合1运动短裤（外-运动短裤/内-紧身长裤）    L     9
# 2  2合1运动短裤（外-运动短裤/内-紧身长裤）    M     9
# 3  2合1运动短裤（外-运动短裤/内-紧身长裤）    S     6
# 4  2合1运动短裤（外-运动短裤/内-紧身长裤）   XL     5
# 5  2合1运动短裤（外-运动短裤/内-紧身长裤）   XS     9
# 6  2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL     9
# boxsize ======================= 11.0
# Xmax-- 三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣) =  1.0 ======
#                          小类   尺码  尺码件数
# 0   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  110     1
# 1   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  120     1
# 2   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  130     1
# 3   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  140     1
# 4   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  150     0
# 5   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  160     1
# 6   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  165     0
# 7   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  170     0
# 8   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  175     1
# 9   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  3XL     0
# 10  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  4XL     0
# 11  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    L     1
# 12  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    M     1
# 13  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    S     0
# 14  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XL     1
# 15  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XS     1
# 16  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  XXL     1
# boxsize ======================= 11.0
# Xmax-- 三合一(内-短棉服/外-运动风衣) =  2.0 ======
#                    小类   尺码  尺码件数
# 0   三合一(内-短棉服/外-运动风衣)  110     0
# 1   三合一(内-短棉服/外-运动风衣)  120     0
# 2   三合一(内-短棉服/外-运动风衣)  130     0
# 3   三合一(内-短棉服/外-运动风衣)  140     0
# 4   三合一(内-短棉服/外-运动风衣)  150     0
# 5   三合一(内-短棉服/外-运动风衣)  160     1
# 6   三合一(内-短棉服/外-运动风衣)  165     2
# 7   三合一(内-短棉服/外-运动风衣)  170     1
# 8   三合一(内-短棉服/外-运动风衣)  175     0
# 9   三合一(内-短棉服/外-运动风衣)  3XL     0
# 10  三合一(内-短棉服/外-运动风衣)  4XL     1
# 11  三合一(内-短棉服/外-运动风衣)    L     2
# 12  三合一(内-短棉服/外-运动风衣)    M     1
# 13  三合一(内-短棉服/外-运动风衣)    S     1
# 14  三合一(内-短棉服/外-运动风衣)   XL     1
# 15  三合一(内-短棉服/外-运动风衣)   XS     1
# 16  三合一(内-短棉服/外-运动风衣)  XXL     0
# boxsize ======================= 11.0
# Xmax-- 三合一(内-紧身运动长裤/外-运动短裤) =  3.0000000000000075 ======
#                      小类   尺码  尺码件数
# 0  三合一(内-紧身运动长裤/外-运动短裤)    L     2
# 1  三合一(内-紧身运动长裤/外-运动短裤)    M     3
# 2  三合一(内-紧身运动长裤/外-运动短裤)    S     2
# 3  三合一(内-紧身运动长裤/外-运动短裤)   XL     0
# 4  三合一(内-紧身运动长裤/外-运动短裤)   XS     1
# 5  三合一(内-紧身运动长裤/外-运动短裤)  XXL     3
# boxsize ======================= 11.0
# Xmax-- 中棉服 =  0.9999999999999999 ======
#      小类   尺码  尺码件数
# 0   中棉服  100     1
# 1   中棉服  110     0
# 2   中棉服  115     0
# 3   中棉服  120     0
# 4   中棉服  125     1
# 5   中棉服  130     0
# 6   中棉服  135     0
# 7   中棉服  140     0
# 8   中棉服  145     0
# 9   中棉服  150     0
# 10  中棉服  155     0
# 11  中棉服  160     0
# 12  中棉服  165     1
# 13  中棉服  170     1
# 14  中棉服  175     1
# 15  中棉服  180     1
# 16  中棉服  185     1
# 17  中棉服  190     0
# 18  中棉服  195     0
# 19  中棉服  200     0
# 20  中棉服  205     0
# 21  中棉服  210     0
# 22  中棉服  215     0
# 23  中棉服  220     0
# 24  中棉服  3XL     0
# 25  中棉服  4XL     0
# 26  中棉服  5XL     0
# 27  中棉服   60     0
# 28  中棉服   70     0
# 29  中棉服   80     0
# 30  中棉服   90     0
# 31  中棉服    L     1
# 32  中棉服    M     1
# 33  中棉服    S     0
# 34  中棉服   XL     1
# 35  中棉服   XS     0
# 36  中棉服  XXL     1
# 37  中棉服  XXS     0
# boxsize ======================= 11.0
# Xmax-- 中羽绒服 =  1.0 ======
#       小类   尺码  尺码件数
# 0   中羽绒服  100     0
# 1   中羽绒服  110     0
# 2   中羽绒服  115     0
# 3   中羽绒服  120     0
# 4   中羽绒服  125     0
# 5   中羽绒服  130     0
# 6   中羽绒服  135     0
# 7   中羽绒服  140     0
# 8   中羽绒服  145     0
# 9   中羽绒服  150     0
# 10  中羽绒服  155     0
# 11  中羽绒服  160     0
# 12  中羽绒服  165     1
# 13  中羽绒服  170     0
# 14  中羽绒服  175     0
# 15  中羽绒服  180     1
# 16  中羽绒服  185     1
# 17  中羽绒服  190     1
# 18  中羽绒服  195     1
# 19  中羽绒服  200     1
# 20  中羽绒服  205     1
# 21  中羽绒服  210     0
# 22  中羽绒服  215     0
# 23  中羽绒服  220     0
# 24  中羽绒服  3XL     0
# 25  中羽绒服  4XL     0
# 26  中羽绒服  5XL     0
# 27  中羽绒服   60     0
# 28  中羽绒服  6XL     0
# 29  中羽绒服   70     0
# 30  中羽绒服  7XL     0
# 31  中羽绒服   80     0
# 32  中羽绒服  8XL     0
# 33  中羽绒服   90     0
# 34  中羽绒服    L     1
# 35  中羽绒服    M     1
# 36  中羽绒服    S     0
# 37  中羽绒服   XL     1
# 38  中羽绒服   XS     0
# 39  中羽绒服  XXL     1
# 40  中羽绒服  XXS     0
# boxsize ======================= 27.0
# Xmax-- 九分卫裤 =  4.0 ======
#      小类   尺码  尺码件数
# 0  九分卫裤  3XL     4
# 1  九分卫裤    L     4
# 2  九分卫裤    M     4
# 3  九分卫裤    S     2
# 4  九分卫裤   XL     3
# 5  九分卫裤   XS     4
# 6  九分卫裤  XXL     2
# 7  九分卫裤  XXS     4
# boxsize ======================= 39.0
# Xmax-- 休闲外套 =  12.0 ======
#      小类   尺码  尺码件数
# 0  休闲外套  3XL     0
# 1  休闲外套  4XL     0
# 2  休闲外套  5XL     3
# 3  休闲外套    L    12
# 4  休闲外套    M     8
# 5  休闲外套    S     4
# 6  休闲外套   XL     8
# 7  休闲外套  XXL     4
# boxsize ======================= 39.0
# Xmax-- 休闲长裤 =  3.0 ======
#       小类    尺码  尺码件数
# 0   休闲长裤  10XL     3
# 1   休闲长裤   3XL     1
# 2   休闲长裤   3XS     3
# 3   休闲长裤   4XL     0
# 4   休闲长裤   5XL     3
# 5   休闲长裤   6XL     3
# 6   休闲长裤   7XL     3
# 7   休闲长裤   8XL     3
# 8   休闲长裤   9XL     3
# 9   休闲长裤     L     3
# 10  休闲长裤     M     2
# 11  休闲长裤     S     1
# 12  休闲长裤    XL     3
# 13  休闲长裤    XS     3
# 14  休闲长裤   XXL     2
# 15  休闲长裤   XXS     3
# boxsize ======================= 27.0
# Xmax-- 卫裤 =  1.0 ======
#     小类    尺码  尺码件数
# 0   卫裤   100     0
# 1   卫裤  10XL     0
# 2   卫裤   110     0
# 3   卫裤   115     1
# 4   卫裤   120     0
# 5   卫裤   125     0
# 6   卫裤   130     0
# 7   卫裤   135     0
# 18  开衫连帽卫衣   190     0
# 19  开衫连帽卫衣   195     0
# 20  开衫连帽卫衣   200     0
# 21  开衫连帽卫衣   205     0
# 22  开衫连帽卫衣   210     0
# 23  开衫连帽卫衣   215     0
# 24  开衫连帽卫衣   220     0
# 25  开衫连帽卫衣   3XL     0
# 26  开衫连帽卫衣   3XS     0
# 27  开衫连帽卫衣   4XL     0
# 28  开衫连帽卫衣   4XS     0
# 29  开衫连帽卫衣   5XL     0
# 30  开衫连帽卫衣    60     0
# 31  开衫连帽卫衣   6XL     0
# 32  开衫连帽卫衣    70     0
# 33  开衫连帽卫衣   7XL     1
# 34  开衫连帽卫衣    80     0
# 35  开衫连帽卫衣   8XL     1
# 36  开衫连帽卫衣    90     1
# 37  开衫连帽卫衣   9XL     1
# 38  开衫连帽卫衣     L     1
# 39  开衫连帽卫衣     M     1
# 40  开衫连帽卫衣     S     0
# 41  开衫连帽卫衣    XL     1
# 42  开衫连帽卫衣    XS     0
# 43  开衫连帽卫衣   XXL     1
# 44  开衫连帽卫衣   XXS     1
# boxsize ======================= 24.0
# Xmax-- 开衫连帽摇粒绒卫衣 =  4.0 ======
#           小类   尺码  尺码件数
# 0  开衫连帽摇粒绒卫衣  3XL     1
# 1  开衫连帽摇粒绒卫衣  4XL     1
# 2  开衫连帽摇粒绒卫衣    L     4
# 3  开衫连帽摇粒绒卫衣    M     3
# 4  开衫连帽摇粒绒卫衣    S     1
# 5  开衫连帽摇粒绒卫衣   XL     4
# 6  开衫连帽摇粒绒卫衣   XS     4
# 7  开衫连帽摇粒绒卫衣  XXL     2
# 8  开衫连帽摇粒绒卫衣  XXS     4
# boxsize ======================= 39.0
# Xmax-- 拼接休闲裤 =  7.0 ======
#       小类   尺码  尺码件数
# 0  拼接休闲裤  3XL     6
# 1  拼接休闲裤    L     7
# 2  拼接休闲裤    M     7
# 3  拼接休闲裤    S     7
# 4  拼接休闲裤   XL     5
# 5  拼接休闲裤  XXL     7
# boxsize ======================= 27.0
# Xmax-- 拼接卫裤 =  6.000000000000004 ======
#      小类   尺码  尺码件数
# 0  拼接卫裤  3XL     3
# 1  拼接卫裤    L     6
# 2  拼接卫裤    M     6
# 3  拼接卫裤    S     3
# 4  拼接卫裤   XL     6
# 5  拼接卫裤  XXL     3
# boxsize ======================= 24.0
# Xmax-- 拼接套头无帽卫衣 =  4.0 ======
#          小类   尺码  尺码件数
# 0  拼接套头无帽卫衣  3XL     4
# 1  拼接套头无帽卫衣    L     4
# 2  拼接套头无帽卫衣    M     4
# 3  拼接套头无帽卫衣    S     4
# 4  拼接套头无帽卫衣   XL     4
# 5  拼接套头无帽卫衣  XXL     4
# boxsize ======================= 11.0
# Xmax-- 拼接棉茄克 =  2.0 ======
#       小类   尺码  尺码件数
# 0  拼接棉茄克  3XL     2
# 1  拼接棉茄克    L     1
# 2  拼接棉茄克    M     2
# 3  拼接棉茄克    S     2
# 4  拼接棉茄克   XL     2
# 5  拼接棉茄克   XS     1
# 6  拼接棉茄克  XXL     1
# boxsize ======================= 65.0
# Xmax-- 拼接紧身运动长裤 =  14.0 ======
#          小类   尺码  尺码件数
# 0  拼接紧身运动长裤    L     3
# 1  拼接紧身运动长裤    M    14
# 2  拼接紧身运动长裤    S    14
# 3  拼接紧身运动长裤   XL     7
# 4  拼接紧身运动长裤   XS    13
# 5  拼接紧身运动长裤  XXL    14
# boxsize ======================= 11.0
# Xmax-- 棉夹克 =  1.0 ======
#      小类    尺码  尺码件数
# 0   棉夹克   100     0
# 1   棉夹克  10XL     0
# 2   棉夹克   110     0
# 3   棉夹克   115     0
# 4   棉夹克   120     0
# 5   棉夹克   125     0
# 6   棉夹克   130     0
# 7   棉夹克   135     0
# 8   棉夹克   140     0
# 9   棉夹克   145     0
# 10  棉夹克   150     0
# 11  棉夹克   155     0
# 12  棉夹克   160     0
# 13  棉夹克   165     0
# 14  棉夹克   170     0
# 15  棉夹克   175     0
# 16  棉夹克   180     0
# 17  棉夹克   185     0
# 18  棉夹克   190     0
# 19  棉夹克   195     0
# 20  棉夹克   200     0
# 21  棉夹克   205     0
# 22  棉夹克   210     0
# 23  棉夹克   215     0
# 24  棉夹克   220     0
# 25  棉夹克   3XL     0
# 26  棉夹克   3XS     0
# 27  棉夹克   4XL     1
# 28  棉夹克   5XL     1
# 29  棉夹克    60     0
# 30  棉夹克   6XL     1
# 31  棉夹克    70     0
# 32  棉夹克   7XL     0
# 33  棉夹克    80     1
# 34  棉夹克   8XL     1
# 35  棉夹克    90     1
# 36  棉夹克   9XL     1
# 37  棉夹克     L     1
# 38  棉夹克     M     1
# 39  棉夹克     S     1
# 40  棉夹克    XL     1
# 41  棉夹克    XS     0
# 42  棉夹克   XXL     0
# 43  棉夹克   XXS     0
# boxsize ======================= 51.0
# Xmax-- 比赛上衣 =  3.0 ======
#       小类    尺码  尺码件数
# 0   比赛上衣  10XL     0
# 1   比赛上衣   110     3
# 2   比赛上衣   120     0
# 3   比赛上衣   130     3
# 4   比赛上衣   140     3
# 5   比赛上衣   150     3
# 6   比赛上衣   160     3
# 7   比赛上衣   170     3
# 8   比赛上衣   3XL     1
# 9   比赛上衣   3XS     3
# 10  比赛上衣   4XL     1
# 11  比赛上衣   5XL     0
# 12  比赛上衣   6XL     3
# 13  比赛上衣   7XL     3
# 14  比赛上衣   8XL     3
# 15  比赛上衣   9XL     3
# 16  比赛上衣     L     2
# 17  比赛上衣     M     1
# 18  比赛上衣     S     1
# 19  比赛上衣    XL     3
# 20  比赛上衣    XS     3
# 21  比赛上衣   XXL     3
# 22  比赛上衣   XXS     3
# boxsize ======================= 46.0
# Xmax-- 比赛裤 =  2.0 ======
#      小类    尺码  尺码件数
# 0   比赛裤  10XL     2
# 1   比赛裤   110     2
# 2   比赛裤   120     2
# 3   比赛裤   130     2
# 4   比赛裤   140     2
# 5   比赛裤   150     2
# 6   比赛裤   160     2
# 7   比赛裤   170     2
# 8   比赛裤   3XL     2
# 9   比赛裤   3XS     2
# 10  比赛裤   4XL     2
# 11  比赛裤   5XL     2
# 12  比赛裤   6XL     2
# 13  比赛裤   7XL     2
# 14  比赛裤   8XL     2
# 15  比赛裤   9XL     2
# 16  比赛裤     L     2
# 17  比赛裤     M     2
# 18  比赛裤     S     2
# 19  比赛裤    XL     2
# 20  比赛裤    XS     2
# 21  比赛裤   XXL     2
# 22  比赛裤   XXS     2
# boxsize ======================= 11.0
# Xmax-- 短棉服 =  1.0 ======
#      小类    尺码  尺码件数
# 0   短棉服  10XL     1
# 1   短棉服   3XL     1
# 2   短棉服   3XS     1
# 3   短棉服   4XL     0
# 4   短棉服   5XL     1
# 5   短棉服   6XL     0
# 6   短棉服   7XL     1
# 7   短棉服   8XL     1
# 8   短棉服   9XL     0
# 9   短棉服     L     1
# 10  短棉服     M     1
# 11  短棉服     S     0
# 12  短棉服    XL     1
# 13  短棉服    XS     0
# 14  短棉服   XXL     1
# 15  短棉服   XXS     1
# boxsize ======================= 11.0
# Xmax-- 短羽绒服 =  1.0 ======
#       小类    尺码  尺码件数
# 0   短羽绒服   100     0
# 1   短羽绒服  10XL     0
# 2   短羽绒服   110     0
# 3   短羽绒服   115     0
# 4   短羽绒服   120     0
# 5   短羽绒服   125     0
# 6   短羽绒服   130     0
# 7   短羽绒服   135     0
# 8   短羽绒服   140     0
# 9   短羽绒服   145     0
# 10  短羽绒服   150     1
# 11  短羽绒服   155     1
# 12  短羽绒服   160     1
# 13  短羽绒服   165     1
# 14  短羽绒服   170     1
# 15  短羽绒服   175     1
# 16  短羽绒服   180     1
# 17  短羽绒服   185     0
# 18  短羽绒服   190     0
# 19  短羽绒服   195     0
# 20  短羽绒服   200     0
# 21  短羽绒服   205     0
# 22  短羽绒服   210     0
# 23  短羽绒服   215     0
# 24  短羽绒服   220     0
# 25  短羽绒服   3XL     0
# 26  短羽绒服   3XS     0
# 27  短羽绒服   4XL     0
# 28  短羽绒服   5XL     0
# 29  短羽绒服    60     0
# 30  短羽绒服   6XL     0
# 31  短羽绒服    70     0
# 32  短羽绒服   7XL     0
# 33  短羽绒服    80     0
# 34  短羽绒服   8XL     0
# 35  短羽绒服    90     0
# 36  短羽绒服   9XL     0
# 37  短羽绒服     L     1
# 38  短羽绒服     M     1
# 39  短羽绒服     S     0
# 40  短羽绒服    XL     1
# 41  短羽绒服    XS     0
# 42  短羽绒服   XXL     1
# 43  短羽绒服   XXS     0
# boxsize ======================= 51.0
# Xmax-- 短袖Polo =  11.999999999999998 ======
#         小类    尺码  尺码件数
# 0   短袖Polo  10XL     0
# 1   短袖Polo   3XL     4
# 2   短袖Polo   3XS     0
# 3   短袖Polo   4XL     2
# 4   短袖Polo   4XS     0
# 5   短袖Polo   5XL     0
# 6   短袖Polo   6XL     0
# 7   短袖Polo   7XL     0
# 8   短袖Polo   8XL     8
# 9   短袖Polo   9XL     0
# 10  短袖Polo     L     8
# 11  短袖Polo     M     5
# 12  短袖Polo     S     2
# 13  短袖Polo    XL    12
# 14  短袖Polo    XS     1
# 15  短袖Polo   XXL     9
# 16  短袖Polo   XXS     0
# boxsize ======================= 69.0
# Xmax-- 短袖T恤 =  3.0 ======
#       小类    尺码  尺码件数
# 0   短袖T恤   100     2
# 1   短袖T恤  10XL     2
# 2   短袖T恤   110     3
# 3   短袖T恤   120     3
# 4   短袖T恤   130     3
# 5   短袖T恤   140     3
# 6   短袖T恤   150     3
# 7   短袖T恤   160     3
# 8   短袖T恤   165     3
# 9   短袖T恤   3XL     0
# 10  短袖T恤   3XS     3
# 11  短袖T恤   4XL     3
# 12  短袖T恤   4XS     3
# 13  短袖T恤   5XL     3
# 14  短袖T恤   6XL     3
# 15  短袖T恤   7XL     3
# 16  短袖T恤   8XL     3
# 17  短袖T恤    90     3
# 18  短袖T恤   9XL     3
# 19  短袖T恤     L     3
# 20  短袖T恤     M     3
# 21  短袖T恤     S     1
# 22  短袖T恤    XL     3
# 23  短袖T恤    XS     3
# 24  短袖T恤   XXL     1
# 25  短袖T恤   XXS     3
# boxsize ======================= 56.0
# Xmax-- 短袖文化衫 =  3.0 ======
#        小类    尺码  尺码件数
# 0   短袖文化衫  10XL     3
# 1   短袖文化衫   130     3
# 2   短袖文化衫   140     3
# 3   短袖文化衫   150     3
# 4   短袖文化衫   160     3
# 5   短袖文化衫   3XL     3
# 6   短袖文化衫   3XS     3
# 7   短袖文化衫   4XL     3
# 8   短袖文化衫   5XL     3
# 9   短袖文化衫   6XL     3
# 10  短袖文化衫   7XL     3
# 11  短袖文化衫   8XL     3
# 12  短袖文化衫   9XL     3
# 13  短袖文化衫     L     3
# 14  短袖文化衫     M     1
# 15  短袖文化衫     S     3
# 16  短袖文化衫    XL     3
# 17  短袖文化衫    XS     3
# 18  短袖文化衫   XXL     1
# 19  短袖文化衫   XXS     3
# boxsize ======================= 65.0
# Xmax-- 紧身运动长裤 =  3.0 ======
#         小类    尺码  尺码件数
# 0   紧身运动长裤  10XL     3
# 1   紧身运动长裤   130     3
# 2   紧身运动长裤   135     3
# 3   紧身运动长裤   140     3
# 4   紧身运动长裤   150     3
# 5   紧身运动长裤   160     3
# 6   紧身运动长裤   165     3
# 7   紧身运动长裤   170     3
# 8   紧身运动长裤   175     3
# 9   紧身运动长裤   3XL     1
# 10  紧身运动长裤   3XS     3
# 11  紧身运动长裤   4XL     3
# 12  紧身运动长裤   5XL     3
# 13  紧身运动长裤   6XL     3
# 14  紧身运动长裤   7XL     3
# 15  紧身运动长裤   8XL     3
# 16  紧身运动长裤   9XL     3
# 17  紧身运动长裤     L     3
# 18  紧身运动长裤     M     3
# 19  紧身运动长裤     S     1
# 20  紧身运动长裤    XL     2
# 21  紧身运动长裤    XS     3
# 22  紧身运动长裤   XXL     1
# 23  紧身运动长裤   XXS     3
# boxsize ======================= 21.0
# Xmax-- 羽绒马甲 =  1.0 ======
#       小类    尺码  尺码件数
# 0   羽绒马甲   100     0
# 1   羽绒马甲  10XL     0
# 2   羽绒马甲   110     0
# 3   羽绒马甲   115     0
# 4   羽绒马甲   120     0
# 5   羽绒马甲   125     0
# 6   羽绒马甲   130     0
# 7   羽绒马甲   135     0
# 8   羽绒马甲   140     0
# 9   羽绒马甲   145     0
# 10  羽绒马甲   150     0
# 11  羽绒马甲   155     0
# 12  羽绒马甲   160     0
# 13  羽绒马甲   165     0
# 14  羽绒马甲   170     0
# 15  羽绒马甲   175     0
# 16  羽绒马甲   180     1
# 17  羽绒马甲   185     1
# 18  羽绒马甲   190     1
# 19  羽绒马甲   195     0
# 20  羽绒马甲   200     1
# 21  羽绒马甲   205     1
# 22  羽绒马甲   210     1
# 23  羽绒马甲   215     1
# 24  羽绒马甲   220     1
# 25  羽绒马甲   3XL     0
# 26  羽绒马甲   3XS     1
# 27  羽绒马甲   4XL     0
# 28  羽绒马甲   5XL     0
# 29  羽绒马甲    60     1
# 30  羽绒马甲   6XL     1
# 31  羽绒马甲    70     1
# 32  羽绒马甲   7XL     1
# 33  羽绒马甲    80     1
# 34  羽绒马甲   8XL     1
# 35  羽绒马甲    90     1
# 36  羽绒马甲   9XL     1
# 37  羽绒马甲     L     1
# 38  羽绒马甲     M     1
# 39  羽绒马甲     S     0
# 40  羽绒马甲    XL     1
# 41  羽绒马甲    XS     0
# 42  羽绒马甲   XXL     1
# 43  羽绒马甲   XXS     0
# boxsize ======================= 72.0
# Xmax-- 背心 =  9.9999999999999 ======
#     小类   尺码  尺码件数
# 0   背心  3XL     3
# 1   背心  3XS     0
# 2   背心  4XL    10
# 3   背心  4XS     0
# 4   背心  5XL     0
# 5   背心  6XL     3
# 6   背心  7XL     0
# 7   背心  8XL     0
# 8   背心    L     9
# 9   背心    M    10
# 10  背心    S     3
# 11  背心   XL     8
# 12  背心   XS    10
# 13  背心  XXL     6
# 14  背心  XXS    10
# boxsize ======================= 33.0
# Xmax-- 裤裙 =  3.0 ======
#     小类   尺码  尺码件数
# 0   裤裙  120     2
# 1   裤裙  130     3
# 2   裤裙  140     2
# 3   裤裙  150     3
# 4   裤裙  160     3
# 5   裤裙  170     3
# 6   裤裙  3XL     3
# 7   裤裙    L     2
# 8   裤裙    M     3
# 9   裤裙    S     3
# 10  裤裙   XL     1
# 11  裤裙   XS     1
# 12  裤裙  XXL     1
# 13  裤裙  XXS     3
# boxsize ======================= 20.0
# Xmax-- 软壳长裤 =  4.000000000000007 ======
#      小类   尺码  尺码件数
# 0  软壳长裤  3XL     2
# 1  软壳长裤  4XL     1
# 2  软壳长裤    L     3
# 3  软壳长裤    M     2
# 4  软壳长裤    S     1
# 5  软壳长裤   XL     4
# 6  软壳长裤   XS     4
# 7  软壳长裤  XXL     3
# boxsize ======================= 38.0
# Xmax-- 运动文胸 =  3.0 ======
#       小类   尺码  尺码件数
# 0   运动文胸  3XL     3
# 1   运动文胸  3XS     3
# 2   运动文胸  4XL     3
# 3   运动文胸  4XS     3
# 4   运动文胸  5XL     3
# 5   运动文胸  6XL     3
# 6   运动文胸  7XL     3
# 7   运动文胸  8XL     3
# 8   运动文胸    L     2
# 9   运动文胸    M     3
# 10  运动文胸    S     1
# 27  运动风衣   4XL     0
# 28  运动风衣   4XS     1
# 29  运动风衣   5XL     1
# 30  运动风衣    60     1
# 31  运动风衣   6XL     1
# 32  运动风衣    70     1
# 33  运动风衣   7XL     1
# 34  运动风衣    80     1
# 35  运动风衣   8XL     1
# 36  运动风衣    90     1
# 37  运动风衣   9XL     1
# 38  运动风衣     L     1
# 39  运动风衣     M     1
# 40  运动风衣     S     0
# 41  运动风衣    XL     1
# 42  运动风衣    XS     0
# 43  运动风衣   XXL     1
# 44  运动风衣   XXS     1
# boxsize ======================= 33.0
# Xmax-- 连衣裙 =  5.0 ======
#     小类   尺码  尺码件数
# 0  连衣裙  3XL     5
# 1  连衣裙    L     4
# 2  连衣裙    M     5
# 3  连衣裙    S     5
# 4  连衣裙   XL     2
# 5  连衣裙   XS     4
# 6  连衣裙  XXL     3
# 7  连衣裙  XXS     5
# boxsize ======================= 47.0
# Xmax-- 速干长裤 =  10.0 ======
#      小类   尺码  尺码件数
# 0  速干长裤  3XL     4
# 1  速干长裤  4XL     2
# 2  速干长裤    L    10
# 3  速干长裤    M     3
# 4  速干长裤    S     1
# 5  速干长裤   XL    10
# 6  速干长裤   XS    10
# 7  速干长裤  XXL     7
# boxsize ======================= 39.0
# Xmax-- 针织休闲裤 =  8.0 ======
#       小类   尺码  尺码件数
# 0  针织休闲裤  3XL     6
# 1  针织休闲裤    L     8
# 2  针织休闲裤    M     8
# 3  针织休闲裤    S     5
# 4  针织休闲裤   XL     8
# 5  针织休闲裤  XXL     4
# boxsize ======================= 39.0
# Xmax-- 针织外套 =  6.0 ======
#      小类   尺码  尺码件数
# 0  针织外套  3XL     4
# 1  针织外套  4XL     6
# 2  针织外套    L     6
# 3  针织外套    M     6
# 4  针织外套    S     5
# 5  针织外套   XL     3
# 6  针织外套   XS     6
# 7  针织外套  XXL     3
# boxsize ======================= 24.0
# Xmax-- 针织运动上衣 =  4.0 ======
#        小类   尺码  尺码件数
# 0  针织运动上衣  3XL     1
# 1  针织运动上衣  4XL     4
# 2  针织运动上衣    L     4
# 3  针织运动上衣    M     3
# 4  针织运动上衣    S     2
# 5  针织运动上衣   XL     3
# 6  针织运动上衣   XS     2
# 7  针织运动上衣  XXL     1
# 8  针织运动上衣  XXS     4
# boxsize ======================= 43.0
# Xmax-- 针织运动裤 =  7.0 ======
#       小类   尺码  尺码件数
# 0  针织运动裤  3XL     3
# 1  针织运动裤  4XL     7
# 2  针织运动裤    L     7
# 3  针织运动裤    M     7
# 4  针织运动裤    S     4
# 5  针织运动裤   XL     5
# 6  针织运动裤   XS     7
# 7  针织运动裤  XXL     3
# boxsize ======================= 24.0
# Xmax-- 针织长袖衫 =  4.0 ======
#       小类   尺码  尺码件数
# 0  针织长袖衫  3XL     1
# 1  针织长袖衫  4XL     4
# 2  针织长袖衫  5XL     4
# 3  针织长袖衫    L     2
# 4  针织长袖衫    M     4
# 5  针织长袖衫    S     2
# 6  针织长袖衫   XL     3
# 7  针织长袖衫  XXL     4
# boxsize ======================= 27.0
# Xmax-- 针织阔腿裤 =  3.999999999999999 ======
#       小类   尺码  尺码件数
# 0  针织阔腿裤  3XL     4
# 1  针织阔腿裤    L     3
# 2  针织阔腿裤    M     4
# 3  针织阔腿裤    S     2
# 4  针织阔腿裤   XL     2
# 5  针织阔腿裤   XS     4
# 6  针织阔腿裤  XXL     4
# 7  针织阔腿裤  XXS     4
# boxsize ======================= 11.0
# Xmax-- 长棉服 =  1.0 ======
#      小类    尺码  尺码件数
# 0   长棉服  10XL     1
# 1   长棉服   3XL     0
# 2   长棉服   3XS     1
# 3   长棉服   4XL     1
# 4   长棉服   5XL     0
# 5   长棉服   6XL     1
# 6   长棉服   7XL     1
# 7   长棉服   8XL     1
# 8   长棉服   9XL     0
# 9   长棉服     L     1
# 10  长棉服     M     1
# 11  长棉服     S     1
# 12  长棉服    XL     1
# 13  长棉服    XS     0
# 14  长棉服   XXL     1
# 15  长棉服   XXS     0
# boxsize ======================= 11.0
# Xmax-- 长羽绒服 =  1.0 ======
#       小类    尺码  尺码件数
# 0   长羽绒服   100     0
# 1   长羽绒服  10XL     0
# 2   长羽绒服   110     1
# 3   长羽绒服   115     1
# 4   长羽绒服   120     0
# 5   长羽绒服   125     0
# 6   长羽绒服   130     1
# 7   长羽绒服   135     0
# 8   长羽绒服   140     0
# 9   长羽绒服   145     0
# 10  长羽绒服   150     0
# 11  长羽绒服   155     0
# 12  长羽绒服   160     0
# 13  长羽绒服   165     0
# 14  长羽绒服   170     0
# 15  长羽绒服   175     0
# 16  长羽绒服   180     0
# 17  长羽绒服   185     1
# 18  长羽绒服   190     1
# 19  长羽绒服   195     0
# 20  长羽绒服   200     0
# 21  长羽绒服   205     0
# 22  长羽绒服   210     0
# 23  长羽绒服   215     0
# 24  长羽绒服   220     0
# 25  长羽绒服   3XL     0
# 26  长羽绒服   3XS     0
# 27  长羽绒服   4XL     0
# 28  长羽绒服   4XS     1
# 29  长羽绒服   5XL     0
# 30  长羽绒服    60     0
# 31  长羽绒服   6XL     0
# 32  长羽绒服    70     0
# 33  长羽绒服   7XL     0
# 34  长羽绒服    80     0
# 35  长羽绒服   8XL     0
# 36  长羽绒服    90     0
# 37  长羽绒服   9XL     0
# 38  长羽绒服     L     1
# 39  长羽绒服     M     1
# 40  长羽绒服     S     0
# 41  长羽绒服    XL     1
# 42  长羽绒服    XS     0
# 43  长羽绒服   XXL     1
# 44  长羽绒服   XXS     1
# boxsize ======================= 51.0
# Xmax-- 长袖Polo =  12.0 ======
#         小类   尺码  尺码件数
# 0   长袖Polo  3XL    12
# 1   长袖Polo  3XS     0
# 2   长袖Polo  4XL     0
# 3   长袖Polo  4XS     0
# 4   长袖Polo  5XL     0
# 5   长袖Polo  6XL     0
# 6   长袖Polo  7XL     0
# 7   长袖Polo  8XL     0
# 8   长袖Polo    L    12
# 9   长袖Polo    M     0
# 10  长袖Polo    S     0
# 11  长袖Polo   XL    12
# 12  长袖Polo   XS     0
# 13  长袖Polo  XXL    12
# 14  长袖Polo  XXS     3
# boxsize ======================= 44.0
# Xmax-- 长袖T恤 =  3.0 ======
#       小类    尺码  尺码件数
# 0   长袖T恤  10XL     3
# 1   长袖T恤   130     0
# 2   长袖T恤   140     0
# 3   长袖T恤   150     3
# 4   长袖T恤   160     3
# 5   长袖T恤   170     3
# 6   长袖T恤   3XL     1
# 7   长袖T恤   3XS     0
# 8   长袖T恤   4XL     3
# 9   长袖T恤   5XL     3
# 10  长袖T恤   6XL     3
# 11  长袖T恤   7XL     3
# 12  长袖T恤   8XL     3
# 13  长袖T恤   9XL     3
# 14  长袖T恤     L     3
# 15  长袖T恤     M     2
# 16  长袖T恤     S     1
# 17  长袖T恤    XL     3
# 18  长袖T恤    XS     2
# 19  长袖T恤   XXL     2
# 20  长袖T恤   XXS     0
# boxsize ======================= 50.0
# Xmax-- 长袖套头衫 =  7.0 ======
#       小类   尺码  尺码件数
# 0  长袖套头衫  3XL     4
# 1  长袖套头衫  4XL     4
# 2  长袖套头衫    L     7
# 3  长袖套头衫    M     7
# 4  长袖套头衫    S     7
# 5  长袖套头衫   XL     7
# 6  长袖套头衫   XS     7
# 7  长袖套头衫  XXL     7
# boxsize ======================= 56.0
# Xmax-- 长袖文化衫 =  3.9999999999910334 ======
#        小类    尺码  尺码件数
# 0   长袖文化衫  10XL     4
# 1   长袖文化衫   3XL     2
# 2   长袖文化衫   3XS     4
# 3   长袖文化衫   4XL     1
# 4   长袖文化衫   5XL     4
# 5   长袖文化衫   6XL     4
# 6   长袖文化衫   7XL     4
# 7   长袖文化衫   8XL     4
# 8   长袖文化衫   9XL     4
# 9   长袖文化衫     L     4
# 10  长袖文化衫     M     4
# 11  长袖文化衫     S     2
# 12  长袖文化衫    XL     4
# 13  长袖文化衫    XS     4
# 14  长袖文化衫   XXL     3
# 15  长袖文化衫   XXS     4
# boxsize ======================= 72.0
# Xmax-- 长袖紧身衣 =  6.0 ======
#        小类   尺码  尺码件数
# 0   长袖紧身衣  135     6
# 1   长袖紧身衣  140     6
# 2   长袖紧身衣  150     6
# 3   长袖紧身衣  160     6
# 4   长袖紧身衣  170     6
# 5   长袖紧身衣  175     6
# 6   长袖紧身衣  3XL     2
# 7   长袖紧身衣  4XL     6
# 8   长袖紧身衣    L     6
# 9   长袖紧身衣    M     3
# 10  长袖紧身衣    S     4
# 11  长袖紧身衣   XL     6
# 12  长袖紧身衣   XS     6
# 13  长袖紧身衣  XXL     3

# %%
# exl_time = dt.datetime.now().strftime('%Y%m%d%H%M')
# locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningClothesResult'+exl_time+'.xlsx'
# Clothes_result.to_excel(locaurl, index = False)
Clothes_result
# Out:
#                            小类    尺码 尺码件数
# 0      2合1运动短裤（外-运动短裤/内-紧身长裤）   3XL    9
# 1      2合1运动短裤（外-运动短裤/内-紧身长裤）     L    9
# 2      2合1运动短裤（外-运动短裤/内-紧身长裤）     M    9
# 3      2合1运动短裤（外-运动短裤/内-紧身长裤）     S    6
# 4      2合1运动短裤（外-运动短裤/内-紧身长裤）    XL    5
# 5      2合1运动短裤（外-运动短裤/内-紧身长裤）    XS    9
# 6      2合1运动短裤（外-运动短裤/内-紧身长裤）   XXL    9
# 7     三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   110    1
# 8     三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   120    1
# 9     三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   130    1
# 10    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   140    1
# 11    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   150    0
# 12    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   160    1
# 13    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   165    0
# 14    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   170    0
# 15    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   175    1
# 16    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   3XL    0
# 17    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   4XL    0
# 18    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)     L    1
# 19    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)     M    1
# 20    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)     S    0
# 21    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    XL    1
# 22    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    XS    1
# 23    三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XXL    1
# 24          三合一(内-短棉服/外-运动风衣)   110    0
# 25          三合一(内-短棉服/外-运动风衣)   120    0
# 26          三合一(内-短棉服/外-运动风衣)   130    0
# 27          三合一(内-短棉服/外-运动风衣)   140    0
# 28          三合一(内-短棉服/外-运动风衣)   150    0
# 29          三合一(内-短棉服/外-运动风衣)   160    1
# ...                       ...   ...  ...
# 1070                    长袖文化衫  10XL    4
# 1071                    长袖文化衫   3XL    2
# 1072                    长袖文化衫   3XS    4
# 1073                    长袖文化衫   4XL    1
# 1074                    长袖文化衫   5XL    4
# 1075                    长袖文化衫   6XL    4
# 1076                    长袖文化衫   7XL    4
# 1077                    长袖文化衫   8XL    4
# 1078                    长袖文化衫   9XL    4
# 1079                    长袖文化衫     L    4
# 1080                    长袖文化衫     M    4
# 1081                    长袖文化衫     S    2
# 1082                    长袖文化衫    XL    4
# 1083                    长袖文化衫    XS    4
# 1084                    长袖文化衫   XXL    3
# 1085                    长袖文化衫   XXS    4
# 1086                    长袖紧身衣   135    6
# 1087                    长袖紧身衣   140    6
# 1088                    长袖紧身衣   150    6
# 1089                    长袖紧身衣   160    6
# 1090                    长袖紧身衣   170    6
# 1091                    长袖紧身衣   175    6
# 1092                    长袖紧身衣   3XL    2
# 1093                    长袖紧身衣   4XL    6
# 1094                    长袖紧身衣     L    6
# 1095                    长袖紧身衣     M    3
# 1096                    长袖紧身衣     S    4
# 1097                    长袖紧身衣    XL    6
# 1098                    长袖紧身衣    XS    6
# 1099                    长袖紧身衣   XXL    3
#
# [1100 rows x 3 columns]

# %%
# clo_data

# %%
def cal_clothes_model_2(data_result):
    
    data_result = data_result.reset_index().set_index(['class_2','org_id','size'])
    
#     minput = 18
#     minput = 12
    
    #建立模型
    model = Model("LiNingExample")

    #  变量及参数定义
    M = 100000   #极大值
    diffabs = {} #绝对值
    bl = {} #bool
    X = {} #决策变量
    Xmax = {} # X 的最大值
    dllb = {}
    diff = {}
    
    dfx = data_result.reset_index('org_id')
    
    #决策变量X，每个尺码的比例
    for idx_s in dfx.index.unique():
        X[idx_s] = model.addVar(vtype="C", name="X")
        
    #辅助变量 max 尺码件数X中的最大值Xmax
    dfmax = data_result.reset_index(['size','org_id'])
    
    for idx_s in dfx.index.unique():
        class_2, size = idx_s
        if class_2 not in Xmax:
            Xmax[class_2] = model.addVar(vtype ='C', name = "Xmax")
        bl[idx_s] = model.addVar(vtype="B", name="bl")

        model.addCons(Xmax[class_2] - X[idx_s] >= 0)
        model.addCons(X[idx_s] - Xmax[class_2] + M * (1 - bl[idx_s])>= 0 )
        model.addCons(X[idx_s] - Xmax[class_2] - M * bl[idx_s] <= -1 )
    
    #辅助等式  绝对值计算 及约束确定
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        # print('myration:', myratio)
#         if myratio!=0:
#             print(idx,'==========',myratio)
        dllb[idx] = model.addVar(vtype = 'B', name = 'dllb')
        diff[idx] = model.addVar(lb = None,  vtype = 'C', name = 'diff')
        diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs')
#       diffabs[idx] = model.addVar(vtype = 'C', name = 'diffabs', obj = data_result.loc[idx, 'qty'])
    
    #设置目标

    for idx in data_result.index.unique():
        model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
#     for idx in data_result.index.unique():
#         model.setObjective(data_result.loc[idx, 'qty']*diffabs[idx], clear = False)
# #         model.setObjective(diffabs[idx], clear = False)

    #绝对值
    for idx in data_result.index.unique():
        myratio = data_result.loc[idx,'ratio']
        class_2, org_id, size = idx
        
#         if myratio!=0:
#             print('==========',myratio)
        model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])

        model.addCons(diffabs[idx] >= diff[idx])
        model.addCons(diffabs[idx] >= -1 * diff[idx])
        model.addCons(diffabs[idx] <= diff[idx] + M * (1 - dllb[idx]))
        model.addCons(diffabs[idx] <= -1 * diff[idx] + M * dllb[idx])
        
        
#         class_2, org_id, size = idx
#         model.addCons(diff[idx] == X[class_2, size] - myratio * Xmax[class_2])
    
    df = data_result.reset_index('size')
    df_1 = data_result.reset_index(['org_id','size'])
    for idx in df_1.index.unique():
        class_2 = idx
        model.addCons(quicksum(bl[class_2, size_1] for size_1 in df_1.loc[idx, ['size']].drop_duplicates().values.ravel()) >= 1)
    
#     约束： 每个尺码的件数之和 等于 最小装箱数
    for idx_s in df.index.unique():
        class_2, org_id = idx_s
        model.addCons(quicksum(X[class_2,size_1] for size_1 in df.loc[idx_s, ['size']].values.ravel()) == 10)

    
    model.setMinimize()
    model.optimize()
    status = model.getStatus()
    
    # 输出到出X为excle到本地
    OutX = {}
    if model.getStatus() =='optimal':
        for i in X:
            OutX[i] = round(model.getVal(X[i]))
        for idx11 in Xmax:
            print('Xmax--',idx, '= ', model.getVal(Xmax[idx]),"======")
    else:
        print("status",'*'*30, model.getStatus())
        print("obj:", model.getObjVal())
        print("gap:", model.getGap())
#         break
    return OutX
        
#     print(OutX)
#     print(liningResult)
    
#     return OutX

# %%
# clo_data

# %%
# clo_data2 = clo_data.copy()

# %%
# clo_data2.loc[clo_data2['ratio'] ==0 ,'ratio'] =0.01
# clo_data2.loc[clo_data2['qty'] ==0 ,'qty'] =0.01

# %%
# clo_data2.loc[clo_data2['ratio'],'ratio']
# clo_data2['ratio']= clo_data2['ratio']*100

# %%
# clo_data

# %%
# class_arry1 = class_arry

# %%
# class_arry1

# %%
Clothes_result_2 =pd.DataFrame(columns=('小类','尺码','尺码比例'))

for class_name in class_arry:
    clo_data_test = clo_data.loc[clo_data['class_2']== class_name]
    clo_data_test = clo_data_test.reset_index().drop('index',axis=1)
    #     print(clo_data_test)
    #     minput = BoxSize_dict[class_name]['minput']
    #     print('boxsize =======================',minput)   
    class_result = {}
    class_result = cal_clothes_model_2(clo_data_test)
    liningResult = pd.DataFrame(class_result, index =['尺码比例']).T.rename_axis(['小类','尺码']).reset_index()
#     liningResult['尺码比例'] = liningResult['尺码比例']/100
    print(liningResult)
    Clothes_result_2 = pd.concat([Clothes_result_2,liningResult],ignore_index=True)
# Out:
# Xmax-- 2合1运动短裤（外-运动短裤/内-紧身长裤） =  1.4285714285714284 ======
#                        小类   尺码  尺码比例
# 0  2合1运动短裤（外-运动短裤/内-紧身长裤）  3XL     1
# 1  2合1运动短裤（外-运动短裤/内-紧身长裤）    L     1
# 2  2合1运动短裤（外-运动短裤/内-紧身长裤）    M     1
# 3  2合1运动短裤（外-运动短裤/内-紧身长裤）    S     1
# 4  2合1运动短裤（外-运动短裤/内-紧身长裤）   XL     1
# 5  2合1运动短裤（外-运动短裤/内-紧身长裤）   XS     1
# 6  2合1运动短裤（外-运动短裤/内-紧身长裤）  XXL     1
# Xmax-- 三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣) =  0.5882352941176471 ======
#                          小类   尺码  尺码比例
# 0   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  110     1
# 1   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  120     1
# 2   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  130     1
# 3   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  140     1
# 4   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  150     1
# 5   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  160     1
# 6   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  165     1
# 7   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  170     1
# 8   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  175     1
# 9   三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  3XL     1
# 10  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  4XL     1
# 11  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    L     1
# 12  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    M     1
# 13  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)    S     1
# 14  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XL     1
# 15  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)   XS     1
# 16  三合一(内-开衫无帽摇粒绒卫衣/外-运动风衣)  XXL     1
# Xmax-- 三合一(内-短棉服/外-运动风衣) =  2.333333333333335 ======
#                    小类   尺码  尺码比例
# 0   三合一(内-短棉服/外-运动风衣)  110     0
# 1   三合一(内-短棉服/外-运动风衣)  120     0
# 2   三合一(内-短棉服/外-运动风衣)  130     0
# 3   三合一(内-短棉服/外-运动风衣)  140     0
# 4   三合一(内-短棉服/外-运动风衣)  150     0
# 5   三合一(内-短棉服/外-运动风衣)  160     0
# 6   三合一(内-短棉服/外-运动风衣)  165     0
# 7   三合一(内-短棉服/外-运动风衣)  170     2
# 8   三合一(内-短棉服/外-运动风衣)  175     2
# 9   三合一(内-短棉服/外-运动风衣)  3XL     0
# 10  三合一(内-短棉服/外-运动风衣)  4XL     0
# 11  三合一(内-短棉服/外-运动风衣)    L     2
# 12  三合一(内-短棉服/外-运动风衣)    M     1
# 13  三合一(内-短棉服/外-运动风衣)    S     0
# 14  三合一(内-短棉服/外-运动风衣)   XL     1
# 15  三合一(内-短棉服/外-运动风衣)   XS     0
# 16  三合一(内-短棉服/外-运动风衣)  XXL     0
# Xmax-- 三合一(内-紧身运动长裤/外-运动短裤) =  2.357142857142858 ======
#                      小类   尺码  尺码比例
# 0  三合一(内-紧身运动长裤/外-运动短裤)    L     1
# 1  三合一(内-紧身运动长裤/外-运动短裤)    M     2
# 2  三合一(内-紧身运动长裤/外-运动短裤)    S     1
# 3  三合一(内-紧身运动长裤/外-运动短裤)   XL     0
# 4  三合一(内-紧身运动长裤/外-运动短裤)   XS     2
# 5  三合一(内-紧身运动长裤/外-运动短裤)  XXL     2
# Xmax-- 中棉服 =  0.2631578947368421 ======
#      小类   尺码  尺码比例
# 0   中棉服  100     0
# 1   中棉服  110     0
# 2   中棉服  115     0
# 3   中棉服  120     0
# 4   中棉服  125     0
# 5   中棉服  130     0
# 6   中棉服  135     0
# 7   中棉服  140     0
# 8   中棉服  145     0
# 9   中棉服  150     0
# 10  中棉服  155     0
# 11  中棉服  160     0
# 12  中棉服  165     0
# 13  中棉服  170     0
# 14  中棉服  175     0
# 15  中棉服  180     0
# 16  中棉服  185     0
# 17  中棉服  190     0
# 18  中棉服  195     0
# 19  中棉服  200     0
# 20  中棉服  205     0
# 21  中棉服  210     0
# 22  中棉服  215     0
# 23  中棉服  220     0
# 24  中棉服  3XL     0
# 25  中棉服  4XL     0
# 26  中棉服  5XL     0
# 27  中棉服   60     0
# 28  中棉服   70     0
# 29  中棉服   80     0
# 30  中棉服   90     0
# 31  中棉服    L     0
# 32  中棉服    M     0
# 33  中棉服    S     0
# 34  中棉服   XL     0
# 35  中棉服   XS     0
# 36  中棉服  XXL     0
# 37  中棉服  XXS     0
# Xmax-- 中羽绒服 =  0.24390243902439024 ======
#       小类   尺码  尺码比例
# 0   中羽绒服  100     0
# 1   中羽绒服  110     0
# 2   中羽绒服  115     0
# 3   中羽绒服  120     0
# 4   中羽绒服  125     0
# 5   中羽绒服  130     0
# 6   中羽绒服  135     0
# 7   中羽绒服  140     0
# 8   中羽绒服  145     0
# 9   中羽绒服  150     0
# 10  中羽绒服  155     0
# 11  中羽绒服  160     0
# 12  中羽绒服  165     0
# 13  中羽绒服  170     0
# 14  中羽绒服  175     0
# 15  中羽绒服  180     0
# 16  中羽绒服  185     0
# 17  中羽绒服  190     0
# 18  中羽绒服  195     0
# 19  中羽绒服  200     0
# 20  中羽绒服  205     0
# 21  中羽绒服  210     0
# 22  中羽绒服  215     0
# 23  中羽绒服  220     0
# 24  中羽绒服  3XL     0
# 25  中羽绒服  4XL     0
# 26  中羽绒服  5XL     0
# 27  中羽绒服   60     0
# 28  中羽绒服  6XL     0
# 29  中羽绒服   70     0
# 30  中羽绒服  7XL     0
# 31  中羽绒服   80     0
# 32  中羽绒服  8XL     0
# 33  中羽绒服   90     0
# 34  中羽绒服    L     0
# 35  中羽绒服    M     0
# 36  中羽绒服    S     0
# 37  中羽绒服   XL     0
# 38  中羽绒服   XS     0
# 39  中羽绒服  XXL     0
# 40  中羽绒服  XXS     0
# Xmax-- 九分卫裤 =  1.647746243739566 ======
#      小类   尺码  尺码比例
# 0  九分卫裤  3XL     2
# 1  九分卫裤    L     2
# 2  九分卫裤    M     2
# 3  九分卫裤    S     1
# 4  九分卫裤   XL     1
# 5  九分卫裤   XS     2
# 6  九分卫裤  XXL     0
# 7  九分卫裤  XXS     2
# Xmax-- 休闲外套 =  3.3333333333333357 ======
#      小类   尺码  尺码比例
# 0  休闲外套  3XL     0
# 1  休闲外套  4XL     0
# 2  休闲外套  5XL     0
# 3  休闲外套    L     3
# 4  休闲外套    M     2
# 5  休闲外套    S     1
# 6  休闲外套   XL     2
# 7  休闲外套  XXL     1
# Xmax-- 休闲长裤 =  0.625 ======
#       小类    尺码  尺码比例
# 0   休闲长裤  10XL     1
# 1   休闲长裤   3XL     1
# 2   休闲长裤   3XS     1
# 3   休闲长裤   4XL     1
# 4   休闲长裤   5XL     1
# 5   休闲长裤   6XL     1
# 6   休闲长裤   7XL     1
# 7   休闲长裤   8XL     1
# 8   休闲长裤   9XL     1
# 9   休闲长裤     L     1
# 10  休闲长裤     M     1
# 11  休闲长裤     S     1
# 12  休闲长裤    XL     1
# 13  休闲长裤    XS     1
# 14  休闲长裤   XXL     1
# 15  休闲长裤   XXS     1
# Xmax-- 卫裤 =  0.22222222222222224 ======
#     小类    尺码  尺码比例
# 0   卫裤   100     0
# 1   卫裤  10XL     0
# 2   卫裤   110     0
# 3   卫裤   115     0
# 4   卫裤   120     0
# 5   卫裤   125     0
# 6   卫裤   130     0
# 7   卫裤   135     0
# 8   卫裤   140     0
# 9   卫裤   145     0
# 10  卫裤   150     0
# 11  卫裤   155     0
# 12  卫裤   160     0
# 13  卫裤   165     0
# 14  卫裤   170     0
# 15  卫裤   175     0
# 16  卫裤   180     0
# 17  卫裤   185     0
# 18  卫裤   190     0
# 19  卫裤   195     0
# 20  卫裤   200     0
# 21  卫裤   205     0
# 22  卫裤   210     0
# 23  卫裤   215     0
# 24  卫裤   220     0
# 25  卫裤   3XL     0
# 26  卫裤   3XS     0
# 27  卫裤   4XL     0
# 28  卫裤   4XS     0
# 29  卫裤   5XL     0
# 30  卫裤    60     0
# 31  卫裤   6XL     0
# 32  卫裤    70     0
# 33  卫裤   7XL     0
# 34  卫裤    80     0
# 35  卫裤   8XL     0
# 36  卫裤    90     0
# 37  卫裤   9XL     0
# 38  卫裤     L     0
# 39  卫裤     M     0
# 40  卫裤     S     0
# 41  卫裤    XL     0
# 42  卫裤    XS     0
# 43  卫裤   XXL     0
# 44  卫裤   XXS     0
# Xmax-- 夹克 =  0.625 ======
#     小类    尺码  尺码比例
# 0   夹克  10XL     1
# 1   夹克   3XL     1
# 2   夹克   3XS     1
# 3   夹克   4XL     1
# 4   夹克   5XL     1
# 5   夹克   6XL     1
# 6   夹克   7XL     1
# 7   夹克   8XL     1
# 8   夹克   9XL     1
# 9   夹克     L     1
# 10  夹克     M     1
# 11  夹克     S     1
# 12  夹克    XL     1
# 13  夹克    XS     1
# 14  夹克   XXL     1
# 15  夹克   XXS     1
# Xmax-- 套头无帽卫衣 =  0.2272727272727273 ======
#         小类    尺码  尺码比例
# 0   套头无帽卫衣   100     0
# 1   套头无帽卫衣  10XL     0
# 2   套头无帽卫衣   110     0
# 3   套头无帽卫衣   115     0
# Xmax-- 拼接卫裤 =  2.0 ======
#      小类   尺码  尺码比例
# 0  拼接卫裤  3XL     1
# 1  拼接卫裤    L     2
# 2  拼接卫裤    M     2
# 3  拼接卫裤    S     2
# 4  拼接卫裤   XL     2
# 5  拼接卫裤  XXL     1
# Xmax-- 拼接套头无帽卫衣 =  1.6666666666666665 ======
#          小类   尺码  尺码比例
# 0  拼接套头无帽卫衣  3XL     2
# 1  拼接套头无帽卫衣    L     2
# 2  拼接套头无帽卫衣    M     2
# 3  拼接套头无帽卫衣    S     2
# 4  拼接套头无帽卫衣   XL     2
# 5  拼接套头无帽卫衣  XXL     2
# Xmax-- 拼接棉茄克 =  2.095238095238095 ======
#       小类   尺码  尺码比例
# 0  拼接棉茄克  3XL     2
# 1  拼接棉茄克    L     1
# 2  拼接棉茄克    M     2
# 3  拼接棉茄克    S     2
# 4  拼接棉茄克   XL     1
# 5  拼接棉茄克   XS     1
# 6  拼接棉茄克  XXL     1
# Xmax-- 拼接紧身运动长裤 =  2.127659574468085 ======
#          小类   尺码  尺码比例
# 0  拼接紧身运动长裤    L     0
# 1  拼接紧身运动长裤    M     2
# 2  拼接紧身运动长裤    S     2
# 3  拼接紧身运动长裤   XL     1
# 4  拼接紧身运动长裤   XS     2
# 5  拼接紧身运动长裤  XXL     2
# Xmax-- 棉夹克 =  0.2272727272727273 ======
#      小类    尺码  尺码比例
# 0   棉夹克   100     0
# 1   棉夹克  10XL     0
# 2   棉夹克   110     0
# 3   棉夹克   115     0
# 4   棉夹克   120     0
# 5   棉夹克   125     0
# 6   棉夹克   130     0
# 7   棉夹克   135     0
# 8   棉夹克   140     0
# 9   棉夹克   145     0
# 10  棉夹克   150     0
# 11  棉夹克   155     0
# 12  棉夹克   160     0
# 13  棉夹克   165     0
# 14  棉夹克   170     0
# 15  棉夹克   175     0
# 16  棉夹克   180     0
# 17  棉夹克   185     0
# 18  棉夹克   190     0
# 19  棉夹克   195     0
# 20  棉夹克   200     0
# 21  棉夹克   205     0
# 22  棉夹克   210     0
# 23  棉夹克   215     0
# 24  棉夹克   220     0
# 25  棉夹克   3XL     0
# 26  棉夹克   3XS     0
# 27  棉夹克   4XL     0
# 28  棉夹克   5XL     0
# 29  棉夹克    60     0
# 30  棉夹克   6XL     0
# 31  棉夹克    70     0
# 32  棉夹克   7XL     0
# 33  棉夹克    80     0
# 34  棉夹克   8XL     0
# 35  棉夹克    90     0
# 36  棉夹克   9XL     0
# 37  棉夹克     L     0
# 38  棉夹克     M     0
# 39  棉夹克     S     0
# 40  棉夹克    XL     0
# 41  棉夹克    XS     0
# 42  棉夹克   XXL     0
# 43  棉夹克   XXS     0
# Xmax-- 比赛上衣 =  0.43478260869565216 ======
#       小类    尺码  尺码比例
# 0   比赛上衣  10XL     0
# 1   比赛上衣   110     0
# 2   比赛上衣   120     0
# 3   比赛上衣   130     0
# 4   比赛上衣   140     0
# 5   比赛上衣   150     0
# 6   比赛上衣   160     0
# 7   比赛上衣   170     0
# 8   比赛上衣   3XL     0
# 9   比赛上衣   3XS     0
# 10  比赛上衣   4XL     0
# 11  比赛上衣   5XL     0
# 12  比赛上衣   6XL     0
# 13  比赛上衣   7XL     0
# 14  比赛上衣   8XL     0
# 15  比赛上衣   9XL     0
# 16  比赛上衣     L     0
# 17  比赛上衣     M     0
# 18  比赛上衣     S     0
# 19  比赛上衣    XL     0
# 20  比赛上衣    XS     0
# 21  比赛上衣   XXL     0
# 22  比赛上衣   XXS     0
# Xmax-- 比赛裤 =  0.43478260869565216 ======
#      小类    尺码  尺码比例
# 0   比赛裤  10XL     0
# 1   比赛裤   110     0
# 2   比赛裤   120     0
# 3   比赛裤   130     0
# 4   比赛裤   140     0
# 5   比赛裤   150     0
# 6   比赛裤   160     0
# 7   比赛裤   170     0
# 8   比赛裤   3XL     0
# 9   比赛裤   3XS     0
# 10  比赛裤   4XL     0
# 11  比赛裤   5XL     0
# 12  比赛裤   6XL     0
# 13  比赛裤   7XL     0
# 14  比赛裤   8XL     0
# 15  比赛裤   9XL     0
# 16  比赛裤     L     0
# 17  比赛裤     M     0
# 18  比赛裤     S     0
# 19  比赛裤    XL     0
# 20  比赛裤    XS     0
# 21  比赛裤   XXL     0
# 22  比赛裤   XXS     0
# Xmax-- 短棉服 =  0.625 ======
#      小类    尺码  尺码比例
# 0   短棉服  10XL     1
# 1   短棉服   3XL     1
# 2   短棉服   3XS     1
# 3   短棉服   4XL     1
# 4   短棉服   5XL     1
# 5   短棉服   6XL     1
# 6   短棉服   7XL     1
# 7   短棉服   8XL     1
# 8   短棉服   9XL     1
# 9   短棉服     L     1
# 10  短棉服     M     1
# 11  短棉服     S     1
# 12  短棉服    XL     1
# 13  短棉服    XS     1
# 14  短棉服   XXL     1
# 15  短棉服   XXS     1
# Xmax-- 短羽绒服 =  0.2272727272727273 ======
#       小类    尺码  尺码比例
# 0   短羽绒服   100     0
# 1   短羽绒服  10XL     0
# 2   短羽绒服   110     0
# 3   短羽绒服   115     0
# 4   短羽绒服   120     0
# 5   短羽绒服   125     0
# 6   短羽绒服   130     0
# 7   短羽绒服   135     0
# 8   短羽绒服   140     0
# 9   短羽绒服   145     0
# 10  短羽绒服   150     0
# 11  短羽绒服   155     0
# 12  短羽绒服   160     0
# 13  短羽绒服   165     0
# 14  短羽绒服   170     0
# 15  短羽绒服   175     0
# 16  短羽绒服   180     0
# 17  短羽绒服   185     0
# 18  短羽绒服   190     0
# 19  短羽绒服   195     0
# 20  短羽绒服   200     0
# 21  短羽绒服   205     0
# 22  短羽绒服   210     0
# 23  短羽绒服   215     0
# 24  短羽绒服   220     0
# 25  短羽绒服   3XL     0
# 26  短羽绒服   3XS     0
# 27  短羽绒服   4XL     0
# 28  短羽绒服   5XL     0
# 29  短羽绒服    60     0
# 30  短羽绒服   6XL     0
# 31  短羽绒服    70     0
# 32  短羽绒服   7XL     0
# 33  短羽绒服    80     0
# 34  短羽绒服   8XL     0
# 35  短羽绒服    90     0
# 36  短羽绒服   9XL     0
# 37  短羽绒服     L     0
# 6   运动风衣   130     0
# 7   运动风衣   135     0
# 8   运动风衣   140     0
# 9   运动风衣   145     0
# 10  运动风衣   150     0
# 11  运动风衣   155     0
# 12  运动风衣   160     0
# 13  运动风衣   165     0
# 14  运动风衣   170     0
# 15  运动风衣   175     0
# 16  运动风衣   180     0
# 17  运动风衣   185     0
# 18  运动风衣   190     0
# 19  运动风衣   195     0
# 20  运动风衣   200     0
# 21  运动风衣   205     0
# 22  运动风衣   210     0
# 23  运动风衣   215     0
# 24  运动风衣   220     0
# 25  运动风衣   3XL     0
# 26  运动风衣   3XS     0
# 27  运动风衣   4XL     0
# 28  运动风衣   4XS     0
# 29  运动风衣   5XL     0
# 30  运动风衣    60     0
# 31  运动风衣   6XL     0
# 32  运动风衣    70     0
# 33  运动风衣   7XL     0
# 34  运动风衣    80     0
# 35  运动风衣   8XL     0
# 36  运动风衣    90     0
# 37  运动风衣   9XL     0
# 38  运动风衣     L     0
# 39  运动风衣     M     0
# 40  运动风衣     S     0
# 41  运动风衣    XL     0
# 42  运动风衣    XS     0
# 43  运动风衣   XXL     0
# 44  运动风衣   XXS     0
# Xmax-- 连衣裙 =  1.5 ======
#     小类   尺码  尺码比例
# 0  连衣裙  3XL     2
# 1  连衣裙    L     2
# 2  连衣裙    M     2
# 3  连衣裙    S     2
# 4  连衣裙   XL     0
# 5  连衣裙   XS     2
# 6  连衣裙  XXL     0
# 7  连衣裙  XXS     2
# Xmax-- 速干长裤 =  2.720430107526843 ======
#      小类   尺码  尺码比例
# 0  速干长裤  3XL     1
# 1  速干长裤  4XL     1
# 2  速干长裤    L     3
# 3  速干长裤    M     1
# 4  速干长裤    S     0
# 5  速干长裤   XL     3
# 6  速干长裤   XS     0
# 7  速干长裤  XXL     2
# Xmax-- 针织休闲裤 =  2.0 ======
#       小类   尺码  尺码比例
# 0  针织休闲裤  3XL     2
# 1  针织休闲裤    L     2
# 2  针织休闲裤    M     2
# 3  针织休闲裤    S     1
# 4  针织休闲裤   XL     2
# 5  针织休闲裤  XXL     1
# Xmax-- 针织外套 =  1.4999999999999976 ======
#      小类   尺码  尺码比例
# 0  针织外套  3XL     1
# 1  针织外套  4XL     1
# 2  针织外套    L     1
# 3  针织外套    M     1
# 4  针织外套    S     1
# 5  针织外套   XL     0
# 6  针织外套   XS     2
# 7  针织外套  XXL     0
# Xmax-- 针织运动上衣 =  1.4659685863907925 ======
#        小类   尺码  尺码比例
# 0  针织运动上衣  3XL     0
# 1  针织运动上衣  4XL     1
# 2  针织运动上衣    L     1
# 3  针织运动上衣    M     1
# 4  针织运动上衣    S     0
# 5  针织运动上衣   XL     1
# 6  针织运动上衣   XS     1
# 7  针织运动上衣  XXL     0
# 8  针织运动上衣  XXS     1
# Xmax-- 针织运动裤 =  1.7931034482758619 ======
#       小类   尺码  尺码比例
# 0  针织运动裤  3XL     0
# 1  针织运动裤  4XL     2
# 2  针织运动裤    L     2
# 3  针织运动裤    M     2
# 4  针织运动裤    S     1
# 5  针织运动裤   XL     1
# 6  针织运动裤   XS     2
# 7  针织运动裤  XXL     1
# Xmax-- 针织长袖衫 =  3.235294117647059 ======
#       小类   尺码  尺码比例
# 0  针织长袖衫  3XL     1
# 1  针织长袖衫  4XL     0
# 2  针织长袖衫  5XL     0
# 3  针织长袖衫    L     1
# 4  针织长袖衫    M     3
# 5  针织长袖衫    S     2
# 6  针织长袖衫   XL     2
# 7  针织长袖衫  XXL     1
# Xmax-- 针织阔腿裤 =  1.375 ======
#       小类   尺码  尺码比例
# 0  针织阔腿裤  3XL     1
# 1  针织阔腿裤    L     1
# 2  针织阔腿裤    M     1
# 3  针织阔腿裤    S     0
# 4  针织阔腿裤   XL     1
# 5  针织阔腿裤   XS     1
# 6  针织阔腿裤  XXL     1
# 7  针织阔腿裤  XXS     1
# Xmax-- 长棉服 =  0.625 ======
#      小类    尺码  尺码比例
# 0   长棉服  10XL     1
# 1   长棉服   3XL     1
# 2   长棉服   3XS     1
# 3   长棉服   4XL     1
# 4   长棉服   5XL     1
# 5   长棉服   6XL     1
# 6   长棉服   7XL     1
# 7   长棉服   8XL     1
# 8   长棉服   9XL     1
# 9   长棉服     L     1
# 10  长棉服     M     1
# 11  长棉服     S     1
# 12  长棉服    XL     1
# 13  长棉服    XS     1
# 14  长棉服   XXL     1
# 15  长棉服   XXS     1
# Xmax-- 长羽绒服 =  0.22222222222222224 ======
#       小类    尺码  尺码比例
# 0   长羽绒服   100     0
# 1   长羽绒服  10XL     0
# 2   长羽绒服   110     0
# 3   长羽绒服   115     0
# 4   长羽绒服   120     0
# 5   长羽绒服   125     0
# 6   长羽绒服   130     0
# 7   长羽绒服   135     0
# 8   长羽绒服   140     0
# 9   长羽绒服   145     0
# 10  长羽绒服   150     0
# 11  长羽绒服   155     0
# 12  长羽绒服   160     0
# 13  长羽绒服   165     0
# 14  长羽绒服   170     0
# 15  长羽绒服   175     0
# 16  长羽绒服   180     0
# 17  长羽绒服   185     0
# 18  长羽绒服   190     0
# 19  长羽绒服   195     0
# 20  长羽绒服   200     0
# 21  长羽绒服   205     0
# 22  长羽绒服   210     0
# 23  长羽绒服   215     0
# 24  长羽绒服   220     0
# 25  长羽绒服   3XL     0
# 26  长羽绒服   3XS     0
# 27  长羽绒服   4XL     0
# 28  长羽绒服   4XS     0
# 29  长羽绒服   5XL     0
# 30  长羽绒服    60     0
# 31  长羽绒服   6XL     0
# 32  长羽绒服    70     0
# 33  长羽绒服   7XL     0
# 34  长羽绒服    80     0
# 35  长羽绒服   8XL     0
# 36  长羽绒服    90     0
# 37  长羽绒服   9XL     0
# 38  长羽绒服     L     0
# 39  长羽绒服     M     0
# 40  长羽绒服     S     0
# 41  长羽绒服    XL     0
# 42  长羽绒服    XS     0
# 43  长羽绒服   XXL     0
# 44  长羽绒服   XXS     0
# Xmax-- 长袖Polo =  0.6666666666666666 ======
#         小类   尺码  尺码比例
# 0   长袖Polo  3XL     1
# 1   长袖Polo  3XS     1
# 2   长袖Polo  4XL     1
# 3   长袖Polo  4XS     1
# 4   长袖Polo  5XL     1
# 5   长袖Polo  6XL     1
# 6   长袖Polo  7XL     1
# 7   长袖Polo  8XL     1
# 8   长袖Polo    L     1
# 9   长袖Polo    M     1
# 10  长袖Polo    S     1
# 11  长袖Polo   XL     1
# 12  长袖Polo   XS     1
# 13  长袖Polo  XXL     1
# 14  长袖Polo  XXS     1
# Xmax-- 长袖T恤 =  0.47619047619047616 ======
#       小类    尺码  尺码比例
# 0   长袖T恤  10XL     0
# 1   长袖T恤   130     0
# 2   长袖T恤   140     0
# 3   长袖T恤   150     0
# 4   长袖T恤   160     0
# 5   长袖T恤   170     0
# 6   长袖T恤   3XL     0
# 7   长袖T恤   3XS     0
# 8   长袖T恤   4XL     0
# 9   长袖T恤   5XL     0
# 10  长袖T恤   6XL     0
# 11  长袖T恤   7XL     0
# 12  长袖T恤   8XL     0
# 13  长袖T恤   9XL     0
# 14  长袖T恤     L     0
# 15  长袖T恤     M     0
# 16  长袖T恤     S     0
# 17  长袖T恤    XL     0
# 18  长袖T恤    XS     0
# 19  长袖T恤   XXL     0
# 20  长袖T恤   XXS     0
# Xmax-- 长袖套头衫 =  1.25 ======
#       小类   尺码  尺码比例
# 0  长袖套头衫  3XL     1
# 1  长袖套头衫  4XL     1
# 2  长袖套头衫    L     1
# 3  长袖套头衫    M     1
# 4  长袖套头衫    S     1
# 5  长袖套头衫   XL     1
# 6  长袖套头衫   XS     1
# 7  长袖套头衫  XXL     1
# Xmax-- 长袖文化衫 =  0.625 ======
#        小类    尺码  尺码比例
# 0   长袖文化衫  10XL     1
# 1   长袖文化衫   3XL     1
# 2   长袖文化衫   3XS     1
# 3   长袖文化衫   4XL     1
# 4   长袖文化衫   5XL     1
# 5   长袖文化衫   6XL     1
# 6   长袖文化衫   7XL     1
# 7   长袖文化衫   8XL     1
# 8   长袖文化衫   9XL     1
# 9   长袖文化衫     L     1
# 10  长袖文化衫     M     1
# 11  长袖文化衫     S     1
# 12  长袖文化衫    XL     1
# 13  长袖文化衫    XS     1
# 14  长袖文化衫   XXL     1
# 15  长袖文化衫   XXS     1
# Xmax-- 长袖紧身衣 =  0.7142857142857142 ======
#        小类   尺码  尺码比例
# 0   长袖紧身衣  135     1
# 1   长袖紧身衣  140     1
# 2   长袖紧身衣  150     1
# 3   长袖紧身衣  160     1
# 4   长袖紧身衣  170     1
# 5   长袖紧身衣  175     1
# 6   长袖紧身衣  3XL     1
# 7   长袖紧身衣  4XL     1
# 8   长袖紧身衣    L     1
# 9   长袖紧身衣    M     1
# 10  长袖紧身衣    S     1
# 11  长袖紧身衣   XL     1
# 12  长袖紧身衣   XS     1
# 13  长袖紧身衣  XXL     1

# %%
# Clothes_result_2

# %%
result = pd.merge(Clothes_result, Clothes_result_2, how='right', on=['小类', '尺码'])

# %%
result

# %%
exl_time = dt.datetime.now().strftime('%Y%m%d')
locaurl ='C:\\Users\\liuju\\Desktop\\LiNingResult\\LiningClothesResult555'+exl_time+'.xlsx'
result.to_excel(locaurl, index = False)
